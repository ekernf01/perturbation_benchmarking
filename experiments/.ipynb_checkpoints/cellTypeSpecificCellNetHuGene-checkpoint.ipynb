# %% [markdown]
# ## Experiment "cellTypeSpecificCellNet"
#
# Same as "cellTypeSpecific", but deriving base networks from CellNet instead of ANANSE.

# %%
EXPERIMENT_NAME="cellTypeSpecificCellNetHuGene_v1"

# %%
import warnings
warnings.filterwarnings('ignore')
import importlib
import os
import gc
import re
import sys
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import celloracle as co
import joblib 
#      visualization settings
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
plt.rcParams['figure.figsize'] = [6, 4.5]
plt.rcParams["savefig.dpi"] = 300

# %%
# Deal with various file paths specific to this project
PROJECT_PATH = '/home/ekernf01/Desktop/jhu/research/projects/perturbation_prediction/cell_type_knowledge_transfer/'
os.chdir(PROJECT_PATH + "benchmarking/")
try:
    os.makedirs("results/" + EXPERIMENT_NAME)
except:
    pass

sys.path.append(os.path.expanduser(PROJECT_PATH + 'networks/load_networks'))
sys.path.append(os.path.expanduser(PROJECT_PATH + 'perturbations/load_perturbations')) 
sys.path.append(os.path.expanduser(PROJECT_PATH + 'benchmarking/evaluator')) 
import evaluator
import load_networks
import load_perturbations
importlib.reload(evaluator) 
importlib.reload(load_networks) 
importlib.reload(load_perturbations)
os.environ["GRN_PATH"]           = PROJECT_PATH + "networks/networks"
os.environ["PERTURBATION_PATH"]  = PROJECT_PATH + "perturbations/perturbations"
load_networks.load_grn_metadata()
# Out:
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2
#                                                       name  \
# name
# cellnet_human_Hg1332                  cellnet_human_Hg1332
# cellnet_human_Hugene                  cellnet_human_Hugene
# cellnet_mouse_4302                      cellnet_mouse_4302
# cellnet_mouse_mogene                  cellnet_mouse_mogene
# encode-nets_human                        encode-nets_human
# fntm                                                  fntm
# humanbase                                        humanbase
# chea                                                  chea
# csnets                                              csnets
# magnum_compendium_32                  magnum_compendium_32
# magnum_compendium_394                magnum_compendium_394
# regulatorynetworks.org_human  regulatorynetworks.org_human
# regulatorynetworks.org_mouse  regulatorynetworks.org_mouse
# gtex_rna                                          gtex_rna
# magnum_compendium_ppi                magnum_compendium_ppi
# celloracle_human                          celloracle_human
# MARA_FANTOM4                                  MARA_FANTOM4
# ANANSE                                              ANANSE
# ANANSE_tissue                                ANANSE_tissue
# STRING                                              STRING
# ANANSE_0.5                                      ANANSE_0.5
# ANANSE_tissue_0.5                        ANANSE_tissue_0.5
#
#                                                                     description  \
# name
# cellnet_human_Hg1332             CLR analysis of microarray data pulled off GEO
# cellnet_human_Hugene             CLR analysis of microarray data pulled off GEO
# cellnet_mouse_4302               CLR analysis of microarray data pulled off GEO
# cellnet_mouse_mogene             CLR analysis of microarray data pulled off GEO
# encode-nets_human                                         TF-ChIP data (ENCODE)
# fntm                          Bayesian classifier based on a ground truth da...
# humanbase                     Bayesian classifier based on a ground truth da...
# chea                                               TF ChIP data (miscellaneous)
# csnets                                         Motif analysis + RNA integration
# magnum_compendium_32          Motif analysis of FANTOM5 CAGE data. Top-level...
# magnum_compendium_394         Motif analysis of FANTOM5 CAGE data. Tissue-sp...
# regulatorynetworks.org_human                Motif analysis of ENCODE Dnase data
# regulatorynetworks.org_mouse                Motif analysis of ENCODE Dnase data
# gtex_rna                      Graphical LASSO on gTEX data (plus tree-struct...
# magnum_compendium_ppi         From same webpage as the MAGNUM CAGE analysis,...
# celloracle_human                                    Motif analysis of promoters
# MARA_FANTOM4                                        Motif analysis of promoters
# ANANSE                                              Motif analysis of enhancers
# ANANSE_tissue                                       Motif analysis of enhancers
# STRING                        Protein-protein interactions from a variety of...
# ANANSE_0.5                    Like “ANANSE” but edges below probability 0.5 ...
# ANANSE_tissue_0.5             Like “ANANSE” but edges below probability 0.5 ...
#
#                                                               data_used  \
# name
# cellnet_human_Hg1332          microarrays (HG133 plus 2 and HuGene 1.0)
# cellnet_human_Hugene          microarrays (HG133 plus 2 and HuGene 1.0)
# cellnet_mouse_4302                   microarrays (MoGene 1.0 and 430.2)
# cellnet_mouse_mogene                 microarrays (MoGene 1.0 and 430.2)
# encode-nets_human                                               TF ChIP
# fntm                                                         everything
# humanbase                                                    everything
# chea                                                             ChIP-X
# csnets                                                       Dnase, RNA
# magnum_compendium_32                                               CAGE
# magnum_compendium_394                                              CAGE
# regulatorynetworks.org_human                                      Dnase
# regulatorynetworks.org_mouse                                      Dnase
# gtex_rna                                                        RNA-seq
# magnum_compendium_ppi                                               ppi
# celloracle_human                                                   None
# MARA_FANTOM4                                                       CAGE
# ANANSE                                                    ATAC and ChIP
# ANANSE_tissue                                             ATAC and ChIP
# STRING                                                              NaN
# ANANSE_0.5                                                ATAC and ChIP
# ANANSE_tissue_0.5                                         ATAC and ChIP
#
#                                   species  \
# name
# cellnet_human_Hg1332                human
# cellnet_human_Hugene                human
# cellnet_mouse_4302                  mouse
# cellnet_mouse_mogene                mouse
# encode-nets_human                   human
# fntm                                mouse
# humanbase                           human
# chea                          human_mouse
# csnets                              human
# magnum_compendium_32                human
# magnum_compendium_394               human
# regulatorynetworks.org_human        human
# regulatorynetworks.org_mouse        mouse
# gtex_rna                            human
# magnum_compendium_ppi               human
# celloracle_human                    human
# MARA_FANTOM4                        human
# ANANSE                              human
# ANANSE_tissue                       human
# STRING                              human
# ANANSE_0.5                          human
# ANANSE_tissue_0.5                   human
#
#                                                                            link  \
# name
# cellnet_human_Hg1332                         http://pcahan1.github.io/cellnetr/
# cellnet_human_Hugene                         http://pcahan1.github.io/cellnetr/
# cellnet_mouse_4302                           http://pcahan1.github.io/cellnetr/
# cellnet_mouse_mogene                         http://pcahan1.github.io/cellnetr/
# encode-nets_human                            http://encodenets.gersteinlab.org/
# fntm                                        http://fntm.princeton.edu/download/
# humanbase                             https://hb.flatironinstitute.org/download
# chea                          http://amp.pharm.mssm.edu/Harmonizome/resource...
# csnets                        http://bioinfo.au.tsinghua.edu.cn/jianglab/CSN...
# magnum_compendium_32                   http://regulatorycircuits.org/index.html
# magnum_compendium_394                  http://regulatorycircuits.org/index.html
# regulatorynetworks.org_human                 http://www.regulatorynetworks.org/
# regulatorynetworks.org_mouse                 http://www.regulatorynetworks.org/
# gtex_rna                                  http://mostafavilab.stat.ubc.ca/gnat/
# magnum_compendium_ppi                  http://regulatorycircuits.org/index.html
# celloracle_human                       https://github.com/morris-lab/CellOracle
# MARA_FANTOM4                  https://swissregulon.unibas.ch/data/fantom4/RE...
# ANANSE                                   https://doi.org/10.5281/zenodo.4809062
# ANANSE_tissue                            https://doi.org/10.5281/zenodo.4807801
# STRING                        https://stringdb-static.org/download/protein.l...
# ANANSE_0.5                               https://doi.org/10.5281/zenodo.4809062
# ANANSE_tissue_0.5                        https://doi.org/10.5281/zenodo.4807801
#
#                                                                        citation  \
# name
# cellnet_human_Hg1332          Cahan, P., Li, H., Morris, S. A., Da Rocha, E....
# cellnet_human_Hugene          Cahan, P., Li, H., Morris, S. A., Da Rocha, E....
# cellnet_mouse_4302            Cahan, P., Li, H., Morris, S. A., Da Rocha, E....
# cellnet_mouse_mogene          Cahan, P., Li, H., Morris, S. A., Da Rocha, E....
# encode-nets_human             Gerstein, M. B., Kundaje, A., Hariharan, M., L...
# fntm                          Goya, J., Wong, A. K., Yao, V., Krishnan, A., ...
# humanbase                     Greene, C. S., Krishnan, A., Wong, A. K., Ricc...
# chea                          Lachmann, A., Xu, H., Krishnan, J., Berger, S....
# csnets                        Ma, S., Jiang, T., & Jiang, R. (2018). Constru...
# magnum_compendium_32          Marbach, D., Lamparter, D., Quon, G., Kellis, ...
# magnum_compendium_394         Marbach, D., Lamparter, D., Quon, G., Kellis, ...
# regulatorynetworks.org_human  Neph, S., Stergachis, A. B., Reynolds, A., San...
# regulatorynetworks.org_mouse  Neph, S., Stergachis, A. B., Reynolds, A., San...
# gtex_rna                      Pierson, E., Koller, D., Battle, A., Mostafavi...
# magnum_compendium_ppi                               See dataset-specific README
# celloracle_human              Kamimoto, K., Hoffmann, C. M., & Morris, S. A....
# MARA_FANTOM4                  Center, R. O. S., & FANTOM Consortium. (2009)....
# ANANSE                        Xu, Q., Georgiou, G., Frölich, S., van der San...
# ANANSE_tissue                 Xu, Q., Georgiou, G., Frölich, S., van der San...
# STRING                        The STRING database in 2021: customizable prot...
# ANANSE_0.5                    Xu, Q., Georgiou, G., Frölich, S., van der San...
# ANANSE_tissue_0.5             Xu, Q., Georgiou, G., Frölich, S., van der San...
#
#                              is_ready first_column
# name
# cellnet_human_Hg1332              yes    symmetric
# cellnet_human_Hugene              yes    symmetric
# cellnet_mouse_4302                yes    symmetric
# cellnet_mouse_mogene              yes    symmetric
# encode-nets_human                 yes    regulator
# fntm                              yes    symmetric
# humanbase                         yes    symmetric
# chea                              yes    regulator
# csnets                            yes    regulator
# magnum_compendium_32              yes    regulator
# magnum_compendium_394             yes    regulator
# regulatorynetworks.org_human      yes    regulator
# regulatorynetworks.org_mouse      yes    regulator
# gtex_rna                          yes    symmetric
# magnum_compendium_ppi             yes    regulator
# celloracle_human                  yes    regulator
# MARA_FANTOM4                      yes    regulator
# ANANSE                            yes    regulator
# ANANSE_tissue                     yes    regulator
# STRING                            yes    regulator
# ANANSE_0.5                        yes    regulator
# ANANSE_tissue_0.5                 yes    regulator

# %% [markdown]
# ### Networks setup
#
# This experiment aims to test a variety of published sparse regulatory network structures.

# %%
networks = {
    'dense': evaluator.makeRandomNetwork(density = 1),
    'CellNet_all': evaluator.networkEdgesToMatrix(load_networks.load_grn_all_subnetworks("cellnet_human_Hugene"))
}

# %%
for network in load_networks.list_subnetworks("cellnet_human_Hugene"):
    print("Loading " + network)
    if not network in networks:
        networks[network] = evaluator.networkEdgesToMatrix(load_networks.load_grn_by_subnetwork("cellnet_human_Hugene", network))
    gc.collect()
    
network_sizes = pd.DataFrame({bn:evaluator.countMatrixEdges(networks[bn]) for bn in networks}, index = ["numEdges"])
network_sizes = network_sizes.T.reset_index().rename({"index":"network"}, axis = 1)
network_sizes
# Out:
# Loading macrophage.csv.gz
# Loading heart.csv.gz
# Loading bcell.csv.gz
# Loading esc.csv.gz
# Loading fibroblast.csv.gz
# Loading tcell.csv.gz
# Loading muscleSkel.csv.gz
# Loading kidney.csv.gz
# Loading endothelial.csv.gz
# Loading liver.csv.gz
# Loading hspc.csv.gz
# Loading lung.csv.gz
# Loading skin.csv.gz
#                network     numEdges
# 0                dense  102313295.0
# 1          CellNet_all     157408.0
# 2    macrophage.csv.gz      11084.0
# 3         heart.csv.gz      12528.0
# 4         bcell.csv.gz      22934.0
# 5           esc.csv.gz      32864.0
# 6    fibroblast.csv.gz      15398.0
# 7         tcell.csv.gz      22582.0
# 8    muscleSkel.csv.gz      12586.0
# 9        kidney.csv.gz       9560.0
# 10  endothelial.csv.gz       9770.0
# 11        liver.csv.gz       9004.0
# 12         hspc.csv.gz      42908.0
# 13         lung.csv.gz       3230.0
# 14         skin.csv.gz       6900.0

# %% [markdown]
# ### Data setup
#
# We use the Nakatake et al data. This experiment is on per-cluster versus shared regression models, so we run Leiden clustering at many different resolutions.

# %%
ko_lab_esc_data = sc.read_h5ad(os.environ["PERTURBATION_PATH"] + "/nakatake/" + "test.h5ad")
cellFateClassifier = joblib.load(os.environ["PERTURBATION_PATH"] + "/nakatake/" + "classifier.joblib")

# %%
ko_lab_esc_data.obs.columns
# Out:
# Index(['perturbation', 'is_control', 'fraction_missing', 'leiden',
#        'fake_cluster'],
#       dtype='object')

# %%
allowedRegulators = set.union(*[set(networks[key].columns) for key in networks])
ko_lab_esc_data_train, ko_lab_esc_data_heldout, perturbationsToPredict = \
    evaluator.splitData(ko_lab_esc_data, allowedRegulators, minTestSetSize=250)
# Out:
# Example perturbations formatted as
#  (gene, expression after perturbation)
# [('ALX3', 2.829177), ('ALX3', 3.583377), ('ARNT2', 3.8641534), ('ARNT2', 2.533805), ('ASCL2', 0.61448115)]
# Test set size:
# 263
# Training set size:
# 250

# %% [markdown]
# ### Experimental metadata

# %%
n_networks = len(networks.keys())
experiments = pd.DataFrame({"network":[n for n in networks.keys()], 
                            "p":[1]*n_networks,
                            "threshold_number":[int(network_sizes['numEdges'].max())]*n_networks,
                            "pruning":["none"]*n_networks})
experiments["index"] = experiments.index
experiments.to_csv("results/" + EXPERIMENT_NAME + "/networkExperiments.csv")
experiments
# Out:
#                network  p  threshold_number pruning  index
# 0                dense  1         102313295    none      0
# 1          CellNet_all  1         102313295    none      1
# 2    macrophage.csv.gz  1         102313295    none      2
# 3         heart.csv.gz  1         102313295    none      3
# 4         bcell.csv.gz  1         102313295    none      4
# 5           esc.csv.gz  1         102313295    none      5
# 6    fibroblast.csv.gz  1         102313295    none      6
# 7         tcell.csv.gz  1         102313295    none      7
# 8    muscleSkel.csv.gz  1         102313295    none      8
# 9        kidney.csv.gz  1         102313295    none      9
# 10  endothelial.csv.gz  1         102313295    none     10
# 11        liver.csv.gz  1         102313295    none     11
# 12         hspc.csv.gz  1         102313295    none     12
# 13         lung.csv.gz  1         102313295    none     13
# 14         skin.csv.gz  1         102313295    none     14

# %%
predictions = {
    i: evaluator.trainCausalModelAndPredict(expression=ko_lab_esc_data_train,
                                  baseNetwork=networks[experiments.loc[i,'network']],
                                  memoizationName="results/" + EXPERIMENT_NAME + "/" + str(i) + ".celloracle.oracle", 
                                  perturbations=perturbationsToPredict,
                                  clusterColumnName = "fake_cluster",
                                  pruningParameters = {"p":experiments.loc[i,'p'], 
                                                       "threshold_number":experiments.loc[i,'threshold_number']}) 
    for i in experiments.index
}
# Out:
# Working on results/cellTypeSpecificCellNetHuGene_v1/0.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/1 [00:00<?, ?it/s]
# inferring GRN for all_one_cluster...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in all_one_cluster
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# Predicting ZSCAN5A
# ALX3 ALX3 ARNT2 ARNT2 ASCL2 ASCL2 ATF1 ATF1 ATF3 ATF3 BARX2 BARX2 BATF BATF BCL6 BCL6 BLZF1 BLZF1 BMP4 BMP4 BRF2 BRF2 CCNE1
# Prediction failed for CCNE1 with error Gene CCNE1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CCNE1
# Prediction failed for CCNE1 with error Gene CCNE1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CDYL
# Prediction failed for CDYL with error Gene CDYL is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CDYL
# Prediction failed for CDYL with error Gene CDYL is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CENPX CERS2 CERS2 CHD4 CHD4 CREB1 CREB1 CRY1
# Prediction failed for CRY1 with error Gene CRY1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CRY1
# Prediction failed for CRY1 with error Gene CRY1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CRY2
# Prediction failed for CRY2 with error Gene CRY2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CRY2
# Prediction failed for CRY2 with error Gene CRY2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTBP2 CTBP2 CUX1 CUX1 DEDD2
# Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DEDD2
# Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DVL2 DVL2 E2F4 E2F4 E2F6 E2F6 EBF1 EBF1 EHF EHF ELF1 ELF1 ELF5 ELF5 ELK3 ELK3 ELL2
# Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELL2
# Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# EN1 EN1 EOMES EOMES ESRRA ESRRA ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETS1 ETS1 ETS2 ETS2 ETV1 ETV1 ETV3 ETV3 ETV5 ETV5 FEV FEV FIGLA FIGLA FLI1 FLI1 FOSL1 FOSL1 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXC1 FOXC1 FOXD1 FOXD1 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXJ1 FOXJ1 FOXM1 FOXM1 FOXN3 FOXN3 FOXO3 FOXO3 FOXP3 FOXP3 GATA6 GATA6 GLI1 GLI1 GRHL2 GRHL2 GSC GSC GTF2F1 GTF2F1 GTF3C2 GTF3C2 HESX1 HESX1 HHEX HHEX HMGA2 HMGA2 HMGXB4 HMGXB4 HNF1A HOPX HOPX HOXA2 HOXA2 HOXA9 HOXA9 HOXB1 HOXB1 HOXB3 HOXB3 HOXB4 HOXB4 HOXD1 HOXD1 HOXD13 HOXD13 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF3 IRF3 IRF4 IRF4 IRF5 IRF5 ISL2 ISL2 JAG1
# Prediction failed for JAG1 with error Gene JAG1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# JAG1
# Prediction failed for JAG1 with error Gene JAG1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# JARID2 JARID2 JUN JUN JUNB JUNB JUNB KAT8 KAT8 KDM5A KDM5A KDM5B KDM5B KLF1 KLF1 KLF11 KLF11 KLF14 KLF14 KLF15 KLF15 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LIN28A LIN28A LMO2 LMO2 MAB21L3
# Prediction failed for MAB21L3 with error Gene MAB21L3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAB21L3
# Prediction failed for MAB21L3 with error Gene MAB21L3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAFK MAFK MEIS1 MEIS1 MNX1 MNX1 MSX2 MSX2 MXI1 MXI1 MYB MYB MYBL2 MYBL2 MYC MYC MYF6 MYF6 NANOG NANOG NEUROD1 NEUROD1 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIC NFIC NFYB NFYB NKX2-1 NKX2-1 NKX6-3 NKX6-3 NR2C2 NR2C2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR3C1 NR3C1 NRF1 NRF1 NSD2 NSD2 OSTF1
# Prediction failed for OSTF1 with error Gene OSTF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OSTF1
# Prediction failed for OSTF1 with error Gene OSTF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OTP OTP OTX1 OTX1 OTX2 OTX2 PA2G4 PA2G4 PATZ1 PATZ1 PAX2 PAX2 PHOX2B PHOX2B PITX3 PITX3 PML PML POLR3A POLR3A POU2AF1 POU2AF1 POU3F2 POU3F2 PPARG PPARG PTF1A PTF1A RARA RARA RASL10A
# Prediction failed for RASL10A with error Gene RASL10A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RASL10A
# Prediction failed for RASL10A with error Gene RASL10A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# REPIN1 REPIN1 REST REST RFX2 RFX2 RFXAP RFXAP RNF2 RNF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RUVBL2
# Prediction failed for RUVBL2 with error Gene RUVBL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RUVBL2
# Prediction failed for RUVBL2 with error Gene RUVBL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SAP30
# Prediction failed for SAP30 with error Gene SAP30 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SIM1 SIM1 SIN3A SIN3A SIRT3 SIRT3 SIRT6 SIRT6 SMAD2 SMAD2 SMAD3 SMAD3 SMAD4 SMAD4 SMARCA4 SMARCA4 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX10 SOX10 SOX15 SOX15 SOX17 SOX17 SOX7 SOX7 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 STAG1 STAG1 STAT3 STAT3 SUB1 SUB1 SUZ12 SUZ12 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TBX6 TBX6 TCF12 TCF12 TCF23 TCF23 TCF4 TCF4 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2C TFAP2C TFCP2L1 TFCP2L1 TGIF1 TGIF1 TGM2
# Prediction failed for TGM2 with error Gene TGM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TGM2
# Prediction failed for TGM2 with error Gene TGM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP1 THAP1 THAP11 THAP11 THAP3 THAP3 TP73 TWIST2 TWIST2 UBTF UBTF VAX1 VAX1 VDR VDR VPS72 VPS72 WNT3A WNT3A WT1 WT1 YY1 YY1 ZBTB3 ZBTB3 ZBTB7A ZFP57 ZFP57 ZIC1 ZIC1 ZKSCAN1 ZKSCAN1 ZMAT4 ZMAT4 ZMYND12
# Prediction failed for ZMYND12 with error Gene ZMYND12 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZMYND12
# Prediction failed for ZMYND12 with error Gene ZMYND12 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF217 ZNF263 ZNF263 ZNF281 ZNF281 ZNF426 ZNF426 ZNF646 ZNF646 ZNF713 ZNF713 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 BMI1 BMI1 BMP7 BMP7 BRF1 BRF1 CBFB CTBP1 CTBP1 CXXC5 CXXC5 DBX1 DBX1 DBX2 DBX2 E2F5 E2F5 ETV4 ETV4 FOSB FOSB HES6 HES6 HMGA1 HMGA1 HOXA1 HOXA1 IKZF5 IKZF5 KLF6 KLF6 LBX2 LBX2 MLLT1 MLLT1 MXD3 MXD3 NFIA NFIA NR1H2 NR1H2 OSR1 OSR1 PGF
# Prediction failed for PGF with error Gene PGF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PGF
# Prediction failed for PGF with error Gene PGF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PRICKLE1
# Prediction failed for PRICKLE1 with error Gene PRICKLE1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SATB1 SATB1 TCF15 TCF15 TEAD2 TEAD2 TEF TEF THRA THRA TNF TNF VAX2 VAX2 ZBTB44 ZBTB44 ZMAT5 ZMAT5 ZNF384 ZNF384 ZNF384 ZNF384 ZNF480 ZNF480 ZSCAN5A ZSCAN5A
# Working on results/cellTypeSpecificCellNetHuGene_v1/1.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/1 [00:00<?, ?it/s]
# inferring GRN for all_one_cluster...
#   0%|          | 0/1290 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in all_one_cluster
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 1149 genes
# Predicting ZSCAN5A
# ALX3
# Prediction failed for ALX3 with error Gene ALX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ALX3
# Prediction failed for ALX3 with error Gene ALX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ARNT2 ARNT2 ASCL2 ASCL2 ATF1
# Prediction failed for ATF1 with error Gene ATF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF1
# Prediction failed for ATF1 with error Gene ATF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF3 ATF3 BARX2
# Prediction failed for BARX2 with error Gene BARX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BARX2
# Prediction failed for BARX2 with error Gene BARX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BATF BATF BCL6 BCL6 BLZF1
# Prediction failed for BLZF1 with error Gene BLZF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BLZF1
# Prediction failed for BLZF1 with error Gene BLZF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BMP4 BMP4 BRF2 BRF2 CCNE1 CCNE1 CDYL CDYL CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CENPX
# Prediction failed for CENPX with error Gene CENPX is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CERS2
# Prediction failed for CERS2 with error Gene CERS2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CERS2
# Prediction failed for CERS2 with error Gene CERS2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD4
# Prediction failed for CHD4 with error Gene CHD4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD4
# Prediction failed for CHD4 with error Gene CHD4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CREB1
# Prediction failed for CREB1 with error Gene CREB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CREB1
# Prediction failed for CREB1 with error Gene CREB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CRY1 CRY1 CRY2 CRY2 CTBP2 CTBP2 CUX1 CUX1 DEDD2 DEDD2 DVL2
# Prediction failed for DVL2 with error Gene DVL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DVL2
# Prediction failed for DVL2 with error Gene DVL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# E2F4
# Prediction failed for E2F4 with error Gene E2F4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# E2F4
# Prediction failed for E2F4 with error Gene E2F4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# E2F6 E2F6 EBF1 EBF1 EHF EHF ELF1 ELF1 ELF5 ELF5 ELK3 ELK3 ELL2 ELL2 EN1 EN1 EOMES EOMES ESRRA
# Prediction failed for ESRRA with error Gene ESRRA does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# ESRRA
# Prediction failed for ESRRA with error Gene ESRRA does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# ESRRB
# Prediction failed for ESRRB with error Gene ESRRB is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ESRRB
# Prediction failed for ESRRB with error Gene ESRRB is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ESRRG ESRRG ESX1
# Prediction failed for ESX1 with error Gene ESX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ESX1
# Prediction failed for ESX1 with error Gene ESX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ETS1 ETS1 ETS2 ETS2 ETV1 ETV1 ETV3
# Prediction failed for ETV3 with error Gene ETV3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ETV3
# Prediction failed for ETV3 with error Gene ETV3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ETV5 ETV5 FEV
# Prediction failed for FEV with error Gene FEV is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FEV
# Prediction failed for FEV with error Gene FEV is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FIGLA
# Prediction failed for FIGLA with error Gene FIGLA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FIGLA
# Prediction failed for FIGLA with error Gene FIGLA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FLI1 FLI1 FOSL1 FOSL1 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1
# Prediction failed for FOXB1 with error Gene FOXB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXB1
# Prediction failed for FOXB1 with error Gene FOXB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXC1 FOXC1 FOXD1 FOXD1 FOXD4L3
# Prediction failed for FOXD4L3 with error Gene FOXD4L3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXD4L3
# Prediction failed for FOXD4L3 with error Gene FOXD4L3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXE3
# Prediction failed for FOXE3 with error Gene FOXE3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXE3
# Prediction failed for FOXE3 with error Gene FOXE3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXJ1
# Prediction failed for FOXJ1 with error Gene FOXJ1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXJ1
# Prediction failed for FOXJ1 with error Gene FOXJ1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXM1 FOXM1 FOXN3 FOXN3 FOXO3
# Prediction failed for FOXO3 with error Gene FOXO3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXO3
# Prediction failed for FOXO3 with error Gene FOXO3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXP3
# Prediction failed for FOXP3 with error Gene FOXP3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXP3
# Prediction failed for FOXP3 with error Gene FOXP3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GATA6 GATA6 GLI1
# Prediction failed for GLI1 with error Gene GLI1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GLI1
# Prediction failed for GLI1 with error Gene GLI1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GRHL2 GRHL2 GSC
# Prediction failed for GSC with error Gene GSC is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GSC
# Prediction failed for GSC with error Gene GSC is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF2F1
# Prediction failed for GTF2F1 with error Gene GTF2F1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF2F1
# Prediction failed for GTF2F1 with error Gene GTF2F1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF3C2 GTF3C2 HESX1 HESX1 HHEX HHEX HMGA2 HMGA2 HMGXB4
# Prediction failed for HMGXB4 with error Gene HMGXB4 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# HMGXB4
# Prediction failed for HMGXB4 with error Gene HMGXB4 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# HNF1A HOPX HOPX HOXA2 HOXA2 HOXA9
# Prediction failed for HOXA9 with error Gene HOXA9 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXA9
# Prediction failed for HOXA9 with error Gene HOXA9 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXB1
# Prediction failed for HOXB1 with error Gene HOXB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXB1
# Prediction failed for HOXB1 with error Gene HOXB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXB3 HOXB3 HOXB4
# Prediction failed for HOXB4 with error Gene HOXB4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXB4
# Prediction failed for HOXB4 with error Gene HOXB4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXD1 HOXD1 HOXD13
# Prediction failed for HOXD13 with error Gene HOXD13 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXD13
# Prediction failed for HOXD13 with error Gene HOXD13 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ID3
# Prediction failed for ID3 with error Gene ID3 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# IKZF1 IKZF1 IRF1 IRF1 IRF3
# Prediction failed for IRF3 with error Gene IRF3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# IRF3
# Prediction failed for IRF3 with error Gene IRF3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# IRF4 IRF4 IRF5 IRF5 ISL2
# Prediction failed for ISL2 with error Gene ISL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ISL2
# Prediction failed for ISL2 with error Gene ISL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# JAG1 JAG1 JARID2
# Prediction failed for JARID2 with error Gene JARID2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# JARID2
# Prediction failed for JARID2 with error Gene JARID2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# JUN JUN JUNB JUNB JUNB KAT8
# Prediction failed for KAT8 with error Gene KAT8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KAT8
# Prediction failed for KAT8 with error Gene KAT8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KDM5A
# Prediction failed for KDM5A with error Gene KDM5A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KDM5A
# Prediction failed for KDM5A with error Gene KDM5A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KDM5B KDM5B KLF1 KLF1 KLF11
# Prediction failed for KLF11 with error Gene KLF11 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KLF11
# Prediction failed for KLF11 with error Gene KLF11 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KLF14
# Prediction failed for KLF14 with error Gene KLF14 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KLF14
# Prediction failed for KLF14 with error Gene KLF14 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KLF15
# Prediction failed for KLF15 with error Gene KLF15 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# KLF15
# Prediction failed for KLF15 with error Gene KLF15 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# LHX1
# Prediction failed for LHX1 with error Gene LHX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHX1
# Prediction failed for LHX1 with error Gene LHX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHX2
# Prediction failed for LHX2 with error Gene LHX2 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# LHX2
# Prediction failed for LHX2 with error Gene LHX2 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# LHX3
# Prediction failed for LHX3 with error Gene LHX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHX3
# Prediction failed for LHX3 with error Gene LHX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHX4
# Prediction failed for LHX4 with error Gene LHX4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHX4
# Prediction failed for LHX4 with error Gene LHX4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LIN28A LIN28A LMO2 LMO2 MAB21L3 MAB21L3 MAFK
# Prediction failed for MAFK with error Gene MAFK is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAFK
# Prediction failed for MAFK with error Gene MAFK is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MEIS1 MEIS1 MNX1
# Prediction failed for MNX1 with error Gene MNX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MNX1
# Prediction failed for MNX1 with error Gene MNX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MSX2 MSX2 MXI1 MXI1 MYB MYB MYBL2 MYBL2 MYC MYC MYF6 MYF6 NANOG NANOG NEUROD1
# Prediction failed for NEUROD1 with error Gene NEUROD1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NEUROD1
# Prediction failed for NEUROD1 with error Gene NEUROD1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NEUROG1 NEUROG1 NEUROG2
# Prediction failed for NEUROG2 with error Gene NEUROG2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NEUROG2
# Prediction failed for NEUROG2 with error Gene NEUROG2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NEUROG3
# Prediction failed for NEUROG3 with error Gene NEUROG3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NEUROG3
# Prediction failed for NEUROG3 with error Gene NEUROG3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NFATC1 NFATC1 NFE2L1 NFIC NFIC NFYB
# Prediction failed for NFYB with error Gene NFYB is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NFYB
# Prediction failed for NFYB with error Gene NFYB is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NKX2-1 NKX2-1 NKX6-3
# Prediction failed for NKX6-3 with error Gene NKX6-3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NKX6-3
# Prediction failed for NKX6-3 with error Gene NKX6-3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NR2C2
# Prediction failed for NR2C2 with error Gene NR2C2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NR2C2
# Prediction failed for NR2C2 with error Gene NR2C2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NR2E1
# Prediction failed for NR2E1 with error Gene NR2E1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NR2E1
# Prediction failed for NR2E1 with error Gene NR2E1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NR2F1
# Prediction failed for NR2F1 with error Gene NR2F1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NR2F1
# Prediction failed for NR2F1 with error Gene NR2F1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NR2F2 NR2F2 NR3C1 NR3C1 NRF1
# Prediction failed for NRF1 with error Gene NRF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NRF1
# Prediction failed for NRF1 with error Gene NRF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NSD2
# Prediction failed for NSD2 with error Gene NSD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NSD2
# Prediction failed for NSD2 with error Gene NSD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OSTF1 OSTF1 OTP
# Prediction failed for OTP with error Gene OTP is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OTP
# Prediction failed for OTP with error Gene OTP is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OTX1
# Prediction failed for OTX1 with error Gene OTX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OTX1
# Prediction failed for OTX1 with error Gene OTX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OTX2 OTX2 PA2G4
# Prediction failed for PA2G4 with error Gene PA2G4 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# PA2G4
# Prediction failed for PA2G4 with error Gene PA2G4 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# PATZ1 PATZ1 PAX2 PAX2 PHOX2B
# Prediction failed for PHOX2B with error Gene PHOX2B is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PHOX2B
# Prediction failed for PHOX2B with error Gene PHOX2B is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PITX3
# Prediction failed for PITX3 with error Gene PITX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PITX3
# Prediction failed for PITX3 with error Gene PITX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PML PML POLR3A
# Prediction failed for POLR3A with error Gene POLR3A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# POLR3A
# Prediction failed for POLR3A with error Gene POLR3A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# POU2AF1 POU2AF1 POU3F2
# Prediction failed for POU3F2 with error Gene POU3F2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# POU3F2
# Prediction failed for POU3F2 with error Gene POU3F2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PPARG PPARG PTF1A
# Prediction failed for PTF1A with error Gene PTF1A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PTF1A
# Prediction failed for PTF1A with error Gene PTF1A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RARA
# Prediction failed for RARA with error Gene RARA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RARA
# Prediction failed for RARA with error Gene RARA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RASL10A RASL10A REPIN1
# Prediction failed for REPIN1 with error Gene REPIN1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# REPIN1
# Prediction failed for REPIN1 with error Gene REPIN1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# REST
# Prediction failed for REST with error Gene REST is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# REST
# Prediction failed for REST with error Gene REST is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RFX2 RFX2 RFXAP RFXAP RNF2
# Prediction failed for RNF2 with error Gene RNF2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RNF2
# Prediction failed for RNF2 with error Gene RNF2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RREB1
# Prediction failed for RREB1 with error Gene RREB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RREB1
# Prediction failed for RREB1 with error Gene RREB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RUNX1 RUNX1 RUNX3 RUNX3 RUVBL2 RUVBL2 SAP30 SIM1 SIM1 SIN3A
# Prediction failed for SIN3A with error Gene SIN3A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SIN3A
# Prediction failed for SIN3A with error Gene SIN3A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SIRT3 SIRT3 SIRT6
# Prediction failed for SIRT6 with error Gene SIRT6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SIRT6
# Prediction failed for SIRT6 with error Gene SIRT6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SMAD2 SMAD2 SMAD3
# Prediction failed for SMAD3 with error Gene SMAD3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SMAD3
# Prediction failed for SMAD3 with error Gene SMAD3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SMAD4
# Prediction failed for SMAD4 with error Gene SMAD4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SMAD4
# Prediction failed for SMAD4 with error Gene SMAD4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SMARCA4 SMARCA4 SMARCB1
# Prediction failed for SMARCB1 with error Gene SMARCB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SMARCB1
# Prediction failed for SMARCB1 with error Gene SMARCB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SMC3
# Prediction failed for SMC3 with error Gene SMC3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SMC3
# Prediction failed for SMC3 with error Gene SMC3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SNAI1
# Prediction failed for SNAI1 with error Gene SNAI1 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# SNAI1
# Prediction failed for SNAI1 with error Gene SNAI1 does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# SNAI2 SNAI2 SNAI3 SNAI3 SOX10
# Prediction failed for SOX10 with error Gene SOX10 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SOX10
# Prediction failed for SOX10 with error Gene SOX10 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SOX15
# Prediction failed for SOX15 with error Gene SOX15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SOX15
# Prediction failed for SOX15 with error Gene SOX15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SOX17 SOX17 SOX7 SOX7 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 STAG1
# Prediction failed for STAG1 with error Gene STAG1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# STAG1
# Prediction failed for STAG1 with error Gene STAG1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# STAT3
# Prediction failed for STAT3 with error Gene STAT3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# STAT3
# Prediction failed for STAT3 with error Gene STAT3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SUB1 SUB1 SUZ12
# Prediction failed for SUZ12 with error Gene SUZ12 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SUZ12
# Prediction failed for SUZ12 with error Gene SUZ12 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TBX6
# Prediction failed for TBX6 with error Gene TBX6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TBX6
# Prediction failed for TBX6 with error Gene TBX6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TCF12
# Prediction failed for TCF12 with error Gene TCF12 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TCF12
# Prediction failed for TCF12 with error Gene TCF12 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TCF23
# Prediction failed for TCF23 with error Gene TCF23 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TCF23
# Prediction failed for TCF23 with error Gene TCF23 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TCF4 TCF4 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2C TFAP2C TFCP2L1 TFCP2L1 TGIF1
# Prediction failed for TGIF1 with error Gene TGIF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TGIF1
# Prediction failed for TGIF1 with error Gene TGIF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TGM2 TGM2 THAP1
# Prediction failed for THAP1 with error Gene THAP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP1
# Prediction failed for THAP1 with error Gene THAP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP11
# Prediction failed for THAP11 with error Gene THAP11 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP11
# Prediction failed for THAP11 with error Gene THAP11 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP3
# Prediction failed for THAP3 with error Gene THAP3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP3
# Prediction failed for THAP3 with error Gene THAP3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TP73
# Prediction failed for TP73 with error Gene TP73 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TWIST2 TWIST2 UBTF
# Prediction failed for UBTF with error Gene UBTF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# UBTF
# Prediction failed for UBTF with error Gene UBTF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# VAX1
# Prediction failed for VAX1 with error Gene VAX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# VAX1
# Prediction failed for VAX1 with error Gene VAX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# VDR VDR VPS72
# Prediction failed for VPS72 with error Gene VPS72 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# VPS72
# Prediction failed for VPS72 with error Gene VPS72 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# WNT3A
# Prediction failed for WNT3A with error Gene WNT3A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# WNT3A
# Prediction failed for WNT3A with error Gene WNT3A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# WT1 WT1 YY1
# Prediction failed for YY1 with error Gene YY1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# YY1
# Prediction failed for YY1 with error Gene YY1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBTB3
# Prediction failed for ZBTB3 with error Gene ZBTB3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBTB3
# Prediction failed for ZBTB3 with error Gene ZBTB3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBTB7A
# Prediction failed for ZBTB7A with error Gene ZBTB7A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZFP57
# Prediction failed for ZFP57 with error Gene ZFP57 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZFP57
# Prediction failed for ZFP57 with error Gene ZFP57 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZIC1 ZIC1 ZKSCAN1
# Prediction failed for ZKSCAN1 with error Gene ZKSCAN1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZKSCAN1
# Prediction failed for ZKSCAN1 with error Gene ZKSCAN1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZMAT4 ZMAT4 ZMYND12 ZMYND12 ZNF217
# Prediction failed for ZNF217 with error Gene ZNF217 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF263
# Prediction failed for ZNF263 with error Gene ZNF263 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF263
# Prediction failed for ZNF263 with error Gene ZNF263 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF281
# Prediction failed for ZNF281 with error Gene ZNF281 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF281
# Prediction failed for ZNF281 with error Gene ZNF281 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF426
# Prediction failed for ZNF426 with error Gene ZNF426 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF426
# Prediction failed for ZNF426 with error Gene ZNF426 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF646
# Prediction failed for ZNF646 with error Gene ZNF646 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF646
# Prediction failed for ZNF646 with error Gene ZNF646 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF713
# Prediction failed for ZNF713 with error Gene ZNF713 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF713
# Prediction failed for ZNF713 with error Gene ZNF713 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ALX1
# Prediction failed for ALX1 with error Gene ALX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ALX1
# Prediction failed for ALX1 with error Gene ALX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ARID3B ARID3B ATF4
# Prediction failed for ATF4 with error Gene ATF4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF4
# Prediction failed for ATF4 with error Gene ATF4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BMI1
# Prediction failed for BMI1 with error Gene BMI1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BMI1
# Prediction failed for BMI1 with error Gene BMI1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BMP7 BMP7 BRF1
# Prediction failed for BRF1 with error Gene BRF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BRF1
# Prediction failed for BRF1 with error Gene BRF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CBFB
# Prediction failed for CBFB with error Gene CBFB does not have enough regulatory connection in the GRNs. Cannot perform simulation.
# CTBP1
# Prediction failed for CTBP1 with error Gene CTBP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTBP1
# Prediction failed for CTBP1 with error Gene CTBP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CXXC5 CXXC5 DBX1
# Prediction failed for DBX1 with error Gene DBX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DBX1
# Prediction failed for DBX1 with error Gene DBX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DBX2
# Prediction failed for DBX2 with error Gene DBX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DBX2
# Prediction failed for DBX2 with error Gene DBX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# E2F5 E2F5 ETV4 ETV4 FOSB FOSB HES6 HES6 HMGA1 HMGA1 HOXA1 HOXA1 IKZF5
# Prediction failed for IKZF5 with error Gene IKZF5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# IKZF5
# Prediction failed for IKZF5 with error Gene IKZF5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KLF6 KLF6 LBX2
# Prediction failed for LBX2 with error Gene LBX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LBX2
# Prediction failed for LBX2 with error Gene LBX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MLLT1
# Prediction failed for MLLT1 with error Gene MLLT1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MLLT1
# Prediction failed for MLLT1 with error Gene MLLT1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MXD3
# ...
# ZKSCAN1
# Prediction failed for ZKSCAN1 with error Gene ZKSCAN1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZKSCAN1
# Prediction failed for ZKSCAN1 with error Gene ZKSCAN1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZMAT4
# Prediction failed for ZMAT4 with error Gene ZMAT4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZMAT4
# Prediction failed for ZMAT4 with error Gene ZMAT4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZMYND12
# Prediction failed for ZMYND12 with error Gene ZMYND12 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZMYND12
# Prediction failed for ZMYND12 with error Gene ZMYND12 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF217
# Prediction failed for ZNF217 with error Gene ZNF217 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF263
# Prediction failed for ZNF263 with error Gene ZNF263 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF263
# Prediction failed for ZNF263 with error Gene ZNF263 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF281
# Prediction failed for ZNF281 with error Gene ZNF281 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF281
# Prediction failed for ZNF281 with error Gene ZNF281 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF426
# Prediction failed for ZNF426 with error Gene ZNF426 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF426
# Prediction failed for ZNF426 with error Gene ZNF426 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF646
# Prediction failed for ZNF646 with error Gene ZNF646 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF646
# Prediction failed for ZNF646 with error Gene ZNF646 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF713
# Prediction failed for ZNF713 with error Gene ZNF713 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF713
# Prediction failed for ZNF713 with error Gene ZNF713 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ALX1
# Prediction failed for ALX1 with error Gene ALX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ALX1
# Prediction failed for ALX1 with error Gene ALX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ARID3B
# Prediction failed for ARID3B with error Gene ARID3B is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ARID3B
# Prediction failed for ARID3B with error Gene ARID3B is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF4
# Prediction failed for ATF4 with error Gene ATF4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF4
# Prediction failed for ATF4 with error Gene ATF4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BMI1
# Prediction failed for BMI1 with error Gene BMI1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BMI1
# Prediction failed for BMI1 with error Gene BMI1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BMP7 BMP7 BRF1
# Prediction failed for BRF1 with error Gene BRF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BRF1
# Prediction failed for BRF1 with error Gene BRF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CBFB
# Prediction failed for CBFB with error Gene CBFB is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTBP1
# Prediction failed for CTBP1 with error Gene CTBP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTBP1
# Prediction failed for CTBP1 with error Gene CTBP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CXXC5
# Prediction failed for CXXC5 with error Gene CXXC5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CXXC5
# Prediction failed for CXXC5 with error Gene CXXC5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DBX1
# Prediction failed for DBX1 with error Gene DBX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DBX1
# Prediction failed for DBX1 with error Gene DBX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DBX2
# Prediction failed for DBX2 with error Gene DBX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DBX2
# Prediction failed for DBX2 with error Gene DBX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# E2F5
# Prediction failed for E2F5 with error Gene E2F5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# E2F5
# Prediction failed for E2F5 with error Gene E2F5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ETV4
# Prediction failed for ETV4 with error Gene ETV4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ETV4
# Prediction failed for ETV4 with error Gene ETV4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOSB
# Prediction failed for FOSB with error Gene FOSB is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOSB
# Prediction failed for FOSB with error Gene FOSB is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HES6
# Prediction failed for HES6 with error Gene HES6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HES6
# Prediction failed for HES6 with error Gene HES6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGA1
# Prediction failed for HMGA1 with error Gene HMGA1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGA1
# Prediction failed for HMGA1 with error Gene HMGA1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXA1
# Prediction failed for HOXA1 with error Gene HOXA1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXA1
# Prediction failed for HOXA1 with error Gene HOXA1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# IKZF5
# Prediction failed for IKZF5 with error Gene IKZF5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# IKZF5
# Prediction failed for IKZF5 with error Gene IKZF5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KLF6
# Prediction failed for KLF6 with error Gene KLF6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# KLF6
# Prediction failed for KLF6 with error Gene KLF6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LBX2
# Prediction failed for LBX2 with error Gene LBX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LBX2
# Prediction failed for LBX2 with error Gene LBX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MLLT1
# Prediction failed for MLLT1 with error Gene MLLT1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MLLT1
# Prediction failed for MLLT1 with error Gene MLLT1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MXD3
# Prediction failed for MXD3 with error Gene MXD3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MXD3
# Prediction failed for MXD3 with error Gene MXD3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NFIA
# Prediction failed for NFIA with error Gene NFIA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NFIA
# Prediction failed for NFIA with error Gene NFIA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NR1H2
# Prediction failed for NR1H2 with error Gene NR1H2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NR1H2
# Prediction failed for NR1H2 with error Gene NR1H2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OSR1
# Prediction failed for OSR1 with error Gene OSR1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OSR1
# Prediction failed for OSR1 with error Gene OSR1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PGF
# Prediction failed for PGF with error Gene PGF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PGF
# Prediction failed for PGF with error Gene PGF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PRICKLE1
# Prediction failed for PRICKLE1 with error Gene PRICKLE1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SATB1
# Prediction failed for SATB1 with error Gene SATB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SATB1
# Prediction failed for SATB1 with error Gene SATB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TCF15
# Prediction failed for TCF15 with error Gene TCF15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TCF15
# Prediction failed for TCF15 with error Gene TCF15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TEAD2
# Prediction failed for TEAD2 with error Gene TEAD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TEAD2
# Prediction failed for TEAD2 with error Gene TEAD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TEF
# Prediction failed for TEF with error Gene TEF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TEF
# Prediction failed for TEF with error Gene TEF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THRA
# Prediction failed for THRA with error Gene THRA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THRA
# Prediction failed for THRA with error Gene THRA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TNF
# Prediction failed for TNF with error Gene TNF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TNF
# Prediction failed for TNF with error Gene TNF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# VAX2
# Prediction failed for VAX2 with error Gene VAX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# VAX2
# Prediction failed for VAX2 with error Gene VAX2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBTB44
# Prediction failed for ZBTB44 with error Gene ZBTB44 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBTB44
# Prediction failed for ZBTB44 with error Gene ZBTB44 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZMAT5
# Prediction failed for ZMAT5 with error Gene ZMAT5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZMAT5
# Prediction failed for ZMAT5 with error Gene ZMAT5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF384
# Prediction failed for ZNF384 with error Gene ZNF384 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF384
# Prediction failed for ZNF384 with error Gene ZNF384 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF384
# Prediction failed for ZNF384 with error Gene ZNF384 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF384
# Prediction failed for ZNF384 with error Gene ZNF384 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF480
# Prediction failed for ZNF480 with error Gene ZNF480 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF480
# Prediction failed for ZNF480 with error Gene ZNF480 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZSCAN5A
# Prediction failed for ZSCAN5A with error Gene ZSCAN5A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZSCAN5A
# Prediction failed for ZSCAN5A with error Gene ZSCAN5A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.

# %%
predictions[0]
# Out:
# {'ALX3': ArrayView([0.31787362, 0.26555526, 0.35006813, ..., 0.51548357,
#             0.28077881, 1.07324214]),
#  'ARNT2': ArrayView([0.28353897, 0.23874468, 0.34349491, ..., 0.48157308,
#             0.27320929, 1.06515696]),
#  'ASCL2': ArrayView([0.31501106, 0.25897231, 0.35430694, ..., 0.51224682,
#             0.28061757, 1.07027102]),
#  'ATF1': ArrayView([0.32699184, 0.26490541, 0.36917727, ..., 0.51563047,
#             0.30010019, 1.05956319]),
#  'ATF3': ArrayView([0.32233458, 0.30263167, 0.4172652 , ..., 0.48242717,
#             0.2569705 , 1.05574006]),
#  'BARX2': ArrayView([0.31759715, 0.25692903, 0.35002558, ..., 0.50957034,
#             0.27853291, 1.0681604 ]),
#  'BATF': ArrayView([0.32323168, 0.27152519, 0.34749868, ..., 0.51044779,
#             0.28141901, 1.07286587]),
#  'BCL6': ArrayView([0.32902557, 0.27999627, 0.31781784, ..., 0.49561525,
#             0.31394969, 1.09176238]),
#  'BLZF1': ArrayView([0.31925196, 0.25728144, 0.36228182, ..., 0.50340472,
#             0.27705853, 1.07601619]),
#  'BMP4': ArrayView([0.54312023, 0.55977773, 0.31767417, ..., 0.50195193,
#             0.21296952, 1.03556831]),
#  'BRF2': ArrayView([0.31551188, 0.2518848 , 0.40245389, ..., 0.50360465,
#             0.2862719 , 1.02736778]),
#  'CCNE1': nan,
#  'CDYL': nan,
#  'CEBPA': ArrayView([0.29731927, 0.24913565, 0.34226384, ..., 0.46335017,
#             0.28025053, 1.05955387]),
#  'CEBPB': ArrayView([0.33827981, 0.29861393, 0.38686643, ..., 0.54914473,
#             0.27137182, 1.05445077]),
#  'CEBPD': ArrayView([0.3129111 , 0.2587471 , 0.350289  , ..., 0.50726395,
#             0.2811313 , 1.06749355]),
#  'CENPX': ArrayView([0.30948356, 0.25618012, 0.3513269 , ..., 0.53484847,
#             0.28096415, 1.08240998]),
#  'CERS2': ArrayView([0.28120015, 0.22522329, 0.2665051 , ..., 0.47770048,
#             0.31567933, 1.08522265]),
#  'CHD4': ArrayView([0.23781771, 0.22488349, 0.3373136 , ..., 0.53898658,
#             0.27910575, 1.06282797]),
#  'CREB1': ArrayView([0.31175308, 0.23124221, 0.33023273, ..., 0.50664211,
#             0.30193688, 1.0879361 ]),
#  'CRY1': nan,
#  'CRY2': nan,
#  'CTBP2': ArrayView([0.3118391 , 0.25012632, 0.34512666, ..., 0.5062182 ,
#             0.3081849 , 1.05802904]),
#  'CUX1': ArrayView([0.29840931, 0.24871003, 0.32697983, ..., 0.51007278,
#             0.28583322, 1.08375891]),
#  'DEDD2': nan,
#  'DVL2': ArrayView([0.29023507, 0.23279529, 0.30376283, ..., 0.45842223,
#             0.25988627, 1.08144303]),
#  'E2F4': ArrayView([0.3229715 , 0.25963119, 0.3762262 , ..., 0.52362159,
#             0.28973735, 1.06979309]),
#  'E2F6': ArrayView([0.31658926, 0.26312688, 0.35701713, ..., 0.5224186 ,
#             0.28010068, 1.0723783 ]),
#  'EBF1': ArrayView([0.31503044, 0.25819911, 0.35146661, ..., 0.51125656,
#             0.28082771, 1.07062862]),
#  'EHF': ArrayView([0.30764216, 0.25503465, 0.36123491, ..., 0.49651212,
#             0.27273288, 1.06191365]),
#  'ELF1': ArrayView([0.31883366, 0.30710727, 0.40481795, ..., 0.50131754,
#             0.25746357, 1.02371302]),
#  'ELF5': ArrayView([0.32644492, 0.27819255, 0.33749268, ..., 0.51162748,
#             0.27822487, 1.07451447]),
#  'ELK3': ArrayView([0.30048377, 0.20912331, 0.35172598, ..., 0.45558814,
#             0.26523904, 1.02814837]),
#  'ELL2': nan,
#  'EN1': ArrayView([0.32894119, 0.27121832, 0.3336458 , ..., 0.50790625,
#             0.27843654, 1.0794881 ]),
#  'EOMES': ArrayView([0.3660515 , 0.26843166, 0.36534499, ..., 0.47667527,
#             0.27470278, 1.02928206]),
#  'ESRRA': ArrayView([0.34674433, 0.28297846, 0.36784101, ..., 0.57217897,
#             0.26903073, 1.07781617]),
#  'ESRRB': ArrayView([0.30852368, 0.25296651, 0.34921145, ..., 0.4949023 ,
#             0.27165859, 1.07371678]),
#  'ESRRG': ArrayView([0.3070526 , 0.2512592 , 0.3594025 , ..., 0.50609742,
#             0.2816482 , 1.06233888]),
#  'ESX1': ArrayView([0.31253117, 0.25404667, 0.34937574, ..., 0.50445782,
#             0.28159723, 1.06291312]),
#  'ETS1': ArrayView([0.38364773, 0.27004265, 0.33292517, ..., 0.49697231,
#             0.34282669, 1.05979622]),
#  'ETS2': ArrayView([0.35135103, 0.22558144, 0.39867396, ..., 0.4827869 ,
#             0.32667514, 1.01171542]),
#  'ETV1': ArrayView([0.35041085, 0.23192472, 0.36270357, ..., 0.51900747,
#             0.30886786, 1.04008301]),
#  'ETV3': ArrayView([0.33991087, 0.27800213, 0.37794781, ..., 0.50136585,
#             0.28261314, 1.05315358]),
#  'ETV5': ArrayView([0.30980126, 0.25697984, 0.35269358, ..., 0.50865358,
#             0.28118464, 1.07032808]),
#  'FEV': ArrayView([0.31458339, 0.25848369, 0.35167315, ..., 0.5110272 ,
#             0.28105899, 1.07114024]),
#  'FIGLA': ArrayView([0.31361712, 0.25582034, 0.35031836, ..., 0.50966767,
#             0.28071252, 1.07196539]),
#  'FLI1': ArrayView([0.36922614, 0.29784456, 0.33100551, ..., 0.49348559,
#             0.28543203, 1.02343378]),
#  'FOSL1': ArrayView([0.31549163, 0.2733632 , 0.39402077, ..., 0.50148718,
#             0.25632692, 1.074677  ]),
#  'FOXA1': ArrayView([0.29898002, 0.24196518, 0.35766979, ..., 0.50988984,
#             0.27458262, 1.03991212]),
#  'FOXA2': ArrayView([0.31760324, 0.21274689, 0.34517731, ..., 0.46436678,
#             0.27331656, 1.06807293]),
#  'FOXB1': ArrayView([0.31200407, 0.25403472, 0.33860949, ..., 0.49865569,
#             0.29095256, 1.02834105]),
#  'FOXC1': ArrayView([0.36242089, 0.31389718, 0.33674412, ..., 0.52605906,
#             0.29007738, 1.04877941]),
#  'FOXD1': ArrayView([0.31466611, 0.25875268, 0.3519356 , ..., 0.51064445,
#             0.28071515, 1.07044586]),
#  'FOXD4L3': ArrayView([0.3147153 , 0.25818682, 0.35188398, ..., 0.51114722,
#             0.28109052, 1.07120615]),
#  'FOXE3': ArrayView([0.31461544, 0.25811085, 0.35105487, ..., 0.51022661,
#             0.28122824, 1.07117686]),
#  'FOXJ1': ArrayView([0.24854038, 0.14799944, 0.30882911, ..., 0.44587905,
#             0.27160232, 1.07212497]),
#  'FOXM1': ArrayView([0.32141664, 0.28004501, 0.32768675, ..., 0.53022312,
#             0.27866965, 1.07599293]),
#  'FOXN3': ArrayView([0.31819785, 0.25615477, 0.34452681, ..., 0.51775831,
#             0.2903598 , 1.0746486 ]),
#  'FOXO3': ArrayView([0.30594783, 0.25813731, 0.34738186, ..., 0.5044226 ,
#             0.27649928, 1.06119973]),
#  'FOXP3': ArrayView([0.31555937, 0.2599001 , 0.3533691 , ..., 0.5105391 ,
#             0.28014628, 1.0688409 ]),
#  'GATA6': ArrayView([0.36336957, 0.29994839, 0.35343917, ..., 0.50727163,
#             0.28349496, 1.04345182]),
#  'GLI1': ArrayView([0.32115579, 0.27056532, 0.38021807, ..., 0.54215483,
#             0.2855549 , 1.05699666]),
#  'GRHL2': ArrayView([0.31651202, 0.26164929, 0.33829247, ..., 0.50357007,
#             0.28040114, 1.07763542]),
#  'GSC': ArrayView([0.31314883, 0.24688029, 0.35526495, ..., 0.50638663,
#             0.26947457, 1.0636958 ]),
#  'GTF2F1': ArrayView([0.31112438, 0.25368264, 0.36874457, ..., 0.49761912,
#             0.27531746, 1.05570362]),
#  'GTF3C2': ArrayView([0.29197519, 0.24295367, 0.35070908, ..., 0.52673567,
#             0.28531258, 1.07249384]),
#  'HESX1': ArrayView([0.31557387, 0.24827702, 0.36911988, ..., 0.52450048,
#             0.27158218, 1.06442098]),
#  'HHEX': ArrayView([0.31931051, 0.25996214, 0.35041073, ..., 0.51111214,
#             0.28145463, 1.06910217]),
#  'HMGA2': ArrayView([0.35577852, 0.25001801, 0.31812055, ..., 0.56350596,
#             0.26914291, 1.06659456]),
#  'HMGXB4': ArrayView([0.31385234, 0.2342836 , 0.29905082, ..., 0.53002075,
#             0.30715412, 1.12391497]),
#  'HNF1A': ArrayView([0.31523782, 0.25948297, 0.35132327, ..., 0.51131637,
#             0.28109717, 1.07123443]),
#  'HOPX': ArrayView([0.31420133, 0.25814683, 0.35193945, ..., 0.51087145,
#             0.28034383, 1.06924455]),
#  'HOXA2': ArrayView([0.31514253, 0.25834866, 0.35174745, ..., 0.51071331,
#             0.28161458, 1.06952965]),
#  'HOXA9': ArrayView([0.32332574, 0.2670617 , 0.35065343, ..., 0.51222004,
#             0.2811631 , 1.06877747]),
#  'HOXB1': ArrayView([0.31642692, 0.25891319, 0.35151611, ..., 0.51036031,
#             0.28031217, 1.07208877]),
#  'HOXB3': ArrayView([0.3140484 , 0.25979452, 0.35685915, ..., 0.5087631 ,
#             0.28153222, 1.06132154]),
#  'HOXB4': ArrayView([0.31476342, 0.2587137 , 0.3518334 , ..., 0.51089469,
#             0.28127038, 1.07055354]),
#  'HOXD1': ArrayView([0.30793182, 0.25630472, 0.35439816, ..., 0.50053888,
#             0.28389163, 1.06965609]),
#  'HOXD13': ArrayView([0.322652  , 0.26461995, 0.35643373, ..., 0.51691118,
#             0.27449404, 1.06762263]),
#  'ID3': ArrayView([0.32856057, 0.31170915, 0.33199291, ..., 0.45000693,
#             0.24178202, 1.07852573]),
#  'IKZF1': ArrayView([0.3062796 , 0.24842324, 0.35646595, ..., 0.51141991,
#             0.27540453, 1.07078567]),
#  'IRF1': ArrayView([0.32254329, 0.27542033, 0.34585312, ..., 0.51577002,
#             0.2790866 , 1.07435499]),
#  'IRF3': ArrayView([0.28681263, 0.25102858, 0.34025943, ..., 0.52798838,
#             0.27692105, 1.09210919]),
#  'IRF4': ArrayView([0.31018689, 0.27345981, 0.37805671, ..., 0.48987044,
#             0.2760347 , 1.03314764]),
#  'IRF5': ArrayView([0.31269209, 0.26054152, 0.3532338 , ..., 0.51321429,
#             0.27929304, 1.07143852]),
#  'ISL2': ArrayView([0.31658991, 0.26205018, 0.35639143, ..., 0.50478958,
#             0.28160611, 1.06279312]),
#  'JAG1': nan,
#  'JARID2': ArrayView([0.3279472 , 0.23302467, 0.37519608, ..., 0.51656935,
#             0.32059711, 1.07756849]),
#  'JUN': ArrayView([0.33587045, 0.27352681, 0.38193854, ..., 0.46045104,
#             0.25533533, 1.06806064]),
#  'JUNB': ArrayView([0.34990413, 0.30390457, 0.46264318, ..., 0.54513917,
#             0.25176682, 1.02298092]),
#  'KAT8': ArrayView([0.30290827, 0.24686487, 0.28699953, ..., 0.55677944,
#             0.30159549, 1.14906715]),
#  'KDM5A': ArrayView([0.30078028, 0.23792895, 0.36526781, ..., 0.4745816 ,
#             0.27961311, 1.04796237]),
#  'KDM5B': ArrayView([0.24111162, 0.2185846 , 0.34388904, ..., 0.49935047,
#             0.27873138, 1.06849279]),
#  'KLF1': ArrayView([0.31674098, 0.25980881, 0.35378465, ..., 0.51250614,
#             0.27970159, 1.0661039 ]),
#  'KLF11': ArrayView([0.32934183, 0.27042082, 0.35124369, ..., 0.52572185,
#             0.27571192, 1.05266057]),
#  'KLF14': ArrayView([0.31457092, 0.25835727, 0.35190833, ..., 0.51077462,
#             0.28108964, 1.0710922 ]),
#  'KLF15': ArrayView([0.30351911, 0.26005693, 0.32495501, ..., 0.49918078,
#             0.28335395, 1.09480053]),
#  'LHX1': ArrayView([0.31280462, 0.27393003, 0.35659649, ..., 0.51269357,
#             0.27727541, 1.05262031]),
#  'LHX2': ArrayView([0.32181591, 0.25890722, 0.34955039, ..., 0.50561244,
#             0.27771941, 1.060666  ]),
#  'LHX3': ArrayView([0.31403734, 0.2584753 , 0.352729  , ..., 0.51105589,
#             0.28072581, 1.07095336]),
#  'LHX4': ArrayView([0.33593737, 0.24855761, 0.34197139, ..., 0.57668587,
#             0.33540047, 1.0710225 ]),
#  'LIN28A': ArrayView([0.31630314, 0.24627133, 0.35139913, ..., 0.5296141 ,
#             0.27175417, 1.10346404]),
#  'LMO2': ArrayView([0.32135354, 0.26017462, 0.3487565 , ..., 0.50493646,
#             0.28060532, 1.05606782]),
#  'MAB21L3': nan,
#  'MAFK': ArrayView([0.30759708, 0.25914885, 0.35649751, ..., 0.51599403,
#             0.27919667, 1.07009251]),
#  'MEIS1': ArrayView([0.33424282, 0.282473  , 0.35577931, ..., 0.50926556,
#             0.276007  , 1.06582715]),
#  'MNX1': ArrayView([0.30977849, 0.2516663 , 0.34759199, ..., 0.5037157 ,
#             0.28731755, 1.06351601]),
#  'MSX2': ArrayView([0.35790366, 0.29326533, 0.38272866, ..., 0.55186208,
#             0.23122198, 1.0723474 ]),
#  'MXI1': ArrayView([0.31434702, 0.26732911, 0.32936754, ..., 0.49370545,
#             0.27828063, 1.04895173]),
#  'MYB': ArrayView([0.30641801, 0.20870708, 0.31117409, ..., 0.53679657,
#             0.30148228, 1.11798852]),
#  'MYBL2': ArrayView([0.2561008 , 0.20122626, 0.39584544, ..., 0.54082745,
#             0.258078  , 1.03400687]),
#  'MYC': ArrayView([0.39413709, 0.31684228, 0.35591169, ..., 0.53739486,
#             0.32215836, 1.14285005]),
#  'MYF6': ArrayView([0.28885439, 0.22829814, 0.33773206, ..., 0.49745384,
#             0.27898926, 1.06820206]),
#  'NANOG': ArrayView([0.42111089, 0.25660807, 0.34538682, ..., 0.62005546,
#             0.34721015, 1.14809105]),
#  'NEUROD1': ArrayView([0.31362022, 0.25649005, 0.35315472, ..., 0.51273052,
#             0.27959393, 1.0758971 ]),
#  'NEUROG1': ArrayView([0.31242547, 0.25632784, 0.34851303, ..., 0.51312386,
#             0.27906802, 1.07408076]),
#  'NEUROG2': ArrayView([0.31599424, 0.26021192, 0.35414502, ..., 0.50701208,
#             0.27901706, 1.06799516]),
#  'NEUROG3': ArrayView([0.33190893, 0.27203927, 0.34630893, ..., 0.50181301,
#             0.28175749, 1.05594132]),
#  'NFATC1': ArrayView([0.31072297, 0.28110296, 0.36129684, ..., 0.56859871,
#             0.28499885, 1.05027759]),
#  'NFE2L1': ArrayView([0.33159451, 0.3022515 , 0.34627674, ..., 0.53286871,
#             0.29387705, 1.03809779]),
#  'NFIC': ArrayView([0.31219653, 0.25697739, 0.34559382, ..., 0.51375764,
#             0.27984962, 1.07304451]),
#  'NFYB': ArrayView([0.31529348, 0.25198676, 0.34681934, ..., 0.51352217,
#             0.28915723, 1.07699464]),
#  'NKX2-1': ArrayView([0.3130301 , 0.25951352, 0.35175128, ..., 0.51154623,
#             0.28011619, 1.07152559]),
#  'NKX6-3': ArrayView([0.31436471, 0.25739374, 0.35225896, ..., 0.51125957,
#             0.2811554 , 1.07132641]),
#  'NR2C2': ArrayView([0.31249505, 0.2559439 , 0.3508495 , ..., 0.50917465,
#             0.28128521, 1.0710815 ]),
#  'NR2E1': ArrayView([0.31669057, 0.25936015, 0.35386765, ..., 0.50756374,
#             0.27944484, 1.06654259]),
#  'NR2F1': ArrayView([0.31460358, 0.26146517, 0.3499217 , ..., 0.51231756,
#             0.28045532, 1.07057055]),
#  'NR2F2': ArrayView([0.32395274, 0.28133174, 0.35000369, ..., 0.50822936,
#             0.28403492, 1.04872821]),
#  'NR3C1': ArrayView([0.32085934, 0.26012779, 0.35533772, ..., 0.51275991,
#             0.28058557, 1.07005098]),
#  'NRF1': ArrayView([0.32150674, 0.25843089, 0.34534741, ..., 0.52083473,
#             0.29183111, 1.06579686]),
#  'NSD2': ArrayView([0.28654334, 0.23843582, 0.28676131, ..., 0.49336219,
#             0.28855526, 1.06503765]),
#  'OSTF1': nan,
#  'OTP': ArrayView([0.3152852 , 0.25814046, 0.3545071 , ..., 0.50887283,
#             0.27922194, 1.06753786]),
#  'OTX1': ArrayView([0.32036472, 0.26271378, 0.35150501, ..., 0.50709574,
#             0.27900006, 1.06456102]),
#  'OTX2': ArrayView([0.32754992, 0.21731659, 0.35636673, ..., 0.48390653,
#             0.28156773, 1.04215678]),
#  'PA2G4': ArrayView([0.331182  , 0.25983015, 0.35700964, ..., 0.54235011,
#             0.28519079, 1.10507218]),
#  'PATZ1': ArrayView([0.27714151, 0.13594709, 0.29177243, ..., 0.44277237,
#             0.30733727, 1.07776002]),
#  'PAX2': ArrayView([0.31957503, 0.26447582, 0.34943508, ..., 0.51757856,
#             0.280144  , 1.06635614]),
#  'PHOX2B': ArrayView([0.30080622, 0.24504135, 0.36331545, ..., 0.50744614,
#             0.27947389, 1.06886208]),
#  'PITX3': ArrayView([0.30613856, 0.24316073, 0.36325327, ..., 0.52221257,
#             0.28970307, 1.05985767]),
#  'PML': ArrayView([0.3155467 , 0.25621206, 0.33855484, ..., 0.51278928,
#             0.28470533, 1.06891511]),
#  'POLR3A': ArrayView([0.30193275, 0.23130946, 0.37392143, ..., 0.4866563 ,
#             0.28321986, 1.07386116]),
#  'POU2AF1': ArrayView([0.31459969, 0.25849797, 0.3517689 , ..., 0.51097312,
#             0.28109722, 1.07113869]),
#  'POU3F2': ArrayView([0.31258865, 0.25560311, 0.35182488, ..., 0.51067827,
#             0.28044478, 1.07061533]),
#  'PPARG': ArrayView([0.36526438, 0.33482051, 0.31956095, ..., 0.4867545 ,
#             0.28238002, 1.06645566]),
#  'PTF1A': ArrayView([0.35018433, 0.29310709, 0.35525862, ..., 0.5233069 ,
#             0.2772606 , 1.05906694]),
#  'RARA': ArrayView([0.31954034, 0.25943308, 0.36295607, ..., 0.51839587,
#             0.2779558 , 1.07118156]),
#  'RASL10A': nan,
#  'REPIN1': ArrayView([0.29451441, 0.24190559, 0.31216797, ..., 0.52549048,
#             0.29409899, 1.09148678]),
#  'REST': ArrayView([0.31574598, 0.24900137, 0.35813207, ..., 0.49666971,
#             0.28565617, 1.05353433]),
#  'RFX2': ArrayView([0.30723778, 0.25252549, 0.34381267, ..., 0.50446598,
#             0.28302815, 1.06968318]),
#  'RFXAP': ArrayView([0.31415668, 0.25511564, 0.34126485, ..., 0.51294904,
#             0.28542892, 1.08106672]),
#  'RNF2': ArrayView([0.31921544, 0.25965211, 0.34794283, ..., 0.49767254,
#             0.2863404 , 1.07351825]),
#  'RREB1': ArrayView([0.31844485, 0.27270918, 0.36873431, ..., 0.49785895,
#             0.26597435, 1.02737744]),
#  'RUNX1': ArrayView([0.32924302, 0.27495573, 0.34285245, ..., 0.49886627,
#             0.28634369, 1.06606016]),
#  'RUNX3': ArrayView([0.34371129, 0.28126493, 0.35722738, ..., 0.51624523,
#             0.28279899, 1.05974594]),
#  'RUVBL2': nan,
#  'SAP30': nan,
#  'SIM1': ArrayView([0.31464072, 0.25854884, 0.35187172, ..., 0.51077316,
#             0.28107855, 1.07103516]),
#  'SIN3A': ArrayView([0.30249436, 0.25744267, 0.32719331, ..., 0.52382705,
#             0.28781806, 1.08222932]),
#  'SIRT3': ArrayView([0.30454651, 0.24943304, 0.31316999, ..., 0.5230945 ,
#             0.28430707, 1.095816  ]),
#  'SIRT6': ArrayView([0.31512282, 0.25408157, 0.37908575, ..., 0.54920188,
#             0.26943181, 1.07905677]),
#  'SMAD2': ArrayView([0.31589163, 0.25960852, 0.34909444, ..., 0.51163384,
#             0.28237561, 1.07067661]),
#  'SMAD3': ArrayView([0.31754962, 0.27111766, 0.32341065, ..., 0.51517223,
#             0.27971194, 1.06332404]),
#  'SMAD4': ArrayView([0.31268044, 0.25692692, 0.34405758, ..., 0.52067626,
#             0.28574967, 1.07551705]),
#  'SMARCA4': ArrayView([0.29919121, 0.23367983, 0.3395196 , ..., 0.50275375,
#             0.2864951 , 1.06574571]),
#  'SMARCB1': ArrayView([0.28457195, 0.23429194, 0.29924968, ..., 0.52235179,
#             0.28548535, 1.1103518 ]),
#  'SMC3': ArrayView([0.31509434, 0.25920923, 0.35318875, ..., 0.50887714,
#             0.28282277, 1.07523783]),
#  'SNAI1': ArrayView([0.33162647, 0.28022736, 0.35867087, ..., 0.50752748,
#             0.28090882, 1.07039305]),
#  'SNAI2': ArrayView([0.28647566, 0.24665687, 0.3492217 , ..., 0.49483308,
#             0.28060795, 1.06779688]),
#  'SNAI3': ArrayView([0.29121673, 0.24863121, 0.3616118 , ..., 0.52372402,
#             0.28456142, 1.06398039]),
#  'SOX10': ArrayView([0.28263735, 0.24036104, 0.3557774 , ..., 0.49749253,
#             0.2771683 , 1.05845062]),
#  'SOX15': ArrayView([0.25811485, 0.30097492, 0.42529125, ..., 0.52744064,
#             0.23075761, 1.05694741]),
#  'SOX17': ArrayView([0.52089653, 0.43286993, 0.32315067, ..., 0.44820792,
#             0.30267961, 1.03996076]),
#  'SOX7': ArrayView([0.36266662, 0.29192251, 0.32113567, ..., 0.45956905,
#             0.29293771, 1.00948466]),
#  'SPI1': ArrayView([0.31285774, 0.259373  , 0.35155781, ..., 0.51263511,
#             0.28075069, 1.07138512]),
#  'SPIB': ArrayView([0.28320316, 0.22345639, 0.4006272 , ..., 0.52010445,
#             0.27668531, 1.06607258]),
#  'SPIC': ArrayView([0.31483016, 0.25797381, 0.3516024 , ..., 0.5111223 ,
#             0.28076941, 1.0717382 ]),
#  'SPZ1': ArrayView([0.31432236, 0.25811983, 0.35149789, ..., 0.51144734,
#             0.28108695, 1.07160811]),
#  'STAG1': ArrayView([0.3079651 , 0.23878197, 0.36552477, ..., 0.4821176 ,
#             0.29151945, 1.09184471]),
#  'STAT3': ArrayView([0.3074017 , 0.28213919, 0.40125947, ..., 0.47543098,
#             0.27126139, 1.03649444]),
#  'SUB1': ArrayView([0.3205971 , 0.25709647, 0.34511997, ..., 0.52800593,
#             0.291701  , 1.08815048]),
#  'SUZ12': ArrayView([0.30770013, 0.25435937, 0.35871211, ..., 0.50459893,
#             0.28350865, 1.06653987]),
#  'TBX2': ArrayView([0.33120436, 0.27492663, 0.34876293, ..., 0.50691786,
#             0.28504403, 1.06543902]),
#  'TBX3': ArrayView([0.38648839, 0.32857633, 0.34219668, ..., 0.49284738,
#             0.27519739, 1.05438765]),
#  'TBX4': ArrayView([0.31880202, 0.26289229, 0.35285271, ..., 0.50887631,
#             0.2801899 , 1.06701973]),
#  'TBX5': ArrayView([0.30828726, 0.25156269, 0.36856077, ..., 0.49890068,
#             0.26845641, 1.07153216]),
#  'TBX6': ArrayView([0.31450266, 0.26677403, 0.35354286, ..., 0.50729438,
#             0.27596578, 1.06525358]),
#  'TCF12': ArrayView([0.31352961, 0.23165408, 0.33312822, ..., 0.45760366,
#             0.27484119, 1.08551483]),
#  'TCF23': ArrayView([0.31449582, 0.25860511, 0.35139781, ..., 0.51106971,
#             0.28092728, 1.07165491]),
#  'TCF4': ArrayView([0.35027912, 0.24724161, 0.32141248, ..., 0.47929993,
#             0.30511894, 1.05259819]),
#  'TCF7L2': ArrayView([0.31559487, 0.2580119 , 0.3534037 , ..., 0.50673646,
#             0.28136925, 1.06762295]),
#  'TEAD4': ArrayView([0.34052011, 0.27221985, 0.38847976, ..., 0.53693556,
#             0.30158917, 1.06077169]),
#  'TFAP2A': ArrayView([0.32316526, 0.26950092, 0.34883735, ..., 0.50930894,
#             0.28170083, 1.07191422]),
#  'TFAP2C': ArrayView([0.34619528, 0.2821785 , 0.34764138, ..., 0.56321975,
#             0.27358405, 1.12369086]),
#  'TFCP2L1': ArrayView([0.34678031, 0.29662634, 0.37837372, ..., 0.49360867,
#             0.26576852, 1.03138677]),
#  'TGIF1': ArrayView([0.32985802, 0.26846487, 0.34699568, ..., 0.51201778,
#             0.28130759, 1.05838976]),
#  'TGM2': nan,
#  'THAP1': ArrayView([0.32079292, 0.25001849, 0.36520759, ..., 0.502914  ,
#             0.29911599, 1.07744928]),
#  'THAP11': ArrayView([0.28389344, 0.23709155, 0.32839202, ..., 0.56036694,
#             0.29327889, 1.11795781]),
#  'THAP3': ArrayView([0.29942518, 0.26122036, 0.34223076, ..., 0.51633438,
#             0.27713673, 1.07530883]),
#  'TP73': ArrayView([0.29853002, 0.25150066, 0.35144868, ..., 0.49603547,
#             0.27800584, 1.05387132]),
#  'TWIST2': ArrayView([0.31775701, 0.26774737, 0.3513533 , ..., 0.51353232,
#             0.28215951, 1.06763997]),
#  'UBTF': ArrayView([0.30881429, 0.25625634, 0.34710778, ..., 0.51626476,
#             0.2818309 , 1.06653993]),
#  'VAX1': ArrayView([0.31638866, 0.25821475, 0.35206711, ..., 0.51074549,
#             0.27985395, 1.06835623]),
#  'VDR': ArrayView([0.31170682, 0.2478911 , 0.34346736, ..., 0.51281348,
#             0.27946833, 1.07435638]),
#  'VPS72': ArrayView([0.26051597, 0.16557262, 0.30174613, ..., 0.55093542,
#             0.28695024, 1.12919317]),
#  'WNT3A': ArrayView([0.33139956, 0.27887688, 0.35298763, ..., 0.50935826,
#             0.28123571, 1.06941958]),
#  'WT1': ArrayView([0.32023264, 0.26128316, 0.35585271, ..., 0.51024654,
#             0.27898312, 1.06556384]),
#  'YY1': ArrayView([0.31817031, 0.25280522, 0.36304111, ..., 0.49142708,
#             0.28635712, 1.06555193]),
#  'ZBTB3': ArrayView([0.27280206, 0.19912271, 0.35722257, ..., 0.49791385,
#             0.29673707, 1.08522717]),
#  'ZBTB7A': ArrayView([0.32120974, 0.26592618, 0.37268902, ..., 0.55249512,
#             0.27827228, 1.07987658]),
#  'ZFP57': ArrayView([0.3180804 , 0.25941293, 0.35113127, ..., 0.4969538 ,
#             0.28246824, 1.07980861]),
#  'ZIC1': ArrayView([0.382113  , 0.27145512, 0.29196616, ..., 0.49056989,
#             0.27144657, 1.0822227 ]),
#  'ZKSCAN1': ArrayView([0.30482106, 0.25206597, 0.34421735, ..., 0.48807722,
#             0.27891226, 1.06285888]),
#  'ZMAT4': ArrayView([0.30571314, 0.25392021, 0.33494267, ..., 0.50228229,
#             0.29188618, 1.11474629]),
#  'ZMYND12': nan,
#  'ZNF217': ArrayView([0.31814781, 0.258788  , 0.34963581, ..., 0.51107719,
#             0.28830498, 1.06825644]),
#  'ZNF263': ArrayView([0.33230613, 0.26260036, 0.38899978, ..., 0.4933259 ,
#             0.28366881, 1.04183473]),
#  'ZNF281': ArrayView([0.32556496, 0.25618771, 0.36153696, ..., 0.50302909,
#             0.28775979, 1.05901287]),
#  'ZNF426': ArrayView([0.31452355, 0.25662268, 0.35408349, ..., 0.50881273,
#             0.2814189 , 1.07133383]),
#  'ZNF646': ArrayView([0.30661195, 0.24133312, 0.35214146, ..., 0.51120227,
#             0.28213985, 1.06811526]),
#  'ZNF713': ArrayView([0.31097299, 0.25432428, 0.33994685, ..., 0.50281598,
#             0.28061094, 1.06958098]),
#  'ALX1': ArrayView([0.33014875, 0.2669572 , 0.36120259, ..., 0.51120771,
#             0.27708481, 1.05558569]),
#  'ARID3B': ArrayView([0.31356099, 0.25742981, 0.3528468 , ..., 0.50943477,
#             0.28053804, 1.06905211]),
#  'ATF4': ArrayView([0.32521559, 0.26358762, 0.34898093, ..., 0.514968  ,
#             0.28556134, 1.07706136]),
#  'BMI1': ArrayView([0.3144821 , 0.25855739, 0.35139893, ..., 0.51175188,
#             0.2811833 , 1.0723278 ]),
#  'BMP7': ArrayView([0.31163641, 0.28453351, 0.32102477, ..., 0.50828402,
#             0.28686562, 1.06114303]),
#  'BRF1': ArrayView([0.31142533, 0.25661479, 0.35218884, ..., 0.51248668,
#             0.2807509 , 1.07096333]),
#  'CBFB': ArrayView([0.31440314, 0.25856436, 0.3519959 , ..., 0.51055492,
#             0.28109266, 1.0701976 ]),
#  'CTBP1': ArrayView([0.31054269, 0.26072942, 0.32941193, ..., 0.51768184,
#             0.28025469, 1.07764675]),
#  'CXXC5': ArrayView([0.30676746, 0.2542836 , 0.3460627 , ..., 0.51626186,
#             0.282497  , 1.07072338]),
#  'DBX1': ArrayView([0.31465367, 0.25868815, 0.35204655, ..., 0.51085274,
#             0.28107183, 1.07051591]),
#  'DBX2': ArrayView([0.31460413, 0.25854024, 0.35176047, ..., 0.51098353,
#             0.28110136, 1.0711315 ]),
#  'E2F5': ArrayView([0.31514754, 0.2578372 , 0.34949731, ..., 0.51072077,
#             0.28171957, 1.07315134]),
#  'ETV4': ArrayView([0.31476294, 0.25921435, 0.35504659, ..., 0.51569205,
#             0.28110412, 1.06936317]),
#  'FOSB': ArrayView([0.31461476, 0.25853558, 0.35174982, ..., 0.51099596,
#             0.28109876, 1.07113022]),
#  'HES6': ArrayView([0.31463065, 0.25850539, 0.35373194, ..., 0.50842725,
#             0.28139432, 1.0642951 ]),
#  'HMGA1': ArrayView([0.29498267, 0.233257  , 0.34004478, ..., 0.5215901 ,
#             0.28765309, 1.07308651]),
#  'HOXA1': ArrayView([0.31460178, 0.25853931, 0.35175888, ..., 0.51098231,
#             0.28110053, 1.0711405 ]),
#  'IKZF5': ArrayView([0.31646003, 0.25810574, 0.35500572, ..., 0.50169201,
#             0.28234978, 1.07714178]),
#  'KLF6': ArrayView([0.31365849, 0.25726865, 0.35231616, ..., 0.51288577,
#             0.28175595, 1.07132738]),
#  'LBX2': ArrayView([0.31460847, 0.2585445 , 0.35176272, ..., 0.5109873 ,
#             0.28109802, 1.07112853]),
#  'MLLT1': ArrayView([0.31457857, 0.25881596, 0.35214778, ..., 0.51130731,
#             0.28123938, 1.07132028]),
#  'MXD3': ArrayView([0.31515314, 0.25784726, 0.35656163, ..., 0.51481066,
#             0.2833787 , 1.06516375]),
#  'NFIA': ArrayView([0.31461046, 0.25856491, 0.35176108, ..., 0.51097123,
#             0.281106  , 1.07113941]),
#  'NR1H2': ArrayView([0.31980795, 0.25941037, 0.35666659, ..., 0.52812248,
#             0.2806301 , 1.07458671]),
#  'OSR1': ArrayView([0.31460041, 0.25853655, 0.35176321, ..., 0.51098739,
#             0.28109999, 1.07113287]),
#  'PGF': nan,
#  'PRICKLE1': nan,
#  'SATB1': ArrayView([0.31480129, 0.25861183, 0.35167166, ..., 0.51091757,
#             0.2810657 , 1.07088754]),
#  'TCF15': ArrayView([0.31461684, 0.25854764, 0.35176409, ..., 0.51098147,
#             0.28110475, 1.07111615]),
#  'TEAD2': ArrayView([0.2955505 , 0.20988215, 0.32239697, ..., 0.51748283,
#             0.31073852, 1.05503838]),
#  'TEF': ArrayView([0.31459898, 0.25853724, 0.35175692, ..., 0.51092346,
#             0.28112592, 1.07102   ]),
#  'THRA': ArrayView([0.29625625, 0.25051836, 0.32343044, ..., 0.52391587,
#             0.2845565 , 1.08721876]),
#  'TNF': ArrayView([0.3146087 , 0.25853626, 0.35176378, ..., 0.51098506,
#             0.28110429, 1.07112766]),
#  'VAX2': ArrayView([0.31477882, 0.25865397, 0.3518205 , ..., 0.51097076,
#             0.28107719, 1.07105115]),
#  'ZBTB44': ArrayView([0.31381715, 0.25439356, 0.34713395, ..., 0.51258296,
#             0.54692948, 1.0743828 ]),
#  'ZMAT5': ArrayView([0.3131253 , 0.25610376, 0.34572958, ..., 0.52015855,
#             0.28157627, 1.07728236]),
#  'ZNF384': ArrayView([0.31777044, 0.25780098, 0.35273049, ..., 0.51070121,
#             0.28084649, 1.06822573]),
#  'ZNF480': ArrayView([0.3145104 , 0.25828814, 0.35112684, ..., 0.51082857,
#             0.28173335, 1.07162039]),
#  'ZSCAN5A': ArrayView([0.31526526, 0.25949484, 0.3527555 , ..., 0.5098169 ,
#             0.2805785 , 1.0704689 ])}

# %% [markdown]
# ### Evaluation
#
# We compute the correlation of the predictions with held-out perturbations.

# %%
controlIndex = ko_lab_esc_data_train.obs["perturbation"]=="Control"
evaluator.evaluateCausalModel(heldout = ko_lab_esc_data_heldout, 
                    predictions = predictions,   
                    baseline = ko_lab_esc_data_train[controlIndex,:].X.mean(axis=0), 
                    classifier=cellFateClassifier, 
                    experiments = experiments,
                    factor_varied = "network",
                    experiment_name = EXPERIMENT_NAME)
# Out:
# (      spearman     spearmanp  cell_fate_correct perturbation  index  \
#  0     0.237572  1.007258e-34                0.0         ALX3      0
#  1     0.174008  3.827145e-19                0.0        ARNT2      0
#  2     0.167099  9.355592e-18                0.0        ASCL2      0
#  3     0.137168  2.093105e-12                0.0         ATF1      0
#  4     0.188078  3.756498e-22                0.0         ATF3      0
#  ...        ...           ...                ...          ...    ...
#  3940  0.000000  1.000000e+00                NaN       ZBTB44     14
#  3941  0.000000  1.000000e+00                NaN        ZMAT5     14
#  3942  0.000000  1.000000e+00                NaN       ZNF384     14
#  3943  0.000000  1.000000e+00                NaN       ZNF480     14
#  3944  0.000000  1.000000e+00                NaN      ZSCAN5A     14
#
#            network  p  threshold_number pruning  somePredictionRefused
#  0           dense  1         102313295    none                   True
#  1           dense  1         102313295    none                   True
#  2           dense  1         102313295    none                   True
#  3           dense  1         102313295    none                   True
#  4           dense  1         102313295    none                   True
#  ...           ... ..               ...     ...                    ...
#  3940  skin.csv.gz  1         102313295    none                   True
#  3941  skin.csv.gz  1         102313295    none                   True
#  3942  skin.csv.gz  1         102313295    none                   True
#  3943  skin.csv.gz  1         102313295    none                   True
#  3944  skin.csv.gz  1         102313295    none                   True
#
#  [3945 rows x 10 columns],
#  <AxesSubplot:xlabel='network', ylabel='Spearman correlation \npredicted log fold change vs observed'>,
#  {'spearman': <AxesSubplot:title={'center':'Mean and SE of spearman'}, xlabel='network', ylabel='spearman'>,
#   'cell_fate_correct': <AxesSubplot:title={'center':'Mean and SE of cell_fate_correct'}, xlabel='network', ylabel='cell_fate_correct'>})
