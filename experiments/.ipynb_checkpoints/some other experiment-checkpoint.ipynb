# %% [markdown]
# ## Experiment: cell type specificity of regression models
#
# This experiment studies whether cluster-specific ridge regression is superior to regression shared across all training data.

# %%
EXPERIMENT_NAME="clusterSpecific_v1"

# %%
import warnings
warnings.filterwarnings('ignore')
import importlib
import os
import sys
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import celloracle as co

#      visualization settings
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
plt.rcParams['figure.figsize'] = [6, 4.5]
plt.rcParams["savefig.dpi"] = 300

# %%
# Deal with various file paths specific to this project
PROJECT_PATH = '/home/ekernf01/Desktop/jhu/research/projects/perturbation_prediction/cell_type_knowledge_transfer/'
os.chdir(PROJECT_PATH + "benchmarking/")
try:
    os.makedirs("results/" + EXPERIMENT_NAME)
except:
    pass

sys.path.append(os.path.expanduser(PROJECT_PATH + 'networks/load_networks'))
sys.path.append(os.path.expanduser(PROJECT_PATH + 'perturbations/load_perturbations')) 
sys.path.append(os.path.expanduser(PROJECT_PATH + 'benchmarking/evaluator')) 
import evaluator
import load_networks
import load_perturbations
importlib.reload(evaluator) 
importlib.reload(load_networks) 
importlib.reload(load_perturbations)
os.environ["GRN_PATH"]           = PROJECT_PATH + "networks/networks"
os.environ["PERTURBATION_PATH"]  = PROJECT_PATH + "perturbations/perturbations"
print("Example networks:")
load_networks.load_grn_metadata().head(2)
# Out:
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2
# Example networks:
#                                       name  \
# name
# cellnet_human_Hg1332  cellnet_human_Hg1332
# cellnet_human_Hugene  cellnet_human_Hugene
#
#                                                          description  \
# name
# cellnet_human_Hg1332  CLR analysis of microarray data pulled off GEO
# cellnet_human_Hugene  CLR analysis of microarray data pulled off GEO
#
#                                                       data_used species  \
# name
# cellnet_human_Hg1332  microarrays (HG133 plus 2 and HuGene 1.0)   human
# cellnet_human_Hugene  microarrays (HG133 plus 2 and HuGene 1.0)   human
#
#                                                     link  \
# name
# cellnet_human_Hg1332  http://pcahan1.github.io/cellnetr/
# cellnet_human_Hugene  http://pcahan1.github.io/cellnetr/
#
#                                                                citation  \
# name
# cellnet_human_Hg1332  Cahan, P., Li, H., Morris, S. A., Da Rocha, E....
# cellnet_human_Hugene  Cahan, P., Li, H., Morris, S. A., Da Rocha, E....
#
#                      is_ready first_column
# name
# cellnet_human_Hg1332      yes    symmetric
# cellnet_human_Hugene      yes    symmetric

# %% [markdown]
# ### Networks setup
#
# This experiment uses the two default networks: the dense network and the CO default network.

# %%
networks = {
    'dense': evaluator.makeRandomNetwork(density = 1),
    'cellOracle': co.data.load_human_promoter_base_GRN()
}
network_sizes = pd.DataFrame({bn:evaluator.countMatrixEdges(networks[bn]) for bn in networks}, index = ["numEdges"])
network_sizes = network_sizes.T.reset_index().rename({"index":"network"}, axis = 1)
network_sizes
# Out:
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2
#       network     numEdges
# 0       dense  102313295.0
# 1  cellOracle    5134330.0

# %% [markdown]
# ### Data setup
#
# We use the Nakatake et al data. This experiment is on per-cluster versus shared regression models, so we run Leiden clustering at many different resolutions.

# %%
ko_lab_esc_data = sc.read_h5ad(os.environ["PERTURBATION_PATH"] + "/nakatake/" + "test.h5ad")
clusterResolutions = []
for r in [i/10.0 for i in range(1,11,2)]:
    sc.tl.leiden(ko_lab_esc_data, resolution=r)
    new_name = "leiden_r="+str(round(r, 1))
    clusterResolutions.append(new_name)
    ko_lab_esc_data.obs[new_name] = ko_lab_esc_data.obs["leiden"]
    sc.pl.umap(ko_lab_esc_data, color = "leiden")
    ko_lab_esc_data.obs[new_name] = ko_lab_esc_data.obs[new_name].astype("category")
    ko_lab_esc_data.uns[new_name + "_colors"] = ko_lab_esc_data.uns["leiden_colors"]

# %% [markdown]
# ### Training and test split
#
# A few factors complicate the training-test split.
#
# - Perturbed genes may be absent from most base GRN's due to lack of motif information or ChIP data. These are excluded from the test data to avoid obvious failure cases.
# - Perturbed genes may not be measured. These are excluded from test data because we don't know to what extent they were overexpressed.
#
# In both cases, we still use those perturbed profiles as training data, hoping they will provide useful info about attainable cell states and downstream causal effects.
#
# For some collections of base networks, there are many factors ineligible for use as test data -- so many that we use all the eligible ones for test and the only ineligible ones for training.
#
# For other cases, such as dense base networks, that would leave too small a training set, so we send some perturbations to the training set at random even if we would be able to use them in the test set. We ensure there are at least 250 training examples.

# %%
test_set_regulators = set.intersection(*[set(networks[key].columns) 
                                      for key in networks if not key == 'empty'])
test_set_regulators = test_set_regulators.difference(ko_lab_esc_data.uns["perturbed_but_not_measured_genes"])
testSetPerturbations     = set(ko_lab_esc_data.obs['perturbation']).intersection(test_set_regulators)
trainingSetPerturbations = set(ko_lab_esc_data.obs['perturbation']).difference(test_set_regulators)
if len(trainingSetPerturbations) < 250:
    swap = np.random.default_rng(seed=0).choice(list(testSetPerturbations), 
                                           250 - len(trainingSetPerturbations), 
                                           replace = False)
    testSetPerturbations = testSetPerturbations.difference(swap)
    trainingSetPerturbations = trainingSetPerturbations.union(swap)
ko_lab_esc_data_heldout  = ko_lab_esc_data[ko_lab_esc_data.obs["perturbation"].isin(testSetPerturbations),    :]
ko_lab_esc_data_train    = ko_lab_esc_data[ko_lab_esc_data.obs["perturbation"].isin(trainingSetPerturbations),:]
ko_lab_esc_data_train.obs['perturbation'].unique()
perturbationsToPredict = [(gene, ko_lab_esc_data_heldout[sample, gene].X[0,0]) for sample,gene in enumerate(ko_lab_esc_data_heldout.obs['perturbation'])] 
print("Example perturbations formatted as \n (gene, expression after perturbation)")
print(perturbationsToPredict[0:5])
print("Test set size:")
print(len(testSetPerturbations))
print("Training set size:")
print(len(trainingSetPerturbations))
# Out:
# Example perturbations formatted as
#  (gene, expression after perturbation)
# [('AATF', 3.8030212), ('AATF', 3.3206005), ('ALX3', 2.829177), ('ALX3', 3.583377), ('ANKRD22', 0.43029666)]
# Test set size:
# 263
# Training set size:
# 250

# %% [markdown]
# ### Experimental metadata

# %%
n_networks = len(networks.keys())
n_resolutions = len(clusterResolutions)
experiments = pd.DataFrame({"network":[n for n in networks.keys()]*n_resolutions, 
                            "cluster_resolution":clusterResolutions + clusterResolutions,
                            "p":[1]*n_networks*n_resolutions,
                            "threshold_number":[int(network_sizes['numEdges'].max())]*n_networks*n_resolutions,
                            "pruning":["none"]*n_networks*n_resolutions})
experiments["index"] = experiments.index
experiments.to_csv("results/" + EXPERIMENT_NAME + "/networkExperiments.csv")
experiments
# Out:
#       network cluster_resolution  p  threshold_number pruning  index
# 0       dense       leiden_r=0.1  1         102313295    none      0
# 1  cellOracle       leiden_r=0.3  1         102313295    none      1
# 2       dense       leiden_r=0.5  1         102313295    none      2
# 3  cellOracle       leiden_r=0.7  1         102313295    none      3
# 4       dense       leiden_r=0.9  1         102313295    none      4
# 5  cellOracle       leiden_r=0.1  1         102313295    none      5
# 6       dense       leiden_r=0.3  1         102313295    none      6
# 7  cellOracle       leiden_r=0.5  1         102313295    none      7
# 8       dense       leiden_r=0.7  1         102313295    none      8
# 9  cellOracle       leiden_r=0.9  1         102313295    none      9

# %%
predictions = {
    i: evaluator.trainCausalModelAndPredict(expression=ko_lab_esc_data_train,
                                  baseNetwork=networks[experiments.loc[i,'network']],
                                  memoizationName="results/" + EXPERIMENT_NAME + "/" + str(i) + ".celloracle.oracle", 
                                  perturbations=perturbationsToPredict,
                                  clusterColumnName = experiments.loc[i, "cluster_resolution"],
                                  pruningParameters = {"p":experiments.loc[i,'p'], 
                                                       "threshold_number":experiments.loc[i,'threshold_number']}) 
    for i in experiments.index
}
# Out:
# Working on results/clusterSpecific_v1/0.celloracle.oracle
# Predicting ZSCAN5A
# AATF AATF ALX3 ALX3 ANKRD22 Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ANKRD22 Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# AR AR ARNT2 ARNT2 ASCL2 ASCL2 ASH2L Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ASH2L Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF2 ATF2 ATF3 ATF3 BACH1 BACH1 BANP BANP BARHL2 BARHL2 BARX2 BARX2 BCL6 BCL6 BHLHE40 BHLHE40 CBX8 Prediction failed for CBX8 with error Gene CBX8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CBX8 Prediction failed for CBX8 with error Gene CBX8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CEBPA CEBPA CEBPB CEBPB CHD1 CHD4 CHD4 CREB1 CREB1 CRY2 Prediction failed for CRY2 with error Gene CRY2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CRY2 Prediction failed for CRY2 with error Gene CRY2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTBP2 CTBP2 CTCFL CTCFL CTNNB1 CTNNB1 DEDD2 Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DEDD2 Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DLX3 DLX3 DMRT1 DMRT1 DMRTC2 DMRTC2 DNMT3L DNMT3L E2F1 E2F1 EGR1 EGR1 ELF1 ELF1 ELF2 ELF2 ELF4 ELL2 Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELL2 Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# EN1 EN1 EOMES EOMES ESRRB ESRRB ETS1 ETS1 ETS2 ETS2 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 EVX1 EVX1 FIGLA FIGLA FOS FOS FOSL2 FOSL2 FOXD1 FOXD1 FOXD3 FOXD3 FOXE3 FOXE3 FOXH1 FOXH1 FOXL2 FOXL2 FOXM1 FOXM1 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GATA3 GATA3 GBX2 GBX2 GLI1 GLI1 GRHL2 GRHL2 GSC GSC GTF2B GTF2B H2AFZ Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# H2AFZ Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HDAC2 HDAC2 HES1 HES1 HEY1 HEY1 HHEX HHEX HMGA2 HMGA2 HMGN1 HMGXB4 HMGXB4 HNF4A HNF4A HOPX HOPX HOXA3 HOXA3 HOXA9 HOXA9 HOXB3 HOXB3 HOXB4 HOXB4 HOXC9 HOXC9 HOXD10 HOXD10 HOXD13 HOXD13 ID1 ID1 IRF2 IRF2 IRF3 IRF3 IRF4 IRF4 IRF5 IRF5 ISL2 ISL2 JARID2 JARID2 JUN JUN JUNB JUNB JUNB JUND JUND KDM1A KDM1A KDM5A KDM5A KDM5B KDM5B KLF1 KLF1 KLF15 KLF15 KLF5 KLF5 KLF9 KLF9 L3MBTL2 Prediction failed for L3MBTL2 with error Gene L3MBTL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# L3MBTL2 Prediction failed for L3MBTL2 with error Gene L3MBTL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHFPL6 Prediction failed for LHFPL6 with error Gene LHFPL6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHFPL6 Prediction failed for LHFPL6 with error Gene LHFPL6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LMO2 LMO2 MAB21L2 Prediction failed for MAB21L2 with error Gene MAB21L2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAB21L2 Prediction failed for MAB21L2 with error Gene MAB21L2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAB21L3 Prediction failed for MAB21L3 with error Gene MAB21L3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAB21L3 Prediction failed for MAB21L3 with error Gene MAB21L3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAFK MAFK MAX MAX MEF2C MEF2C MEIS1 MEIS1 MSGN1 MSGN1 MYC MYC MYF6 MYF6 NANOG NANOG NELFA Prediction failed for NELFA with error Gene NELFA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFA Prediction failed for NELFA with error Gene NELFA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFE Prediction failed for NELFE with error Gene NELFE is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFE Prediction failed for NELFE with error Gene NELFE is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NEUROD2 NEUROD2 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NFIL3 NFIL3 NFYB NFYB NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-3 NKX6-3 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F2 NR2F2 NR5A1 NR5A1 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OSTF1 Prediction failed for OSTF1 with error Gene OSTF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OSTF1 Prediction failed for OSTF1 with error Gene OSTF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PA2G4 PA2G4 PABPC1 Prediction failed for PABPC1 with error Gene PABPC1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PAX8 PAX8 PBX1 PBX1 PCDH1 Prediction failed for PCDH1 with error Gene PCDH1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PCDH1 Prediction failed for PCDH1 with error Gene PCDH1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PHF8 Prediction failed for PHF8 with error Gene PHF8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PHF8 Prediction failed for PHF8 with error Gene PHF8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PHOX2B PHOX2B PITX3 PITX3 PLXNB3 PLXNB3 PML PML POU3F2 POU3F2 POU4F1 POU4F1 POU4F3 POU4F3 POU5F1 POU5F1 POU5F1 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTAFR Prediction failed for PTAFR with error Gene PTAFR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PTAFR Prediction failed for PTAFR with error Gene PTAFR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RARA RARA RASL10A Prediction failed for RASL10A with error Gene RASL10A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RASL10A Prediction failed for RASL10A with error Gene RASL10A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP5 Prediction failed for RBBP5 with error Gene RBBP5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP5 Prediction failed for RBBP5 with error Gene RBBP5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP6 Prediction failed for RBBP6 with error Gene RBBP6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP6 Prediction failed for RBBP6 with error Gene RBBP6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RFX2 RFX2 RHOXF2 RHOXF2 RNF2 RNF2 RPS6KA1 Prediction failed for RPS6KA1 with error Gene RPS6KA1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RPS6KA1 Prediction failed for RPS6KA1 with error Gene RPS6KA1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RUNX3 RUNX3 SAP30 Prediction failed for SAP30 with error Gene SAP30 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SIX1 SIX1 SMAD1 SMAD1 SMAD3 SMAD3 SMAD4 SMAD4 SMAD7 SMAD7 SMARCA4 SMARCA4 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI3 SNAI3 SOX11 SOX11 SOX2 SOX2 SOX6 SOX6 SPIC SPIC SPIC SPZ1 SPZ1 STAG1 STAG1 STAT3 STAT3 STAT5A STAT5A STRA8 Prediction failed for STRA8 with error Gene STRA8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# STRA8 Prediction failed for STRA8 with error Gene STRA8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SUB1 SUB1 TAL1 TAL1 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF4 TCF4 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFCP2L1 TFCP2L1 TFE3 TFE3 TGM2 Prediction failed for TGM2 with error Gene TGM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TGM2 Prediction failed for TGM2 with error Gene TGM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP1 THAP1 THAP11 THAP11 THAP7 THAP7 TLX3 TLX3 TP73 TRAF4 TRAF4 TYRP1 Prediction failed for TYRP1 with error Gene TYRP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TYRP1 Prediction failed for TYRP1 with error Gene TYRP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# UGP2 Prediction failed for UGP2 with error Gene UGP2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# UGP2 Prediction failed for UGP2 with error Gene UGP2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# USF1 USF1 USF2 USF2 VAX1 VAX1 WT1 WT1 XRCC4 Prediction failed for XRCC4 with error Gene XRCC4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# XRCC4 Prediction failed for XRCC4 with error Gene XRCC4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBTB3 ZBTB3 ZFP57 ZFP57 ZNF263 ZNF263 ZNF274 ZNF274 ZNF280B ZNF280B ZNF281 ZNF281 ZNF426 ZNF426 ZNF706 ZNF706 ZNF713 ZNF713 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 BMI1 BMI1 BRF1 BRF1 CBFB CBX3 Prediction failed for CBX3 with error Gene CBX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CBX3 Prediction failed for CBX3 with error Gene CBX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD5 Prediction failed for CHD5 with error Gene CHD5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD5 Prediction failed for CHD5 with error Gene CHD5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTBP1 CTBP1 DBX1 DBX1 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 ETV4 ETV4 GTF3C5 Prediction failed for GTF3C5 with error Gene GTF3C5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF3C5 Prediction failed for GTF3C5 with error Gene GTF3C5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HES6 HES6 HLX HLX HMGA1 HMGA1 HNRNPD HNRNPD IKZF5 IKZF5 ILF2 Prediction failed for ILF2 with error Gene ILF2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ILF2 Prediction failed for ILF2 with error Gene ILF2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MBD3 MBD3 MLLT1 MLLT1 MXD3 MXD3 MYCN MYCN NR1H2 NR1H2 OSR1 OSR1 PAX9 PAX9 S1PR1 Prediction failed for S1PR1 with error Gene S1PR1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# S1PR1 Prediction failed for S1PR1 with error Gene S1PR1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SRF SRF TEAD2 TEAD2 THRA THRA VAX2 VAX2 ZMAT5 ZMAT5 ZNF384 ZNF384 ZNF384 ZNF384 ZNF480 ZNF480 ZNF780A ZNF780A ZSCAN5A ZSCAN5A
# Working on results/clusterSpecific_v1/1.celloracle.oracle
# Predicting ZSCAN5A
# AATF Prediction failed for AATF with error Gene AATF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# AATF Prediction failed for AATF with error Gene AATF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ALX3 ALX3 ANKRD22 Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ANKRD22 Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# AR AR ARNT2 ARNT2 ASCL2 ASCL2 ASH2L Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ASH2L Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF2 ATF2 ATF3 ATF3 BACH1 BACH1 BANP Prediction failed for BANP with error Gene BANP is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BANP Prediction failed for BANP with error Gene BANP is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BARHL2 BARHL2 BARX2 BARX2 BCL6 BCL6 BHLHE40 BHLHE40 CBX8 Prediction failed for CBX8 with error Gene CBX8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CBX8 Prediction failed for CBX8 with error Gene CBX8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CEBPA CEBPA CEBPB CEBPB CHD1 Prediction failed for CHD1 with error Gene CHD1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD4 Prediction failed for CHD4 with error Gene CHD4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD4 Prediction failed for CHD4 with error Gene CHD4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CREB1 CREB1 CRY2 Prediction failed for CRY2 with error Gene CRY2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CRY2 Prediction failed for CRY2 with error Gene CRY2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTBP2 Prediction failed for CTBP2 with error Gene CTBP2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTBP2 Prediction failed for CTBP2 with error Gene CTBP2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTCFL CTCFL CTNNB1 Prediction failed for CTNNB1 with error Gene CTNNB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTNNB1 Prediction failed for CTNNB1 with error Gene CTNNB1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DEDD2 Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DEDD2 Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DLX3 Prediction failed for DLX3 with error Gene DLX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DLX3 Prediction failed for DLX3 with error Gene DLX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DMRT1 DMRT1 DMRTC2 DMRTC2 DNMT3L Prediction failed for DNMT3L with error Gene DNMT3L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DNMT3L Prediction failed for DNMT3L with error Gene DNMT3L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# E2F1 E2F1 EGR1 EGR1 ELF1 ELF1 ELF2 ELF2 ELF4 ELL2 Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELL2 Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# EN1 EN1 EOMES EOMES ESRRB ESRRB ETS1 ETS1 ETS2 ETS2 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 EVX1 Prediction failed for EVX1 with error Gene EVX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# EVX1 Prediction failed for EVX1 with error Gene EVX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FIGLA Prediction failed for FIGLA with error Gene FIGLA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FIGLA Prediction failed for FIGLA with error Gene FIGLA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOS FOS FOSL2 FOSL2 FOXD1 FOXD1 FOXD3 FOXD3 FOXE3 FOXE3 FOXH1 FOXH1 FOXL2 FOXL2 FOXM1 FOXM1 FOXO3 FOXO3 FOXP1 FOXP1

# %%
predictions[0]

# %% [markdown]
# ### Evaluation
#
# We compute the correlation of the predictions with held-out perturbations.

# %%
controlIndex = ko_lab_esc_data_train.obs["perturbation"]=="Control"
evaluationResults = {}
for i in predictions:
    evaluationResults[i] = \
        evaluateCausalModel(ko_lab_esc_data_heldout, 
                            predictions[i],   
                            baseline = ko_lab_esc_data_train[controlIndex,:].X.mean(axis=0),     
                            doPlots=False)[0]
    evaluationResults[i]["index"] = i
evaluationResults = pd.concat(evaluationResults)
evaluationResults = evaluationResults.merge(experiments, how = "left")
evaluationResults = pd.DataFrame(evaluationResults.to_dict())
evaluationResults.head()

# %%
noPredictionMade = evaluationResults.iloc[[x==0 for x in evaluationResults["spearman"]],:]['perturbation']
noPredictionMade = set(noPredictionMade)
noPredictionMade
evaluationResults["somePredictionRefused"] = evaluationResults["perturbation"].isin(noPredictionMade) 
evaluationResults.to_csv("../results/"+ EXPERIMENT_NAME +"/networksExperimentEvaluation.csv")
evaluationResults.head()

# %%
baseNetworkComparisonFigure = sns.FacetGrid(evaluationResults[~evaluationResults['somePredictionRefused']], 
                                            col = 'pruning',
                                            sharey = False, 
                                            height=5, 
                                            aspect=1).set(title = "Performance")
baseNetworkComparisonFigure.map(sns.violinplot, "spearman", "network", 
                                palette=["r", "b", "k", "y", "g"]
                               ).add_legend()
baseNetworkComparisonFigure.set(ylabel="Spearman correlation\nminus average over all methods")
plt.show()

# %%
summary = evaluationResults[~evaluationResults['somePredictionRefused']]
summary = summary.groupby(["pruning", "network"]).mean()[["spearman"]].reset_index(["pruning", "network"])
summary = summary.merge(network_sizes)
summary.sort_values(['pruning', 'network'], inplace=True)
summary.to_csv("../results/" + EXPERIMENT_NAME + "/networksExperimentEvaluationSummary.csv")
print(summary)
baseNetworkComparisonFigureCompact = sns.scatterplot(data=summary[[p!="harsh" for p in summary["pruning"]]],
                x='numEdges',
                y='spearman', 
                hue='network')
baseNetworkComparisonFigureCompact.set_xscale("log")
baseNetworkComparisonFigureCompact.set(title="Density vs performance")
baseNetworkComparisonFigureCompact.legend(loc='center left', bbox_to_anchor=(1, 0.5))
