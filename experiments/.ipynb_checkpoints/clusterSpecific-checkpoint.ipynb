# %% [markdown]
# ## Experiment: cell type specificity of regression models
#
# This experiment studies whether cluster-specific ridge regression is superior to regression shared across all training data.

# %%
EXPERIMENT_NAME="clusterSpecific_v1"

# %%
import warnings
warnings.filterwarnings('ignore')
import importlib
import os
import sys
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import celloracle as co

#      visualization settings
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
plt.rcParams['figure.figsize'] = [6, 4.5]
plt.rcParams["savefig.dpi"] = 300

# %%
# Deal with various file paths specific to this project
PROJECT_PATH = '/home/ekernf01/Desktop/jhu/research/projects/perturbation_prediction/cell_type_knowledge_transfer/'
os.chdir(PROJECT_PATH + "benchmarking/")
try:
    os.makedirs("results/" + EXPERIMENT_NAME)
except:
    pass

sys.path.append(os.path.expanduser(PROJECT_PATH + 'networks/load_networks'))
sys.path.append(os.path.expanduser(PROJECT_PATH + 'perturbations/load_perturbations')) 
sys.path.append(os.path.expanduser(PROJECT_PATH + 'benchmarking/evaluator')) 
import evaluator
import load_networks
import load_perturbations
importlib.reload(evaluator) 
importlib.reload(load_networks) 
importlib.reload(load_perturbations)
os.environ["GRN_PATH"]           = PROJECT_PATH + "networks/networks"
os.environ["PERTURBATION_PATH"]  = PROJECT_PATH + "perturbations/perturbations"
# Out:
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2

# %% [markdown]
# ### Networks setup
#
# This experiment uses the two default networks: the dense network and the CO default network.

# %%
networks = {
    'dense': evaluator.makeRandomNetwork(density = 1),
    'cellOracle': co.data.load_human_promoter_base_GRN()
}
network_sizes = pd.DataFrame({bn:evaluator.countMatrixEdges(networks[bn]) for bn in networks}, index = ["numEdges"])
network_sizes = network_sizes.T.reset_index().rename({"index":"network"}, axis = 1)
network_sizes
# Out:
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2
#       network     numEdges
# 0       dense  102313295.0
# 1  cellOracle    5134330.0

# %% [markdown]
# ### Data setup
#
# We use the Nakatake et al data. This experiment is on per-cluster versus shared regression models, so we run Leiden clustering at many different resolutions.

# %%
ko_lab_esc_data = sc.read_h5ad(os.environ["PERTURBATION_PATH"] + "/nakatake/" + "test.h5ad")
clusterResolutions = []
for r in [i/10.0 for i in range(1,11,2)]:
    sc.tl.leiden(ko_lab_esc_data, resolution=r)
    new_name = "leiden_r="+str(round(r, 1))
    clusterResolutions.append(new_name)
    ko_lab_esc_data.obs[new_name] = ko_lab_esc_data.obs["leiden"]
    ax = sc.pl.umap(ko_lab_esc_data, color = "leiden", return_fig=True)
    ax.savefig("results/" + EXPERIMENT_NAME + "/" + new_name + ".pdf")
    ko_lab_esc_data.obs[new_name] = ko_lab_esc_data.obs[new_name].astype("category")
    ko_lab_esc_data.uns[new_name + "_colors"] = ko_lab_esc_data.uns["leiden_colors"]

# %%
allowedRegulators = set.intersection(*[set(networks[key].columns) for key in networks])
ko_lab_esc_data_train, ko_lab_esc_data_heldout, perturbationsToPredict = \
    evaluator.splitData(ko_lab_esc_data, allowedRegulators, minTestSetSize=250)
# Out:
# Example perturbations formatted as
#  (gene, expression after perturbation)
# [('ALX3', 2.829177), ('ALX3', 3.583377), ('ALX4', 1.1726332), ('ALX4', 0.7964212), ('AR', 1.1614258)]
# Test set size:
# 263
# Training set size:
# 250

# %% [markdown]
# ### Experimental metadata

# %%
n_networks = len(networks.keys())
n_resolutions = len(clusterResolutions)
experiments = pd.DataFrame({"network":[n for n in networks.keys()]*n_resolutions, 
                            "cluster_resolution":clusterResolutions + clusterResolutions,
                            "p":[1]*n_networks*n_resolutions,
                            "threshold_number":[int(network_sizes['numEdges'].max())]*n_networks*n_resolutions,
                            "pruning":["none"]*n_networks*n_resolutions})
experiments["index"] = experiments.index
experiments.to_csv("results/" + EXPERIMENT_NAME + "/networkExperiments.csv")
experiments
# Out:
#       network cluster_resolution  p  threshold_number pruning  index
# 0       dense       leiden_r=0.1  1         102313295    none      0
# 1  cellOracle       leiden_r=0.3  1         102313295    none      1
# 2       dense       leiden_r=0.5  1         102313295    none      2
# 3  cellOracle       leiden_r=0.7  1         102313295    none      3
# 4       dense       leiden_r=0.9  1         102313295    none      4
# 5  cellOracle       leiden_r=0.1  1         102313295    none      5
# 6       dense       leiden_r=0.3  1         102313295    none      6
# 7  cellOracle       leiden_r=0.5  1         102313295    none      7
# 8       dense       leiden_r=0.7  1         102313295    none      8
# 9  cellOracle       leiden_r=0.9  1         102313295    none      9

# %%
predictions = {
    i: evaluator.trainCausalModelAndPredict(expression=ko_lab_esc_data_train,
                                  baseNetwork=networks[experiments.loc[i,'network']],
                                  memoizationName="results/" + EXPERIMENT_NAME + "/" + str(i) + ".celloracle.oracle", 
                                  perturbations=perturbationsToPredict,
                                  clusterColumnName = experiments.loc[i, "cluster_resolution"],
                                  pruningParameters = {"p":experiments.loc[i,'p'], 
                                                       "threshold_number":experiments.loc[i,'threshold_number']}) 
    for i in experiments.index
}
# Out:
# Working on results/clusterSpecific_v1/0.celloracle.oracle
# Memoized results found.
# Predicting ZNF384
# ALX3 ALX3 ALX4 ALX4 AR AR ARID3A ARID3A ARNT2 ARNT2 ASCL1 ASCL1 ASCL2 ASCL2 ATF2 ATF2 ATF3 ATF3 ATOH1 ATOH1 BACH1 BACH1 BARX2 BARX2 BATF BATF BHLHE40 BHLHE40 BRF2 BRF2 CDX2 CDX2 CDX2 CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CREB1 CREB1 CREB3 CREB3 CTCF CTCFL CTCFL CUX1 CUX1 DLX5 DLX5 DMRT1 DMRT1 E2F1 E2F1 E2F6 E2F6 E2F7 E2F7 EBF1 EBF1 EGR2 EGR2 EHF EHF ELF1 ELF1 ELF2 ELF2 ELF4 ELF5 ELF5 ELK3 ELK3 EN1 EN1 EOMES EOMES ERG ERG ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETV1 ETV1 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 FEV FEV FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOSL2 FOSL2 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXD1 FOXD1 FOXD3 FOXD3 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXF1 FOXF1 FOXG1 FOXG1 FOXH1 FOXH1 FOXJ1 FOXJ1 FOXL2 FOXL2 FOXN3 FOXN3 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GATA3 GATA3 GLI1 GLI1 GLIS2 GLIS2 GRHL2 GRHL2 GSC GSC GTF3C2 GTF3C2 HDAC2 HDAC2 HES1 HES1 HESX1 HESX1 HMGA2 HMGA2 HNF4A HNF4A HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXC9 HOXC9 HOXD1 HOXD1 HOXD10 HOXD10 HOXD13 HOXD13 HOXD3 HOXD3 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF2 IRF2 IRF5 IRF5 IRX2 IRX2 ISL1 ISL1 ISL2 ISL2 JUNB JUNB JUNB JUND JUND KLF1 KLF1 KLF11 KLF11 KLF12 KLF14 KLF14 KLF15 KLF15 KLF2 KLF2 KLF3 KLF3 KLF4 KLF4 KLF5 KLF5 KLF8 KLF8 KLF9 KLF9 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LMO2 LMO2 MAFK MAFK MEF2A MEF2A MEF2C MEF2C MEIS1 MEIS1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MYBL2 MYBL2 MYC MYC MYF5 MYF5 MYOD1 MYOD1 NEUROD1 NEUROD1 NEUROD2 NEUROD2 NEUROD4 NEUROD4 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NR4A3 NR4A3 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PAX5 PAX5 PAX8 PAX8 PBX1 PBX1 PDX1 PDX1 PITX2 PITX2 POLR3A POLR3A POU2F2 POU2F2 POU4F1 POU4F1 POU4F3 POU4F3 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTF1A PTF1A RAD21 RAD21 RARA RARA REST REST RFX2 RFX2 RFX5 RFX5 RHOXF2 RHOXF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RXRA RXRA SALL4 SALL4 SETDB1 SETDB1 SIN3A SIN3A SIRT6 SIRT6 SIX1 SIX1 SIX5 SIX5 SMAD2 SMAD2 SMAD3 SMAD3 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX6 SOX6 SOX7 SOX7 SOX9 SOX9 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 SREBF2 SREBF2 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A TAL1 TAL1 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFAP2C TFAP2C TFAP4 TFAP4 TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 THAP1 THAP1 THAP11 THAP11 TLX3 TLX3 TP53 TP53 TP73 TRIM28 USF1 USF1 VAX1 VAX1 VDR VDR YY1 YY1 ZFP57 ZFP57 ZIC1 ZIC1 ZIC3 ZIC3 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF274 ZNF274 ZNF713 ZNF713 ZSCAN4 ZSCAN4 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 CBFB DBX1 DBX1 DBX2 DBX2 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 FOXE1 FOXE1 HMGA1 HMGA1 HOXA1 HOXA1 LBX2 LBX2 MYCN MYCN NFIA NFIA NFYA NFYA OSR1 OSR1 POU3F4 POU3F4 SRF SRF TCF15 TCF15 TEF TEF ZNF384 ZNF384 ZNF384 ZNF384
# Working on results/clusterSpecific_v1/1.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/3 [00:00<?, ?it/s]
# inferring GRN for 0...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 1...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 2...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in 0
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 1
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 2
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# Predicting ZNF384
# ALX3 ALX3 ALX4 ALX4 AR AR ARID3A ARID3A ARNT2 ARNT2 ASCL1 ASCL1 ASCL2 ASCL2 ATF2 ATF2 ATF3 ATF3 ATOH1 ATOH1 BACH1 BACH1 BARX2 BARX2 BATF BATF BHLHE40 BHLHE40 BRF2 BRF2 CDX2 CDX2 CDX2 CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CREB1 CREB1 CREB3 CREB3 CTCF CTCFL CTCFL CUX1 CUX1 DLX5 DLX5 DMRT1 DMRT1 E2F1 E2F1 E2F6 E2F6 E2F7 E2F7 EBF1 EBF1 EGR2 EGR2 EHF EHF ELF1 ELF1 ELF2 ELF2 ELF4 ELF5 ELF5 ELK3 ELK3 EN1 EN1 EOMES EOMES ERG ERG ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETV1 ETV1 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 FEV FEV FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOSL2 FOSL2 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXD1 FOXD1 FOXD3 FOXD3 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXF1 FOXF1 FOXG1 FOXG1 FOXH1 FOXH1 FOXJ1 FOXJ1 FOXL2 FOXL2 FOXN3 FOXN3 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GATA3 GATA3 GLI1 GLI1 GLIS2 GLIS2 GRHL2 GRHL2 GSC GSC GTF3C2 GTF3C2 HDAC2 HDAC2 HES1 HES1 HESX1 HESX1 HMGA2 HMGA2 HNF4A HNF4A HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXC9 HOXC9 HOXD1 HOXD1 HOXD10 HOXD10 HOXD13 HOXD13 HOXD3 HOXD3 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF2 IRF2 IRF5 IRF5 IRX2 IRX2 ISL1 ISL1 ISL2 ISL2 JUNB JUNB JUNB JUND JUND KLF1 KLF1 KLF11 KLF11 KLF12 KLF14 KLF14 KLF15 KLF15 KLF2 KLF2 KLF3 KLF3 KLF4 KLF4 KLF5 KLF5 KLF8 KLF8 KLF9 KLF9 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LMO2 LMO2 MAFK MAFK MEF2A MEF2A MEF2C MEF2C MEIS1 MEIS1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MYBL2 MYBL2 MYC MYC MYF5 MYF5 MYOD1 MYOD1 NEUROD1 NEUROD1 NEUROD2 NEUROD2 NEUROD4 NEUROD4 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NR4A3 NR4A3 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PAX5 PAX5 PAX8 PAX8 PBX1 PBX1 PDX1 PDX1 PITX2 PITX2 POLR3A POLR3A POU2F2 POU2F2 POU4F1 POU4F1 POU4F3 POU4F3 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTF1A PTF1A RAD21 RAD21 RARA RARA REST REST RFX2 RFX2 RFX5 RFX5 RHOXF2 RHOXF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RXRA RXRA SALL4 SALL4 SETDB1 SETDB1 SIN3A SIN3A SIRT6 SIRT6 SIX1 SIX1 SIX5 SIX5 SMAD2 SMAD2 SMAD3 SMAD3 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX6 SOX6 SOX7 SOX7 SOX9 SOX9 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 SREBF2 SREBF2 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A TAL1 TAL1 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFAP2C TFAP2C TFAP4 TFAP4 TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 THAP1 THAP1 THAP11 THAP11 TLX3 TLX3 TP53 TP53 TP73 TRIM28 USF1 USF1 VAX1 VAX1 VDR VDR YY1 YY1 ZFP57 ZFP57 ZIC1 ZIC1 ZIC3 ZIC3 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF274 ZNF274 ZNF713 ZNF713 ZSCAN4 ZSCAN4 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 CBFB DBX1 DBX1 DBX2 DBX2 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 FOXE1 FOXE1 HMGA1 HMGA1 HOXA1 HOXA1 LBX2 LBX2 MYCN MYCN NFIA NFIA NFYA NFYA OSR1 OSR1 POU3F4 POU3F4 SRF SRF TCF15 TCF15 TEF TEF ZNF384 ZNF384 ZNF384 ZNF384
# Working on results/clusterSpecific_v1/2.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/6 [00:00<?, ?it/s]
# inferring GRN for 0...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 1...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 2...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 3...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 4...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 5...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in 0
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 1
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 2
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 3
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 4
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 5
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# Predicting ZNF384
# ALX3 ALX3 ALX4 ALX4 AR AR ARID3A ARID3A ARNT2 ARNT2 ASCL1 ASCL1 ASCL2 ASCL2 ATF2 ATF2 ATF3 ATF3 ATOH1 ATOH1 BACH1 BACH1 BARX2 BARX2 BATF BATF BHLHE40 BHLHE40 BRF2 BRF2 CDX2 CDX2 CDX2 CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CREB1 CREB1 CREB3 CREB3 CTCF CTCFL CTCFL CUX1 CUX1 DLX5 DLX5 DMRT1 DMRT1 E2F1 E2F1 E2F6 E2F6 E2F7 E2F7 EBF1 EBF1 EGR2 EGR2 EHF EHF ELF1 ELF1 ELF2 ELF2 ELF4 ELF5 ELF5 ELK3 ELK3 EN1 EN1 EOMES EOMES ERG ERG ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETV1 ETV1 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 FEV FEV FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOSL2 FOSL2 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXD1 FOXD1 FOXD3 FOXD3 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXF1 FOXF1 FOXG1 FOXG1 FOXH1 FOXH1 FOXJ1 FOXJ1 FOXL2 FOXL2 FOXN3 FOXN3 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GATA3 GATA3 GLI1 GLI1 GLIS2 GLIS2 GRHL2 GRHL2 GSC GSC GTF3C2 GTF3C2 HDAC2 HDAC2 HES1 HES1 HESX1 HESX1 HMGA2 HMGA2 HNF4A HNF4A HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXC9 HOXC9 HOXD1 HOXD1 HOXD10 HOXD10 HOXD13 HOXD13 HOXD3 HOXD3 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF2 IRF2 IRF5 IRF5 IRX2 IRX2 ISL1 ISL1 ISL2 ISL2 JUNB JUNB JUNB JUND JUND KLF1 KLF1 KLF11 KLF11 KLF12 KLF14 KLF14 KLF15 KLF15 KLF2 KLF2 KLF3 KLF3 KLF4 KLF4 KLF5 KLF5 KLF8 KLF8 KLF9 KLF9 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LMO2 LMO2 MAFK MAFK MEF2A MEF2A MEF2C MEF2C MEIS1 MEIS1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MYBL2 MYBL2 MYC MYC MYF5 MYF5 MYOD1 MYOD1 NEUROD1 NEUROD1 NEUROD2 NEUROD2 NEUROD4 NEUROD4 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NR4A3 NR4A3 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PAX5 PAX5 PAX8 PAX8 PBX1 PBX1 PDX1 PDX1 PITX2 PITX2 POLR3A POLR3A POU2F2 POU2F2 POU4F1 POU4F1 POU4F3 POU4F3 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTF1A PTF1A RAD21 RAD21 RARA RARA REST REST RFX2 RFX2 RFX5 RFX5 RHOXF2 RHOXF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RXRA RXRA SALL4 SALL4 SETDB1 SETDB1 SIN3A SIN3A SIRT6 SIRT6 SIX1 SIX1 SIX5 SIX5 SMAD2 SMAD2 SMAD3 SMAD3 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX6 SOX6 SOX7 SOX7 SOX9 SOX9 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 SREBF2 SREBF2 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A TAL1 TAL1 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFAP2C TFAP2C TFAP4 TFAP4 TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 THAP1 THAP1 THAP11 THAP11 TLX3 TLX3 TP53 TP53 TP73 TRIM28 USF1 USF1 VAX1 VAX1 VDR VDR YY1 YY1 ZFP57 ZFP57 ZIC1 ZIC1 ZIC3 ZIC3 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF274 ZNF274 ZNF713 ZNF713 ZSCAN4 ZSCAN4 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 CBFB DBX1 DBX1 DBX2 DBX2 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 FOXE1 FOXE1 HMGA1 HMGA1 HOXA1 HOXA1 LBX2 LBX2 MYCN MYCN NFIA NFIA NFYA NFYA OSR1 OSR1 POU3F4 POU3F4 SRF SRF TCF15 TCF15 TEF TEF ZNF384 ZNF384 ZNF384 ZNF384
# Working on results/clusterSpecific_v1/3.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/9 [00:00<?, ?it/s]
# inferring GRN for 0...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 1...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 2...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 3...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 4...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 5...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 6...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 7...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 8...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in 0
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 1
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 2
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 3
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 4
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 5
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 6
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 7
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 8
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# Predicting ZNF384
# ALX3 ALX3 ALX4 ALX4 AR AR ARID3A ARID3A ARNT2 ARNT2 ASCL1 ASCL1 ASCL2 ASCL2 ATF2 ATF2 ATF3 ATF3 ATOH1 ATOH1 BACH1 BACH1 BARX2 BARX2 BATF BATF BHLHE40 BHLHE40 BRF2 BRF2 CDX2 CDX2 CDX2 CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CREB1 CREB1 CREB3 CREB3 CTCF CTCFL CTCFL CUX1 CUX1 DLX5 DLX5 DMRT1 DMRT1 E2F1 E2F1 E2F6 E2F6 E2F7 E2F7 EBF1 EBF1 EGR2 EGR2 EHF EHF ELF1 ELF1 ELF2 ELF2 ELF4 ELF5 ELF5 ELK3 ELK3 EN1 EN1 EOMES EOMES ERG ERG ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETV1 ETV1 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 FEV FEV FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOSL2 FOSL2 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXD1 FOXD1 FOXD3 FOXD3 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXF1 FOXF1 FOXG1 FOXG1 FOXH1 FOXH1 FOXJ1 FOXJ1 FOXL2 FOXL2 FOXN3 FOXN3 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GATA3 GATA3 GLI1 GLI1 GLIS2 GLIS2 GRHL2 GRHL2 GSC GSC GTF3C2 GTF3C2 HDAC2 HDAC2 HES1 HES1 HESX1 HESX1 HMGA2 HMGA2 HNF4A HNF4A HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXC9 HOXC9 HOXD1 HOXD1 HOXD10 HOXD10 HOXD13 HOXD13 HOXD3 HOXD3 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF2 IRF2 IRF5 IRF5 IRX2 IRX2 ISL1 ISL1 ISL2 ISL2 JUNB JUNB JUNB JUND JUND KLF1 KLF1 KLF11 KLF11 KLF12 KLF14 KLF14 KLF15 KLF15 KLF2 KLF2 KLF3 KLF3 KLF4 KLF4 KLF5 KLF5 KLF8 KLF8 KLF9 KLF9 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LMO2 LMO2 MAFK MAFK MEF2A MEF2A MEF2C MEF2C MEIS1 MEIS1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MYBL2 MYBL2 MYC MYC MYF5 MYF5 MYOD1 MYOD1 NEUROD1 NEUROD1 NEUROD2 NEUROD2 NEUROD4 NEUROD4 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NR4A3 NR4A3 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PAX5 PAX5 PAX8 PAX8 PBX1 PBX1 PDX1 PDX1 PITX2 PITX2 POLR3A POLR3A POU2F2 POU2F2 POU4F1 POU4F1 POU4F3 POU4F3 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTF1A PTF1A RAD21 RAD21 RARA RARA REST REST RFX2 RFX2 RFX5 RFX5 RHOXF2 RHOXF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RXRA RXRA SALL4 SALL4 SETDB1 SETDB1 SIN3A SIN3A SIRT6 SIRT6 SIX1 SIX1 SIX5 SIX5 SMAD2 SMAD2 SMAD3 SMAD3 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX6 SOX6 SOX7 SOX7 SOX9 SOX9 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 SREBF2 SREBF2 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A TAL1 TAL1 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFAP2C TFAP2C TFAP4 TFAP4 TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 THAP1 THAP1 THAP11 THAP11 TLX3 TLX3 TP53 TP53 TP73 TRIM28 USF1 USF1 VAX1 VAX1 VDR VDR YY1 YY1 ZFP57 ZFP57 ZIC1 ZIC1 ZIC3 ZIC3 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF274 ZNF274 ZNF713 ZNF713 ZSCAN4 ZSCAN4 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 CBFB DBX1 DBX1 DBX2 DBX2 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 FOXE1 FOXE1 HMGA1 HMGA1 HOXA1 HOXA1 LBX2 LBX2 MYCN MYCN NFIA NFIA NFYA NFYA OSR1 OSR1 POU3F4 POU3F4 SRF SRF TCF15 TCF15 TEF TEF ZNF384 ZNF384 ZNF384 ZNF384
# Working on results/clusterSpecific_v1/4.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/11 [00:00<?, ?it/s]
# inferring GRN for 0...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 1...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 10...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 2...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 3...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 4...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 5...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 6...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 7...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 8...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 9...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in 0
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 1
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 10
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 2
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 3
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 4
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 5
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 6
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 7
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 8
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 9
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# Predicting ZNF384
# ALX3 ALX3 ALX4 ALX4 AR AR ARID3A ARID3A ARNT2 ARNT2 ASCL1 ASCL1 ASCL2 ASCL2 ATF2 ATF2 ATF3 ATF3 ATOH1 ATOH1 BACH1 BACH1 BARX2 BARX2 BATF BATF BHLHE40 BHLHE40 BRF2 BRF2 CDX2 CDX2 CDX2 CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CREB1 CREB1 CREB3 CREB3 CTCF CTCFL CTCFL CUX1 CUX1 DLX5 DLX5 DMRT1 DMRT1 E2F1 E2F1 E2F6 E2F6 E2F7 E2F7 EBF1 EBF1 EGR2 EGR2 EHF EHF ELF1 ELF1 ELF2 ELF2 ELF4 ELF5 ELF5 ELK3 ELK3 EN1 EN1 EOMES EOMES ERG ERG ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETV1 ETV1 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 FEV FEV FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOSL2 FOSL2 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXD1 FOXD1 FOXD3 FOXD3 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXF1 FOXF1 FOXG1 FOXG1 FOXH1 FOXH1 FOXJ1 FOXJ1 FOXL2 FOXL2 FOXN3 FOXN3 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GATA3 GATA3 GLI1 GLI1 GLIS2 GLIS2 GRHL2 GRHL2 GSC GSC GTF3C2 GTF3C2 HDAC2 HDAC2 HES1 HES1 HESX1 HESX1 HMGA2 HMGA2 HNF4A HNF4A HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXC9 HOXC9 HOXD1 HOXD1 HOXD10 HOXD10 HOXD13 HOXD13 HOXD3 HOXD3 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF2 IRF2 IRF5 IRF5 IRX2 IRX2 ISL1 ISL1 ISL2 ISL2 JUNB JUNB JUNB JUND JUND KLF1 KLF1 KLF11 KLF11 KLF12 KLF14 KLF14 KLF15 KLF15 KLF2 KLF2 KLF3 KLF3 KLF4 KLF4 KLF5 KLF5 KLF8 KLF8 KLF9 KLF9 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LMO2 LMO2 MAFK MAFK MEF2A MEF2A MEF2C MEF2C MEIS1 MEIS1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MYBL2 MYBL2 MYC MYC MYF5 MYF5 MYOD1 MYOD1 NEUROD1 NEUROD1 NEUROD2 NEUROD2 NEUROD4 NEUROD4 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NR4A3 NR4A3 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PAX5 PAX5 PAX8 PAX8 PBX1 PBX1 PDX1 PDX1 PITX2 PITX2 POLR3A POLR3A POU2F2 POU2F2 POU4F1 POU4F1 POU4F3 POU4F3 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTF1A PTF1A RAD21 RAD21 RARA RARA REST REST RFX2 RFX2 RFX5 RFX5 RHOXF2 RHOXF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RXRA RXRA SALL4 SALL4 SETDB1 SETDB1 SIN3A SIN3A SIRT6 SIRT6 SIX1 SIX1 SIX5 SIX5 SMAD2 SMAD2 SMAD3 SMAD3 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX6 SOX6 SOX7 SOX7 SOX9 SOX9 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 SREBF2 SREBF2 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A TAL1 TAL1 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFAP2C TFAP2C TFAP4 TFAP4 TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 THAP1 THAP1 THAP11 THAP11 TLX3 TLX3 TP53 TP53 TP73 TRIM28 USF1 USF1 VAX1 VAX1 VDR VDR YY1 YY1 ZFP57 ZFP57 ZIC1 ZIC1 ZIC3 ZIC3 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF274 ZNF274 ZNF713 ZNF713 ZSCAN4 ZSCAN4 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 CBFB DBX1 DBX1 DBX2 DBX2 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 FOXE1 FOXE1 HMGA1 HMGA1 HOXA1 HOXA1 LBX2 LBX2 MYCN MYCN NFIA NFIA NFYA NFYA OSR1 OSR1 POU3F4 POU3F4 SRF SRF TCF15 TCF15 TEF TEF ZNF384 ZNF384 ZNF384 ZNF384
# Working on results/clusterSpecific_v1/5.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/1 [00:00<?, ?it/s]
# inferring GRN for 0...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in 0
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# Predicting ZNF384
# ALX3 ALX3 ALX4 ALX4 AR AR ARID3A ARID3A ARNT2 ARNT2 ASCL1 ASCL1 ASCL2 ASCL2 ATF2 ATF2 ATF3 ATF3 ATOH1 ATOH1 BACH1 BACH1 BARX2 BARX2 BATF BATF BHLHE40 BHLHE40 BRF2 BRF2 CDX2 CDX2 CDX2 CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CREB1 CREB1 CREB3 CREB3 CTCF CTCFL CTCFL CUX1 CUX1 DLX5 DLX5 DMRT1 DMRT1 E2F1 E2F1 E2F6 E2F6 E2F7 E2F7 EBF1 EBF1 EGR2 EGR2 EHF EHF ELF1 ELF1 ELF2 ELF2 ELF4 ELF5 ELF5 ELK3 ELK3 EN1 EN1 EOMES EOMES ERG ERG ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETV1 ETV1 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 FEV FEV FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOSL2 FOSL2 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXD1 FOXD1 FOXD3 FOXD3 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXF1 FOXF1 FOXG1 FOXG1 FOXH1 FOXH1 FOXJ1 FOXJ1 FOXL2 FOXL2 FOXN3 FOXN3 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GATA3 GATA3 GLI1 GLI1 GLIS2 GLIS2 GRHL2 GRHL2 GSC GSC GTF3C2 GTF3C2 HDAC2 HDAC2 HES1 HES1 HESX1 HESX1 HMGA2 HMGA2 HNF4A HNF4A HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXC9 HOXC9 HOXD1 HOXD1 HOXD10 HOXD10 HOXD13 HOXD13 HOXD3 HOXD3 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF2 IRF2 IRF5 IRF5 IRX2 IRX2 ISL1 ISL1 ISL2 ISL2 JUNB JUNB JUNB JUND JUND KLF1 KLF1 KLF11 KLF11 KLF12 KLF14 KLF14 KLF15 KLF15 KLF2 KLF2 KLF3 KLF3 KLF4 KLF4 KLF5 KLF5 KLF8 KLF8 KLF9 KLF9 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LMO2 LMO2 MAFK MAFK MEF2A MEF2A MEF2C MEF2C MEIS1 MEIS1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MYBL2 MYBL2 MYC MYC MYF5 MYF5 MYOD1 MYOD1 NEUROD1 NEUROD1 NEUROD2 NEUROD2 NEUROD4 NEUROD4 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NR4A3 NR4A3 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PAX5 PAX5 PAX8 PAX8 PBX1 PBX1 PDX1 PDX1 PITX2 PITX2 POLR3A POLR3A POU2F2 POU2F2 POU4F1 POU4F1 POU4F3 POU4F3 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTF1A PTF1A RAD21 RAD21 RARA RARA REST REST RFX2 RFX2 RFX5 RFX5 RHOXF2 RHOXF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RXRA RXRA SALL4 SALL4 SETDB1 SETDB1 SIN3A SIN3A SIRT6 SIRT6 SIX1 SIX1 SIX5 SIX5 SMAD2 SMAD2 SMAD3 SMAD3 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX6 SOX6 SOX7 SOX7 SOX9 SOX9 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 SREBF2 SREBF2 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A TAL1 TAL1 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFAP2C TFAP2C TFAP4 TFAP4 TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 THAP1 THAP1 THAP11 THAP11 TLX3 TLX3 TP53 TP53 TP73 TRIM28 USF1 USF1 VAX1 VAX1 VDR VDR YY1 YY1 ZFP57 ZFP57 ZIC1 ZIC1 ZIC3 ZIC3 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF274 ZNF274 ZNF713 ZNF713 ZSCAN4 ZSCAN4 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 CBFB DBX1 DBX1 DBX2 DBX2 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 FOXE1 FOXE1 HMGA1 HMGA1 HOXA1 HOXA1 LBX2 LBX2 MYCN MYCN NFIA NFIA NFYA NFYA OSR1 OSR1 POU3F4 POU3F4 SRF SRF TCF15 TCF15 TEF TEF ZNF384 ZNF384 ZNF384 ZNF384
# Working on results/clusterSpecific_v1/6.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/3 [00:00<?, ?it/s]
# inferring GRN for 0...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 1...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 2...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in 0
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 1
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 2
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# Predicting ZNF384
# ALX3 ALX3 ALX4 ALX4 AR AR ARID3A ARID3A ARNT2 ARNT2 ASCL1 ASCL1 ASCL2 ASCL2 ATF2 ATF2 ATF3 ATF3 ATOH1 ATOH1 BACH1 BACH1 BARX2 BARX2 BATF BATF BHLHE40 BHLHE40 BRF2 BRF2 CDX2 CDX2 CDX2 CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CREB1 CREB1 CREB3 CREB3 CTCF CTCFL CTCFL CUX1 CUX1 DLX5 DLX5 DMRT1 DMRT1 E2F1 E2F1 E2F6 E2F6 E2F7 E2F7 EBF1 EBF1 EGR2 EGR2 EHF EHF ELF1 ELF1 ELF2 ELF2 ELF4 ELF5 ELF5 ELK3 ELK3 EN1 EN1 EOMES EOMES ERG ERG ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETV1 ETV1 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 FEV FEV FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOSL2 FOSL2 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXD1 FOXD1 FOXD3 FOXD3 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXF1 FOXF1 FOXG1 FOXG1 FOXH1 FOXH1 FOXJ1 FOXJ1 FOXL2 FOXL2 FOXN3 FOXN3 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GATA3 GATA3 GLI1 GLI1 GLIS2 GLIS2 GRHL2 GRHL2 GSC GSC GTF3C2 GTF3C2 HDAC2 HDAC2 HES1 HES1 HESX1 HESX1 HMGA2 HMGA2 HNF4A HNF4A HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXC9 HOXC9 HOXD1 HOXD1 HOXD10 HOXD10 HOXD13 HOXD13 HOXD3 HOXD3 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF2 IRF2 IRF5 IRF5 IRX2 IRX2 ISL1 ISL1 ISL2 ISL2 JUNB JUNB JUNB JUND JUND KLF1 KLF1 KLF11 KLF11 KLF12 KLF14 KLF14 KLF15 KLF15 KLF2 KLF2 KLF3 KLF3 KLF4 KLF4 KLF5 KLF5 KLF8 KLF8 KLF9 KLF9 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LMO2 LMO2 MAFK MAFK MEF2A MEF2A MEF2C MEF2C MEIS1 MEIS1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MYBL2 MYBL2 MYC MYC MYF5 MYF5 MYOD1 MYOD1 NEUROD1 NEUROD1 NEUROD2 NEUROD2 NEUROD4 NEUROD4 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NR4A3 NR4A3 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PAX5 PAX5 PAX8 PAX8 PBX1 PBX1 PDX1 PDX1 PITX2 PITX2 POLR3A POLR3A POU2F2 POU2F2 POU4F1 POU4F1 POU4F3 POU4F3 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTF1A PTF1A RAD21 RAD21 RARA RARA REST REST RFX2 RFX2 RFX5 RFX5 RHOXF2 RHOXF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RXRA RXRA SALL4 SALL4 SETDB1 SETDB1 SIN3A SIN3A SIRT6 SIRT6 SIX1 SIX1 SIX5 SIX5 SMAD2 SMAD2 SMAD3 SMAD3 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX6 SOX6 SOX7 SOX7 SOX9 SOX9 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 SREBF2 SREBF2 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A TAL1 TAL1 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFAP2C TFAP2C TFAP4 TFAP4 TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 THAP1 THAP1 THAP11 THAP11 TLX3 TLX3 TP53 TP53 TP73 TRIM28 USF1 USF1 VAX1 VAX1 VDR VDR YY1 YY1 ZFP57 ZFP57 ZIC1 ZIC1 ZIC3 ZIC3 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF274 ZNF274 ZNF713 ZNF713 ZSCAN4 ZSCAN4 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 CBFB DBX1 DBX1 DBX2 DBX2 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 FOXE1 FOXE1 HMGA1 HMGA1 HOXA1 HOXA1 LBX2 LBX2 MYCN MYCN NFIA NFIA NFYA NFYA OSR1 OSR1 POU3F4 POU3F4 SRF SRF TCF15 TCF15 TEF TEF ZNF384 ZNF384 ZNF384 ZNF384
# Working on results/clusterSpecific_v1/7.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/6 [00:00<?, ?it/s]
# inferring GRN for 0...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 1...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 2...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 3...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 4...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 5...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in 0
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 1
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 2
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 3
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 4
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 5
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# Predicting ZNF384
# ALX3 ALX3 ALX4 ALX4 AR AR ARID3A ARID3A ARNT2 ARNT2 ASCL1 ASCL1 ASCL2 ASCL2 ATF2 ATF2 ATF3 ATF3 ATOH1 ATOH1 BACH1 BACH1 BARX2 BARX2 BATF BATF BHLHE40 BHLHE40 BRF2 BRF2 CDX2 CDX2 CDX2 CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CREB1 CREB1 CREB3 CREB3 CTCF CTCFL CTCFL CUX1 CUX1 DLX5 DLX5 DMRT1 DMRT1 E2F1 E2F1 E2F6 E2F6 E2F7 E2F7 EBF1 EBF1 EGR2 EGR2 EHF EHF ELF1 ELF1 ELF2 ELF2 ELF4 ELF5 ELF5 ELK3 ELK3 EN1 EN1 EOMES EOMES ERG ERG ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETV1 ETV1 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 FEV FEV FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOSL2 FOSL2 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXD1 FOXD1 FOXD3 FOXD3 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXF1 FOXF1 FOXG1 FOXG1 FOXH1 FOXH1 FOXJ1 FOXJ1 FOXL2 FOXL2 FOXN3 FOXN3 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GATA3 GATA3 GLI1 GLI1 GLIS2 GLIS2 GRHL2 GRHL2 GSC GSC GTF3C2 GTF3C2 HDAC2 HDAC2 HES1 HES1 HESX1 HESX1 HMGA2 HMGA2 HNF4A HNF4A HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXC9 HOXC9 HOXD1 HOXD1 HOXD10 HOXD10 HOXD13 HOXD13 HOXD3 HOXD3 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF2 IRF2 IRF5 IRF5 IRX2 IRX2 ISL1 ISL1 ISL2 ISL2 JUNB JUNB JUNB JUND JUND KLF1 KLF1 KLF11 KLF11 KLF12 KLF14 KLF14 KLF15 KLF15 KLF2 KLF2 KLF3 KLF3 KLF4 KLF4 KLF5 KLF5 KLF8 KLF8 KLF9 KLF9 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LMO2 LMO2 MAFK MAFK MEF2A MEF2A MEF2C MEF2C MEIS1 MEIS1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MYBL2 MYBL2 MYC MYC MYF5 MYF5 MYOD1 MYOD1 NEUROD1 NEUROD1 NEUROD2 NEUROD2 NEUROD4 NEUROD4 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NR4A3 NR4A3 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PAX5 PAX5 PAX8 PAX8 PBX1 PBX1 PDX1 PDX1 PITX2 PITX2 POLR3A POLR3A POU2F2 POU2F2 POU4F1 POU4F1 POU4F3 POU4F3 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTF1A PTF1A RAD21 RAD21 RARA RARA REST REST RFX2 RFX2 RFX5 RFX5 RHOXF2 RHOXF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RXRA RXRA SALL4 SALL4 SETDB1 SETDB1 SIN3A SIN3A SIRT6 SIRT6 SIX1 SIX1 SIX5 SIX5 SMAD2 SMAD2 SMAD3 SMAD3 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX6 SOX6 SOX7 SOX7 SOX9 SOX9 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 SREBF2 SREBF2 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A TAL1 TAL1 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFAP2C TFAP2C TFAP4 TFAP4 TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 THAP1 THAP1 THAP11 THAP11 TLX3 TLX3 TP53 TP53 TP73 TRIM28 USF1 USF1 VAX1 VAX1 VDR VDR YY1 YY1 ZFP57 ZFP57 ZIC1 ZIC1 ZIC3 ZIC3 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF274 ZNF274 ZNF713 ZNF713 ZSCAN4 ZSCAN4 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 CBFB DBX1 DBX1 DBX2 DBX2 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 FOXE1 FOXE1 HMGA1 HMGA1 HOXA1 HOXA1 LBX2 LBX2 MYCN MYCN NFIA NFIA NFYA NFYA OSR1 OSR1 POU3F4 POU3F4 SRF SRF TCF15 TCF15 TEF TEF ZNF384 ZNF384 ZNF384 ZNF384
# Working on results/clusterSpecific_v1/8.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/9 [00:00<?, ?it/s]
# inferring GRN for 0...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 1...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 2...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 3...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 4...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 5...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 6...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 7...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 8...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in 0
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 1
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 2
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 3
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 4
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 5
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 6
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 7
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# calculating GRN in 8
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# Predicting ZNF384
# ALX3 ALX3 ALX4 ALX4 AR AR ARID3A ARID3A ARNT2 ARNT2 ASCL1 ASCL1 ASCL2 ASCL2 ATF2 ATF2 ATF3 ATF3 ATOH1 ATOH1 BACH1 BACH1 BARX2 BARX2 BATF BATF BHLHE40 BHLHE40 BRF2 BRF2 CDX2 CDX2 CDX2 CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CREB1 CREB1 CREB3 CREB3 CTCF CTCFL CTCFL CUX1 CUX1 DLX5 DLX5 DMRT1 DMRT1 E2F1 E2F1 E2F6 E2F6 E2F7 E2F7 EBF1 EBF1 EGR2 EGR2 EHF EHF ELF1 ELF1 ELF2 ELF2 ELF4 ELF5 ELF5 ELK3 ELK3 EN1 EN1 EOMES EOMES ERG ERG ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETV1 ETV1 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 FEV FEV FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOSL2 FOSL2 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXD1 FOXD1 FOXD3 FOXD3 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXF1 FOXF1 FOXG1 FOXG1 FOXH1 FOXH1 FOXJ1 FOXJ1 FOXL2 FOXL2 FOXN3 FOXN3 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GATA3 GATA3 GLI1 GLI1 GLIS2 GLIS2 GRHL2 GRHL2 GSC GSC GTF3C2 GTF3C2 HDAC2 HDAC2 HES1 HES1 HESX1 HESX1 HMGA2 HMGA2 HNF4A HNF4A HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXC9 HOXC9 HOXD1 HOXD1 HOXD10 HOXD10 HOXD13 HOXD13 HOXD3 HOXD3 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF2 IRF2 IRF5 IRF5 IRX2 IRX2 ISL1 ISL1 ISL2 ISL2 JUNB JUNB JUNB JUND JUND KLF1 KLF1 KLF11 KLF11 KLF12 KLF14 KLF14 KLF15 KLF15 KLF2 KLF2 KLF3 KLF3 KLF4 KLF4 KLF5 KLF5 KLF8 KLF8 KLF9 KLF9 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LMO2 LMO2 MAFK MAFK MEF2A MEF2A MEF2C MEF2C MEIS1 MEIS1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MYBL2 MYBL2 MYC MYC MYF5 MYF5 MYOD1 MYOD1 NEUROD1 NEUROD1 NEUROD2 NEUROD2 NEUROD4 NEUROD4 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NR4A3 NR4A3 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PAX5 PAX5 PAX8 PAX8 PBX1 PBX1 PDX1 PDX1 PITX2 PITX2 POLR3A POLR3A POU2F2 POU2F2 POU4F1 POU4F1 POU4F3 POU4F3 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTF1A PTF1A RAD21 RAD21 RARA RARA REST REST RFX2 RFX2 RFX5 RFX5 RHOXF2 RHOXF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RXRA RXRA SALL4 SALL4 SETDB1 SETDB1 SIN3A SIN3A SIRT6 SIRT6 SIX1 SIX1 SIX5 SIX5 SMAD2 SMAD2 SMAD3 SMAD3 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX6 SOX6 SOX7 SOX7 SOX9 SOX9 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 SREBF2 SREBF2 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A TAL1 TAL1 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFAP2C TFAP2C TFAP4 TFAP4 TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 THAP1 THAP1 THAP11 THAP11 TLX3 TLX3 TP53 TP53 TP73 TRIM28 USF1 USF1 VAX1 VAX1 VDR VDR YY1 YY1 ZFP57 ZFP57 ZIC1 ZIC1 ZIC3 ZIC3 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF274 ZNF274 ZNF713 ZNF713 ZSCAN4 ZSCAN4 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 CBFB DBX1 DBX1 DBX2 DBX2 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 FOXE1 FOXE1 HMGA1 HMGA1 HOXA1 HOXA1 LBX2 LBX2 MYCN MYCN NFIA NFIA NFYA NFYA OSR1 OSR1 POU3F4 POU3F4 SRF SRF TCF15 TCF15 TEF TEF ZNF384 ZNF384 ZNF384 ZNF384
# Working on results/clusterSpecific_v1/9.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/11 [00:00<?, ?it/s]
# inferring GRN for 0...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 1...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 10...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 2...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 3...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 4...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 5...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 6...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 7...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 8...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# inferring GRN for 9...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in 0
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 1
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 10
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 2
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 3
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 4
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 5
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 6
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 7
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 8
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# calculating GRN in 9
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# Predicting ZNF384
# ALX3 ALX3 ALX4 ALX4 AR AR ARID3A ARID3A ARNT2 ARNT2 ASCL1 ASCL1 ASCL2 ASCL2 ATF2 ATF2 ATF3 ATF3 ATOH1 ATOH1 BACH1 BACH1 BARX2 BARX2 BATF BATF BHLHE40 BHLHE40 BRF2 BRF2 CDX2 CDX2 CDX2 CEBPA CEBPA CEBPB CEBPB CEBPD CEBPD CREB1 CREB1 CREB3 CREB3 CTCF CTCFL CTCFL CUX1 CUX1 DLX5 DLX5 DMRT1 DMRT1 E2F1 E2F1 E2F6 E2F6 E2F7 E2F7 EBF1 EBF1 EGR2 EGR2 EHF EHF ELF1 ELF1 ELF2 ELF2 ELF4 ELF5 ELF5 ELK3 ELK3 EN1 EN1 EOMES EOMES ERG ERG ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETV1 ETV1 ETV2 ETV2 ETV3 ETV3 ETV5 ETV5 FEV FEV FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOSL2 FOSL2 FOXA1 FOXA1 FOXA2 FOXA2 FOXB1 FOXB1 FOXD1 FOXD1 FOXD3 FOXD3 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXF1 FOXF1 FOXG1 FOXG1 FOXH1 FOXH1 FOXJ1 FOXJ1 FOXL2 FOXL2 FOXN3 FOXN3 FOXO3 FOXO3 FOXP1 FOXP1 FOXP1 FOXP3 FOXP3 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GATA3 GATA3 GLI1 GLI1 GLIS2 GLIS2 GRHL2 GRHL2 GSC GSC GTF3C2 GTF3C2 HDAC2 HDAC2 HES1 HES1 HESX1 HESX1 HMGA2 HMGA2 HNF4A HNF4A HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXC9 HOXC9 HOXD1 HOXD1 HOXD10 HOXD10 HOXD13 HOXD13 HOXD3 HOXD3 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF2 IRF2 IRF5 IRF5 IRX2 IRX2 ISL1 ISL1 ISL2 ISL2 JUNB JUNB JUNB JUND JUND KLF1 KLF1 KLF11 KLF11 KLF12 KLF14 KLF14 KLF15 KLF15 KLF2 KLF2 KLF3 KLF3 KLF4 KLF4 KLF5 KLF5 KLF8 KLF8 KLF9 KLF9 LHX1 LHX1 LHX2 LHX2 LHX3 LHX3 LHX4 LHX4 LMO2 LMO2 MAFK MAFK MEF2A MEF2A MEF2C MEF2C MEIS1 MEIS1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MYBL2 MYBL2 MYC MYC MYF5 MYF5 MYOD1 MYOD1 NEUROD1 NEUROD1 NEUROD2 NEUROD2 NEUROD4 NEUROD4 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NEUROG3 NEUROG3 NFATC1 NFATC1 NFE2L1 NFIB NFIB NFIC NFIC NKX2-1 NKX2-1 NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NPAS2 NPAS2 NR1D2 NR1D2 NR2E1 NR2E1 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NR4A3 NR4A3 NRF1 NRF1 OLIG1 OLIG1 OLIG2 OLIG2 OTP OTP OTX1 OTX1 OTX2 OTX2 OVOL2 OVOL2 PAX5 PAX5 PAX8 PAX8 PBX1 PBX1 PDX1 PDX1 PITX2 PITX2 POLR3A POLR3A POU2F2 POU2F2 POU4F1 POU4F1 POU4F3 POU4F3 PPARG PPARG PPARGC1A PPARGC1A PRDM1 PRDM1 PTF1A PTF1A RAD21 RAD21 RARA RARA REST REST RFX2 RFX2 RFX5 RFX5 RHOXF2 RHOXF2 RREB1 RREB1 RUNX1 RUNX1 RUNX3 RUNX3 RXRA RXRA SALL4 SALL4 SETDB1 SETDB1 SIN3A SIN3A SIRT6 SIRT6 SIX1 SIX1 SIX5 SIX5 SMAD2 SMAD2 SMAD3 SMAD3 SMARCB1 SMARCB1 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SNAI3 SNAI3 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX6 SOX6 SOX7 SOX7 SOX9 SOX9 SPI1 SPI1 SPIB SPIB SPIC SPIC SPIC SPZ1 SPZ1 SREBF2 SREBF2 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A TAL1 TAL1 TBX2 TBX2 TBX3 TBX3 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF23 TCF23 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFAP2C TFAP2C TFAP4 TFAP4 TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 THAP1 THAP1 THAP11 THAP11 TLX3 TLX3 TP53 TP53 TP73 TRIM28 USF1 USF1 VAX1 VAX1 VDR VDR YY1 YY1 ZFP57 ZFP57 ZIC1 ZIC1 ZIC3 ZIC3 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF274 ZNF274 ZNF713 ZNF713 ZSCAN4 ZSCAN4 ALX1 ALX1 ARID3B ARID3B ATF4 ATF4 CBFB DBX1 DBX1 DBX2 DBX2 E2F3 E2F3 E2F5 E2F5 EMX2 EMX2 FOXE1 FOXE1 HMGA1 HMGA1 HOXA1 HOXA1 LBX2 LBX2 MYCN MYCN NFIA NFIA NFYA NFYA OSR1 OSR1 POU3F4 POU3F4 SRF SRF TCF15 TCF15 TEF TEF ZNF384 ZNF384 ZNF384 ZNF384

# %%
predictions[0]
# Out:
# {'ALX3': ArrayView([0.18082665, 0.74215583, 0.47992207, ..., 1.40367105,
#             0.46909222, 0.58120591]),
#  'ALX4': ArrayView([0.19045539, 0.74306295, 0.48582042, ..., 1.40425116,
#             0.46877906, 0.58187577]),
#  'AR': ArrayView([0.16373922, 0.74914977, 0.49064938, ..., 1.40414385,
#             0.4646936 , 0.57854438]),
#  'ARID3A': ArrayView([0.1951145 , 0.71581857, 0.43473277, ..., 1.40107129,
#             0.48440655, 0.55340253]),
#  'ARNT2': ArrayView([0.22072898, 0.71939478, 0.46300221, ..., 1.39979177,
#             0.46019013, 0.6060639 ]),
#  'ASCL1': ArrayView([0.18719252, 0.7372036 , 0.48328278, ..., 1.40291906,
#             0.4715608 , 0.58508465]),
#  'ASCL2': ArrayView([0.18017329, 0.74479302, 0.48419076, ..., 1.4037699 ,
#             0.46764413, 0.58030376]),
#  'ATF2': ArrayView([0.16562766, 0.7705618 , 0.48113527, ..., 1.40256003,
#             0.4610194 , 0.58080444]),
#  'ATF3': ArrayView([0.2707518 , 0.69463921, 0.56716896, ..., 1.39850449,
#             0.41535539, 0.59190227]),
#  'ATOH1': ArrayView([0.0859748 , 0.758856  , 0.47872837, ..., 1.39200015,
#             0.43759487, 0.5551667 ]),
#  'BACH1': ArrayView([0.16360465, 0.73383792, 0.5022479 , ..., 1.40481072,
#             0.46223035, 0.58983241]),
#  'BARX2': ArrayView([0.18183963, 0.7439226 , 0.47986911, ..., 1.40052194,
#             0.46465988, 0.57707215]),
#  'BATF': ArrayView([0.17249584, 0.74309526, 0.48887228, ..., 1.4041277 ,
#             0.46916461, 0.5802726 ]),
#  'BHLHE40': ArrayView([0.19030632, 0.72725698, 0.57917826, ..., 1.39428028,
#             0.41483182, 0.56376941]),
#  'BRF2': ArrayView([0.15994614, 0.72792832, 0.59196475, ..., 1.40185535,
#             0.45927014, 0.57634909]),
#  'CDX2': ArrayView([0.10026124, 0.70347233, 0.53584776, ..., 1.398433  ,
#             0.48559657, 0.57743219]),
#  'CEBPA': ArrayView([0.18684501, 0.74147619, 0.49602008, ..., 1.40271216,
#             0.45375447, 0.58296842]),
#  'CEBPB': ArrayView([0.20960965, 0.71883616, 0.49918056, ..., 1.39462235,
#             0.45520447, 0.5534031 ]),
#  'CEBPD': ArrayView([0.19342085, 0.74346411, 0.48513057, ..., 1.40490258,
#             0.46604942, 0.58188494]),
#  'CREB1': ArrayView([0.15540361, 0.77018507, 0.45947485, ..., 1.40620122,
#             0.46982852, 0.58904433]),
#  'CREB3': ArrayView([0.23457643, 0.70697523, 0.47290923, ..., 1.39605292,
#             0.49205163, 0.58056855]),
#  'CTCF': ArrayView([0.04926625, 0.74145162, 0.47587735, ..., 1.39365022,
#             0.42668542, 0.6140101 ]),
#  'CTCFL': ArrayView([0.17359442, 0.73653052, 0.45512971, ..., 1.40511491,
#             0.48265583, 0.57273499]),
#  'CUX1': ArrayView([0.18181362, 0.83135953, 0.44709076, ..., 1.40183584,
#             0.46978002, 0.58349427]),
#  'DLX5': ArrayView([0.02954657, 0.69122101, 0.4517547 , ..., 1.37553344,
#             0.47251083, 0.56435064]),
#  'DMRT1': ArrayView([0.18122538, 0.71338808, 0.49011481, ..., 1.40773116,
#             0.45406195, 0.60516559]),
#  'E2F1': ArrayView([0.1562544 , 0.73510866, 0.44627041, ..., 1.39900529,
#             0.46292444, 0.58031822]),
#  'E2F6': ArrayView([0.18144826, 0.74841827, 0.49650182, ..., 1.40458736,
#             0.47359218, 0.57989222]),
#  'E2F7': ArrayView([0.16294768, 0.75946207, 0.48565903, ..., 1.40146081,
#             0.44931071, 0.5948771 ]),
#  'EBF1': ArrayView([0.18128093, 0.74504176, 0.4829255 , ..., 1.40421711,
#             0.46805004, 0.57927533]),
#  'EGR2': ArrayView([0.17921021, 0.72889126, 0.50576791, ..., 1.40251933,
#             0.46376379, 0.5841579 ]),
#  'EHF': ArrayView([0.18970408, 0.73917379, 0.48244927, ..., 1.40321375,
#             0.47995174, 0.58530351]),
#  'ELF1': ArrayView([0.18741544, 0.71970552, 0.53028083, ..., 1.39935406,
#             0.4883321 , 0.5891782 ]),
#  'ELF2': ArrayView([0.18531233, 0.74924499, 0.4811876 , ..., 1.40471759,
#             0.47091498, 0.58161076]),
#  'ELF4': ArrayView([0.27446934, 0.72156842, 0.49128455, ..., 1.4037325 ,
#             0.47553714, 0.60190796]),
#  'ELF5': ArrayView([0.17084601, 0.74090725, 0.49071544, ..., 1.4046463 ,
#             0.46923298, 0.58258886]),
#  'ELK3': ArrayView([0.13781638, 0.76135504, 0.5363268 , ..., 1.39864432,
#             0.45573026, 0.58604962]),
#  'EN1': ArrayView([0.17907519, 0.73924616, 0.46049191, ..., 1.40452784,
#             0.46418784, 0.59286917]),
#  'EOMES': ArrayView([0.21644646, 0.75420215, 0.46245512, ..., 1.40044192,
#             0.46542154, 0.55607036]),
#  'ERG': ArrayView([0.16673783, 0.74411154, 0.48336306, ..., 1.40335306,
#             0.46898372, 0.58170249]),
#  'ESRRB': ArrayView([0.18874598, 0.72828042, 0.48046238, ..., 1.40603052,
#             0.45149148, 0.58535704]),
#  'ESRRG': ArrayView([0.18506508, 0.74550204, 0.47225222, ..., 1.40301281,
#             0.4733341 , 0.57840054]),
#  'ESX1': ArrayView([0.17297846, 0.74063205, 0.49192205, ..., 1.40244789,
#             0.46746125, 0.58173473]),
#  'ETV1': ArrayView([0.16213006, 0.72589659, 0.46233396, ..., 1.41383374,
#             0.48583544, 0.61447441]),
#  'ETV2': ArrayView([0.17995788, 0.74496198, 0.48243801, ..., 1.4045125 ,
#             0.46915246, 0.57699771]),
#  'ETV3': ArrayView([0.19014943, 0.73832381, 0.4883898 , ..., 1.40501174,
#             0.45663642, 0.58273219]),
#  'ETV5': ArrayView([0.1840039 , 0.74153203, 0.48574462, ..., 1.40360041,
#             0.467089  , 0.57914831]),
#  'FEV': ArrayView([0.18158457, 0.74542924, 0.48309816, ..., 1.40419349,
#             0.46830161, 0.57934491]),
#  'FLI1': ArrayView([0.15279626, 0.74124771, 0.4746437 , ..., 1.40511423,
#             0.45562797, 0.56888267]),
#  'FOS': ArrayView([0.13496923, 0.70126919, 0.56941587, ..., 1.38651495,
#             0.39634382, 0.49216399]),
#  'FOSL1': ArrayView([0.14261692, 0.78155832, 0.58493017, ..., 1.40500133,
#             0.45449024, 0.55714128]),
#  'FOSL2': ArrayView([0.18096779, 0.74229136, 0.48850572, ..., 1.4011073 ,
#             0.4593328 , 0.57458955]),
#  'FOXA1': ArrayView([0.1657289 , 0.73321352, 0.50926685, ..., 1.40061982,
#             0.47074033, 0.58108012]),
#  'FOXA2': ArrayView([0.17012159, 0.7677266 , 0.3997852 , ..., 1.40775223,
#             0.46908186, 0.57301015]),
#  'FOXB1': ArrayView([0.18979743, 0.72886675, 0.46879877, ..., 1.40645579,
#             0.4640427 , 0.6042509 ]),
#  'FOXD1': ArrayView([0.18127526, 0.74527596, 0.48346438, ..., 1.40403655,
#             0.46784649, 0.57950583]),
#  'FOXD3': ArrayView([0.14010719, 0.77227341, 0.46806633, ..., 1.40529297,
#             0.45131528, 0.61021932]),
#  'FOXD4L3': ArrayView([0.18132862, 0.74637501, 0.48246093, ..., 1.40418481,
#             0.46735412, 0.57984313]),
#  'FOXE3': ArrayView([0.19685532, 0.74107495, 0.50167548, ..., 1.40272059,
#             0.46883781, 0.57800199]),
#  'FOXF1': ArrayView([0.21452882, 0.7338179 , 0.49096188, ..., 1.40575251,
#             0.46249996, 0.59019103]),
#  'FOXG1': ArrayView([0.18172515, 0.74470109, 0.48330614, ..., 1.40415047,
#             0.46794681, 0.58027938]),
#  'FOXH1': ArrayView([0.21035556, 0.78151517, 0.43273077, ..., 1.40869095,
#             0.47169514, 0.56893831]),
#  'FOXJ1': ArrayView([0.17737488, 0.76225722, 0.41584007, ..., 1.41102137,
#             0.45656214, 0.61355356]),
#  'FOXL2': ArrayView([0.19425121, 0.73983137, 0.49285744, ..., 1.40214633,
#             0.47068676, 0.58270716]),
#  'FOXN3': ArrayView([0.1790173 , 0.74709156, 0.47757747, ..., 1.40431274,
#             0.46953842, 0.58408326]),
#  'FOXO3': ArrayView([0.19037489, 0.73340092, 0.48000409, ..., 1.40412117,
#             0.47111576, 0.58831511]),
#  'FOXP1': ArrayView([0.11191048, 0.64874585, 0.33731553, ..., 1.40402152,
#             0.58474512, 0.54911899]),
#  'FOXP3': ArrayView([0.18083664, 0.7409046 , 0.4832783 , ..., 1.40412449,
#             0.46758584, 0.58086094]),
#  'GABPA': ArrayView([0.19788196, 0.74274582, 0.46943824, ..., 1.4075981 ,
#             0.46634011, 0.58749593]),
#  'GATA1': ArrayView([0.1808331 , 0.74552884, 0.48391355, ..., 1.40432324,
#             0.46911441, 0.58007969]),
#  'GATA2': ArrayView([0.18585608, 0.72896714, 0.4827834 , ..., 1.40477881,
#             0.45899068, 0.58287807]),
#  'GATA3': ArrayView([0.09891059, 0.65833131, 0.46662649, ..., 1.40085111,
#             0.50388168, 0.55249119]),
#  'GLI1': ArrayView([0.15831929, 0.74420639, 0.48454714, ..., 1.40565533,
#             0.45851816, 0.59974163]),
#  'GLIS2': ArrayView([0.1834892 , 0.74303588, 0.49296736, ..., 1.40512184,
#             0.46998583, 0.57631852]),
#  'GRHL2': ArrayView([0.17318851, 0.75426497, 0.48379101, ..., 1.40319937,
#             0.4670466 , 0.58330769]),
#  'GSC': ArrayView([0.20663033, 0.74265081, 0.47805987, ..., 1.40156787,
#             0.46005656, 0.57250539]),
#  'GTF3C2': ArrayView([0.17782094, 0.70188853, 0.45547966, ..., 1.39748627,
#             0.46431228, 0.59653829]),
#  'HDAC2': ArrayView([0.14735259, 0.75522112, 0.46184827, ..., 1.40293133,
#             0.45448257, 0.59277468]),
#  'HES1': ArrayView([0.20063075, 0.70084551, 0.50721072, ..., 1.41183507,
#             0.47889357, 0.61005984]),
#  'HESX1': ArrayView([0.1777268 , 0.74008221, 0.47766279, ..., 1.40310854,
#             0.46276516, 0.57486444]),
#  'HMGA2': ArrayView([0.18076948, 0.74740538, 0.36750302, ..., 1.39393469,
#             0.44112323, 0.567198  ]),
#  'HNF4A': ArrayView([0.18323358, 0.74905588, 0.4722662 , ..., 1.40352597,
#             0.47105035, 0.57646785]),
#  'HOXA10': ArrayView([0.18151283, 0.74628275, 0.48590905, ..., 1.40404138,
#             0.46820628, 0.57850544]),
#  'HOXA2': ArrayView([0.18124965, 0.74535416, 0.48222661, ..., 1.40423528,
#             0.4683933 , 0.57968032]),
#  'HOXB1': ArrayView([0.19463071, 0.74609662, 0.46120891, ..., 1.40337149,
#             0.46581413, 0.57864132]),
#  'HOXC9': ArrayView([0.18148442, 0.74549699, 0.48319567, ..., 1.40417515,
#             0.46827223, 0.57938269]),
#  'HOXD1': ArrayView([0.17488533, 0.74480899, 0.48939348, ..., 1.40622545,
#             0.47127604, 0.57016294]),
#  'HOXD10': ArrayView([0.17922115, 0.74474577, 0.48539311, ..., 1.40417718,
#             0.46814442, 0.57969381]),
#  'HOXD13': ArrayView([0.17797241, 0.73874736, 0.48473222, ..., 1.40220707,
#             0.46691436, 0.57823021]),
#  'HOXD3': ArrayView([0.18110176, 0.74651778, 0.48377781, ..., 1.4045201 ,
#             0.46802759, 0.58058724]),
#  'ID1': ArrayView([0.14131371, 0.7236988 , 0.48137028, ..., 1.403361  ,
#             0.47274684, 0.55864153]),
#  'ID3': ArrayView([0.04805957, 0.74321739, 0.42336584, ..., 1.40469496,
#             0.47772065, 0.53985984]),
#  'IKZF1': ArrayView([0.17159287, 0.74835807, 0.4819805 , ..., 1.40235253,
#             0.46457821, 0.57820288]),
#  'IRF1': ArrayView([0.20292153, 0.74466761, 0.49244198, ..., 1.40425973,
#             0.46720586, 0.58568373]),
#  'IRF2': ArrayView([0.18894436, 0.7570242 , 0.48047085, ..., 1.4060191 ,
#             0.48138816, 0.59273413]),
#  'IRF5': ArrayView([0.18630196, 0.74534075, 0.48419673, ..., 1.40388996,
#             0.46753936, 0.57969188]),
#  'IRX2': ArrayView([0.2169046 , 0.73675923, 0.51000511, ..., 1.41460696,
#             0.46488679, 0.63608974]),
#  'ISL1': ArrayView([0.1512695 , 0.73345655, 0.49168814, ..., 1.40174458,
#             0.46936852, 0.57788288]),
#  'ISL2': ArrayView([0.20365992, 0.73168724, 0.47609207, ..., 1.40444598,
#             0.46192557, 0.56051279]),
#  'JUNB': ArrayView([0.22301965, 0.72687048, 0.55025888, ..., 1.40126211,
#             0.45734632, 0.56775027]),
#  'JUND': ArrayView([0.18661645, 0.73566503, 0.48372485, ..., 1.40483568,
#             0.47058571, 0.57351338]),
#  'KLF1': ArrayView([0.17987287, 0.73980325, 0.48223766, ..., 1.40416641,
#             0.46820213, 0.58009827]),
#  'KLF11': ArrayView([0.17891047, 0.71769754, 0.46317464, ..., 1.40350529,
#             0.47831253, 0.58330778]),
#  'KLF12': ArrayView([0.15079851, 0.76092779, 0.48292619, ..., 1.40461906,
#             0.4661382 , 0.6011565 ]),
#  'KLF14': ArrayView([0.1815714 , 0.74573135, 0.48335698, ..., 1.4041915 ,
#             0.4682778 , 0.57929512]),
#  'KLF15': ArrayView([0.20718168, 0.73807867, 0.47758634, ..., 1.39948411,
#             0.45484971, 0.57965905]),
#  'KLF2': ArrayView([0.18992071, 0.74932405, 0.52523788, ..., 1.40837418,
#             0.48173446, 0.6225474 ]),
#  'KLF3': ArrayView([0.18758296, 0.73652008, 0.49545709, ..., 1.40356378,
#             0.47108034, 0.5940364 ]),
#  'KLF4': ArrayView([0.18506392, 0.71525484, 0.50284847, ..., 1.39451837,
#             0.44484216, 0.55871128]),
#  'KLF5': ArrayView([0.18322886, 0.74400905, 0.48558761, ..., 1.404103  ,
#             0.46644238, 0.57816912]),
#  'KLF8': ArrayView([0.18289626, 0.74379302, 0.48515204, ..., 1.40569536,
#             0.47674781, 0.5918566 ]),
#  'KLF9': ArrayView([0.18154534, 0.74447072, 0.4840714 , ..., 1.40416362,
#             0.46929004, 0.58013649]),
#  'LHX1': ArrayView([0.19782394, 0.68799998, 0.42439253, ..., 1.4174622 ,
#             0.49225529, 0.57618494]),
#  'LHX2': ArrayView([0.17830248, 0.73687558, 0.48284888, ..., 1.4029042 ,
#             0.46297944, 0.58487894]),
#  'LHX3': ArrayView([0.18223919, 0.74618407, 0.48355123, ..., 1.40435832,
#             0.46729292, 0.57955922]),
#  'LHX4': ArrayView([0.07715994, 0.72931211, 0.52684988, ..., 1.39690285,
#             0.42039224, 0.59154502]),
#  'LMO2': ArrayView([0.19022156, 0.73774343, 0.48706689, ..., 1.40321001,
#             0.47317816, 0.57811139]),
#  'MAFK': ArrayView([0.17347312, 0.73917701, 0.49131932, ..., 1.40360823,
#             0.46250204, 0.57633685]),
#  'MEF2A': ArrayView([0.18688471, 0.73882412, 0.48480019, ..., 1.40469604,
#             0.47868331, 0.5880742 ]),
#  'MEF2C': ArrayView([0.18658233, 0.73600138, 0.46772513, ..., 1.39898133,
#             0.46990162, 0.56583931]),
#  'MEIS1': ArrayView([0.16735921, 0.7358061 , 0.48679163, ..., 1.40209228,
#             0.46702796, 0.57243054]),
#  'MSC': ArrayView([0.16531322, 0.72821559, 0.49484459, ..., 1.3987972 ,
#             0.49388598, 0.59906231]),
#  'MSGN1': ArrayView([0.20690788, 0.75832706, 0.48349139, ..., 1.40802477,
#             0.46620652, 0.58153137]),
#  'MSX2': ArrayView([0.17556476, 0.70176061, 0.3884995 , ..., 1.39648208,
#             0.49405769, 0.52837469]),
#  'MYBL2': ArrayView([0.09915751, 0.64011245, 0.46440748, ..., 1.37895598,
#             0.38860158, 0.53715997]),
#  'MYC': ArrayView([0.09992642, 0.76430983, 0.49766835, ..., 1.41084219,
#             0.369867  , 0.6238782 ]),
#  'MYF5': ArrayView([0.18351838, 0.74525486, 0.48026557, ..., 1.4043371 ,
#             0.46833936, 0.57970262]),
#  'MYOD1': ArrayView([0.18528101, 0.74435796, 0.47977796, ..., 1.40441976,
#             0.46862991, 0.58067703]),
#  'NEUROD1': ArrayView([0.18810509, 0.74507877, 0.47713842, ..., 1.40466844,
#             0.46991136, 0.57940772]),
#  'NEUROD2': ArrayView([0.21027042, 0.74747357, 0.48653806, ..., 1.40596901,
#             0.4677239 , 0.58246633]),
#  'NEUROD4': ArrayView([0.17946912, 0.74624763, 0.48296864, ..., 1.40387742,
#             0.46729469, 0.57890401]),
#  'NEUROG1': ArrayView([0.18446731, 0.74374028, 0.48158389, ..., 1.40366831,
#             0.46800366, 0.57955415]),
#  'NEUROG2': ArrayView([0.1822619 , 0.74085719, 0.48197022, ..., 1.40317687,
#             0.46451706, 0.58116275]),
#  'NEUROG3': ArrayView([0.19241023, 0.72585641, 0.48503087, ..., 1.40163189,
#             0.46014279, 0.59110758]),
#  'NFATC1': ArrayView([0.24909007, 0.73732028, 0.49609203, ..., 1.40878119,
#             0.47594591, 0.59266889]),
#  'NFE2L1': ArrayView([0.23025537, 0.69237849, 0.49145504, ..., 1.39920685,
#             0.49127577, 0.61571534]),
#  'NFIB': ArrayView([0.20913465, 0.73383496, 0.4995532 , ..., 1.40032548,
#             0.48370539, 0.57103099]),
#  'NFIC': ArrayView([0.17716064, 0.73097913, 0.52876124, ..., 1.41057331,
#             0.49875368, 0.54035291]),
#  'NKX2-1': ArrayView([0.22709984, 0.73505129, 0.46979491, ..., 1.39486035,
#             0.45325716, 0.57880087]),
#  'NKX2-2': ArrayView([0.17143103, 0.7403426 , 0.49136836, ..., 1.40258692,
#             0.46799653, 0.57982395]),
#  'NKX2-5': ArrayView([0.21192631, 0.72634498, 0.45106917, ..., 1.40620069,
#             0.4675705 , 0.56648447]),
#  'NKX6-1': ArrayView([0.18199515, 0.7369303 , 0.49215111, ..., 1.40262113,
#             0.46504678, 0.5793133 ]),
#  'NKX6-2': ArrayView([0.18950811, 0.73930081, 0.48729089, ..., 1.40228644,
#             0.46848695, 0.57863785]),
#  'NPAS2': ArrayView([0.20542612, 0.73203988, 0.47754489, ..., 1.39877993,
#             0.46009155, 0.58127628]),
#  'NR1D2': ArrayView([0.19443799, 0.71331843, 0.46148797, ..., 1.39851643,
#             0.48977519, 0.58594734]),
#  'NR2E1': ArrayView([0.2256751 , 0.76221558, 0.40796292, ..., 1.39708383,
#             0.43099115, 0.55468991]),
#  'NR2F1': ArrayView([0.17856329, 0.74576293, 0.48281035, ..., 1.40472908,
#             0.46953623, 0.57994648]),
#  'NR2F2': ArrayView([0.17201538, 0.73370629, 0.49069894, ..., 1.40270077,
#             0.47208871, 0.58193308]),
#  'NR4A2': ArrayView([0.18132862, 0.74498977, 0.48330899, ..., 1.40443556,
#             0.46856014, 0.57834499]),
#  'NR4A3': ArrayView([0.18118349, 0.7386983 , 0.47716967, ..., 1.4038147 ,
#             0.46224296, 0.58212191]),
#  'NRF1': ArrayView([0.14860033, 0.79399395, 0.45043711, ..., 1.4144877 ,
#             0.45215808, 0.61428238]),
#  'OLIG1': ArrayView([0.18079409, 0.74510196, 0.48318781, ..., 1.40407582,
#             0.46775277, 0.57923012]),
#  'OLIG2': ArrayView([0.17589407, 0.74519121, 0.48585437, ..., 1.40329525,
#             0.46522286, 0.57777952]),
#  'OTP': ArrayView([0.18152936, 0.74300418, 0.47998851, ..., 1.40448297,
#             0.46559456, 0.58252404]),
#  'OTX1': ArrayView([0.18140745, 0.73766828, 0.47722043, ..., 1.40274177,
#             0.46376914, 0.58178991]),
#  'OTX2': ArrayView([0.24192124, 0.75643997, 0.44755581, ..., 1.39950438,
#             0.50081392, 0.58596173]),
#  'OVOL2': ArrayView([0.16592825, 0.75407441, 0.4201565 , ..., 1.40331166,
#             0.49163746, 0.58309398]),
#  'PAX5': ArrayView([0.20720594, 0.73141264, 0.47357768, ..., 1.40571869,
#             0.45622483, 0.59987831]),
#  'PAX8': ArrayView([0.25050208, 0.75011576, 0.49192949, ..., 1.40814438,
#             0.46492981, 0.58690248]),
#  'PBX1': ArrayView([0.17994124, 0.74009452, 0.48089589, ..., 1.40455524,
#             0.47651113, 0.58668358]),
#  'PDX1': ArrayView([0.18176109, 0.74553787, 0.48301537, ..., 1.40418416,
#             0.46813823, 0.57949604]),
#  'PITX2': ArrayView([0.18098664, 0.77307525, 0.42767747, ..., 1.40014098,
#             0.4838426 , 0.57349004]),
#  'POLR3A': ArrayView([0.18326142, 0.75789949, 0.49790036, ..., 1.40343237,
#             0.44719527, 0.58619901]),
#  'POU2F2': ArrayView([0.18151307, 0.74464735, 0.48274138, ..., 1.40440649,
#             0.46834862, 0.57963241]),
#  'POU4F1': ArrayView([0.16910323, 0.74521681, 0.47646742, ..., 1.40090428,
#             0.46479047, 0.57237713]),
#  'POU4F3': ArrayView([0.15859597, 0.74805632, 0.48392638, ..., 1.40155797,
#             0.46108635, 0.57648428]),
#  'PPARG': ArrayView([0.12138737, 0.72249312, 0.52796667, ..., 1.40011495,
#             0.47601253, 0.55904609]),
#  'PPARGC1A': ArrayView([0.18243411, 0.74338472, 0.48280482, ..., 1.40398593,
#             0.46758375, 0.57873266]),
#  'PRDM1': ArrayView([0.14159389, 0.70905848, 0.45143686, ..., 1.41268352,
#             0.50515565, 0.50063828]),
#  'PTF1A': ArrayView([0.16503214, 0.72666548, 0.50448171, ..., 1.40009771,
#             0.4656161 , 0.58140741]),
#  'RAD21': ArrayView([0.2018036 , 0.74653536, 0.45095925, ..., 1.40734617,
#             0.48839871, 0.60654362]),
#  'RARA': ArrayView([0.17141729, 0.74628197, 0.4829166 , ..., 1.40348443,
#             0.46076421, 0.5794204 ]),
#  'REST': ArrayView([0.19138694, 0.73892907, 0.48104808, ..., 1.40431675,
#             0.46990115, 0.58563809]),
#  'RFX2': ArrayView([0.18195314, 0.74433613, 0.483236  , ..., 1.40372209,
#             0.47002145, 0.58112932]),
#  'RFX5': ArrayView([0.19502906, 0.74712017, 0.47928102, ..., 1.40516962,
#             0.47564163, 0.58066536]),
#  'RHOXF2': ArrayView([0.18110862, 0.74643913, 0.47532626, ..., 1.40497313,
#             0.46724276, 0.58119583]),
#  'RREB1': ArrayView([0.23563766, 0.73015736, 0.47907407, ..., 1.40148269,
#             0.46288477, 0.60646871]),
#  'RUNX1': ArrayView([0.19051568, 0.73512533, 0.4766962 , ..., 1.40411408,
#             0.47074708, 0.57445035]),
#  'RUNX3': ArrayView([0.17874839, 0.73316558, 0.4835779 , ..., 1.40278479,
#             0.47540179, 0.5807573 ]),
#  'RXRA': ArrayView([0.16980347, 0.74936678, 0.48166743, ..., 1.4023391 ,
#             0.46703325, 0.58422771]),
#  'SALL4': ArrayView([0.18541896, 0.74585986, 0.37495003, ..., 1.39738985,
#             0.44697838, 0.59867726]),
#  'SETDB1': ArrayView([0.26987212, 0.73808345, 0.42199784, ..., 1.41096222,
#             0.50843754, 0.58519194]),
#  'SIN3A': ArrayView([0.19876016, 0.72974146, 0.46161039, ..., 1.40372603,
#             0.4813114 , 0.58110779]),
#  'SIRT6': ArrayView([0.17150847, 0.76724449, 0.52631752, ..., 1.40656817,
#             0.46187944, 0.57512907]),
#  'SIX1': ArrayView([0.18843355, 0.73479592, 0.4809597 , ..., 1.4021393 ,
#             0.46019038, 0.58338884]),
#  'SIX5': ArrayView([0.21601198, 0.740101  , 0.47864687, ..., 1.40500904,
#             0.46587525, 0.59025658]),
#  'SMAD2': ArrayView([0.18357428, 0.74469957, 0.48067598, ..., 1.40381749,
#             0.46887255, 0.58327783]),
#  'SMAD3': ArrayView([0.19647603, 0.72591596, 0.4812992 , ..., 1.40168678,
#             0.47048393, 0.57963601]),
#  'SMARCB1': ArrayView([0.1990309 , 0.736014  , 0.4707059 , ..., 1.40552501,
#             0.47921752, 0.57679148]),
#  'SMC3': ArrayView([0.18347994, 0.75153333, 0.47690748, ..., 1.40295774,
#             0.46488606, 0.58155293]),
#  'SNAI1': ArrayView([0.20818001, 0.74309171, 0.51160945, ..., 1.40166688,
#             0.4640456 , 0.57054117]),
#  'SNAI2': ArrayView([0.18161447, 0.74044814, 0.48924245, ..., 1.40671899,
#             0.461331  , 0.57179661]),
#  'SNAI3': ArrayView([0.16987494, 0.72590532, 0.47701731, ..., 1.40681365,
#             0.46156147, 0.58689223]),
#  'SOX14': ArrayView([0.17808638, 0.73410664, 0.52478996, ..., 1.40189942,
#             0.48953556, 0.59617464]),
#  'SOX15': ArrayView([0.15865475, 0.69352901, 0.60719766, ..., 1.40658202,
#             0.46849787, 0.5842679 ]),
#  'SOX17': ArrayView([0.24614624, 0.67621477, 0.42680787, ..., 1.3833566 ,
#             0.60950822, 0.62855972]),
#  'SOX6': ArrayView([0.20849585, 0.7206672 , 0.48125691, ..., 1.39982127,
#             0.50725039, 0.59525357]),
#  'SOX7': ArrayView([0.26907413, 0.7390082 , 0.48996215, ..., 1.4088468 ,
#             0.44555507, 0.60325588]),
#  'SOX9': ArrayView([0.22901337, 0.72923147, 0.49663173, ..., 1.40372912,
#             0.46922219, 0.56940197]),
#  'SPI1': ArrayView([0.18409189, 0.74498914, 0.48437642, ..., 1.4043131 ,
#             0.4696219 , 0.5801751 ]),
#  'SPIB': ArrayView([0.18193805, 0.76716249, 0.50309021, ..., 1.40941344,
#             0.4242115 , 0.60234328]),
#  'SPIC': ArrayView([0.18186952, 0.74609481, 0.481427  , ..., 1.40441793,
#             0.46848016, 0.57969093]),
#  'SPZ1': ArrayView([0.18206318, 0.74561582, 0.48271099, ..., 1.40427208,
#             0.46854336, 0.57972288]),
#  'SREBF2': ArrayView([0.16243778, 0.77282845, 0.46532524, ..., 1.39926253,
#             0.47952631, 0.57384237]),
#  'STAT3': ArrayView([0.18515345, 0.61683431, 0.54003805, ..., 1.39041569,
#             0.44757537, 0.54607936]),
#  'STAT4': ArrayView([0.16923984, 0.73696142, 0.50573777, ..., 1.40173596,
#             0.47335986, 0.57868316]),
#  'STAT5A': ArrayView([0.20347835, 0.66388248, 0.4794203 , ..., 1.4034704 ,
#             0.4696054 , 0.58610778]),
#  'TAL1': ArrayView([0.1828386 , 0.74501598, 0.48169393, ..., 1.4041853 ,
#             0.46812184, 0.57932842]),
#  'TBX2': ArrayView([0.16838545, 0.7381787 , 0.49430143, ..., 1.40215602,
#             0.46731123, 0.58169246]),
#  'TBX3': ArrayView([0.13592507, 0.72351922, 0.46369427, ..., 1.39918847,
#             0.48247171, 0.55361838]),
#  'TBX4': ArrayView([0.18229286, 0.74046412, 0.48324091, ..., 1.40378942,
#             0.46638391, 0.58189606]),
#  'TBX5': ArrayView([0.1426145 , 0.73987428, 0.50104636, ..., 1.39863762,
#             0.45186308, 0.58593008]),
#  'TCF12': ArrayView([0.2256867 , 0.77841909, 0.4727953 , ..., 1.40396545,
#             0.49076242, 0.60381012]),
#  'TCF23': ArrayView([0.1798404 , 0.74358971, 0.47823424, ..., 1.4023028 ,
#             0.46744392, 0.57741984]),
#  'TCF7L2': ArrayView([0.17925953, 0.73774823, 0.48816679, ..., 1.4026799 ,
#             0.46373973, 0.58135114]),
#  'TEAD4': ArrayView([0.11208316, 0.71773649, 0.50036639, ..., 1.39332768,
#             0.40580824, 0.59957242]),
#  'TFAP2A': ArrayView([0.17459245, 0.7422487 , 0.48254382, ..., 1.40397666,
#             0.46965219, 0.57802531]),
#  'TFAP2B': ArrayView([0.18129191, 0.74555769, 0.48344266, ..., 1.40418953,
#             0.46831017, 0.57944903]),
#  'TFAP2C': ArrayView([0.25423541, 0.75152238, 0.48649991, ..., 1.40367367,
#             0.44933235, 0.55950681]),
#  'TFAP4': ArrayView([0.16897689, 0.74795005, 0.47252781, ..., 1.40684481,
#             0.43976627, 0.58230609]),
#  'TFCP2L1': ArrayView([0.17734106, 0.7407238 , 0.49828542, ..., 1.40151602,
#             0.45064714, 0.595596  ]),
#  'TFE3': ArrayView([0.16901549, 0.78270979, 0.45405696, ..., 1.39641098,
#             0.40931436, 0.5628847 ]),
#  'TGIF1': ArrayView([0.17870053, 0.74043334, 0.48218688, ..., 1.40303892,
#             0.46743855, 0.58508895]),
#  'THAP1': ArrayView([0.1640169 , 0.78064938, 0.4686068 , ..., 1.41161376,
#             0.45854119, 0.60231296]),
#  'THAP11': ArrayView([0.14849861, 0.81723258, 0.49130348, ..., 1.41713328,
#             0.44937722, 0.6243799 ]),
#  'TLX3': ArrayView([0.17864221, 0.74486945, 0.51023914, ..., 1.39806385,
#             0.45801042, 0.56431396]),
#  'TP53': ArrayView([0.18502969, 0.74821165, 0.50083412, ..., 1.40571518,
#             0.45864187, 0.58449116]),
#  'TP73': ArrayView([0.18453081, 0.74411462, 0.47228138, ..., 1.40224651,
#             0.44694122, 0.5951036 ]),
#  'TRIM28': ArrayView([0.14354068, 0.75131813, 0.50057868, ..., 1.40080263,
#             0.43984105, 0.57499615]),
#  'USF1': ArrayView([0.145887  , 0.75123448, 0.49560591, ..., 1.40390809,
#             0.44471394, 0.56628413]),
#  'VAX1': ArrayView([0.19470296, 0.74285692, 0.47360394, ..., 1.40435657,
#             0.47204228, 0.57924458]),
#  'VDR': ArrayView([0.2149093 , 0.73878111, 0.46826125, ..., 1.40530915,
#             0.46682202, 0.57580776]),
#  'YY1': ArrayView([0.16090615, 0.74744174, 0.48517354, ..., 1.40205736,
#             0.44791044, 0.58994939]),
#  'ZFP57': ArrayView([0.17947569, 0.74717001, 0.49431206, ..., 1.40546979,
#             0.46460192, 0.58202304]),
#  'ZIC1': ArrayView([0.45085322, 0.73599141, 0.55156502, ..., 1.42159328,
#             0.49006183, 0.62197006]),
#  'ZIC3': ArrayView([0.26157894, 0.71961749, 0.41588943, ..., 1.39672225,
#             0.51510666, 0.62194474]),
#  'ZKSCAN1': ArrayView([0.20873861, 0.73123759, 0.47419539, ..., 1.40696709,
#             0.48828644, 0.58618892]),
#  'ZNF263': ArrayView([0.16321481, 0.71653875, 0.46970453, ..., 1.40325114,
#             0.44685587, 0.60141359]),
#  'ZNF274': ArrayView([0.18133411, 0.75426638, 0.48058627, ..., 1.40268975,
#             0.45830873, 0.57317552]),
#  'ZNF713': ArrayView([0.19088403, 0.73524575, 0.4887569 , ..., 1.40394428,
#             0.47013017, 0.58468635]),
#  'ZSCAN4': ArrayView([0.18061293, 0.74551694, 0.48277466, ..., 1.40388583,
#             0.46732792, 0.57863299]),
#  'ALX1': ArrayView([0.17134618, 0.74656743, 0.48650817, ..., 1.40309213,
#             0.46487484, 0.57831378]),
#  'ARID3B': ArrayView([0.18081415, 0.74401059, 0.48470778, ..., 1.4037392 ,
#             0.46725827, 0.5795218 ]),
#  'ATF4': ArrayView([0.18067382, 0.75323111, 0.49059304, ..., 1.40477969,
#             0.46462166, 0.58517253]),
#  'CBFB': ArrayView([0.18230737, 0.74494245, 0.48332104, ..., 1.40396915,
#             0.4682572 , 0.57885204]),
#  'DBX1': ArrayView([0.18183017, 0.74513967, 0.48314197, ..., 1.40412745,
#             0.46832902, 0.57955395]),
#  'DBX2': ArrayView([0.18163821, 0.74551518, 0.48312458, ..., 1.40417221,
#             0.46830785, 0.57934551]),
#  'E2F3': ArrayView([0.17151683, 0.74272723, 0.48767427, ..., 1.40404863,
#             0.46497671, 0.57944539]),
#  'E2F5': ArrayView([0.18174901, 0.74720594, 0.48232925, ..., 1.40395786,
#             0.46885132, 0.58001583]),
#  'EMX2': ArrayView([0.18164232, 0.74549984, 0.48312435, ..., 1.40417045,
#             0.46829897, 0.57935567]),
#  'FOXE1': ArrayView([0.18163943, 0.74551475, 0.48312639, ..., 1.404172  ,
#             0.46830874, 0.57934715]),
#  'HMGA1': ArrayView([0.15696342, 0.75916125, 0.47566426, ..., 1.39816122,
#             0.45651004, 0.57441588]),
#  'HOXA1': ArrayView([0.18162653, 0.7455118 , 0.48312914, ..., 1.40417129,
#             0.46830918, 0.57934448]),
#  'LBX2': ArrayView([0.18163947, 0.74551356, 0.48313622, ..., 1.40417198,
#             0.46831093, 0.57934932]),
#  'MYCN': ArrayView([0.18070772, 0.74711257, 0.48253827, ..., 1.40414863,
#             0.46890246, 0.57878969]),
#  'NFIA': ArrayView([0.18164373, 0.74551203, 0.48313209, ..., 1.40417372,
#             0.46830323, 0.57935094]),
#  'NFYA': ArrayView([0.18198672, 0.74544684, 0.48328598, ..., 1.40412851,
#             0.4683055 , 0.57937833]),
#  'OSR1': ArrayView([0.18163935, 0.7455165 , 0.4831271 , ..., 1.40417264,
#             0.46830986, 0.57934648]),
#  'POU3F4': ArrayView([0.17014443, 0.75274703, 0.47601488, ..., 1.40399101,
#             0.47862103, 0.58746525]),
#  'SRF': ArrayView([0.1840183 , 0.74542636, 0.47903228, ..., 1.40437161,
#             0.47101058, 0.57913951]),
#  'TCF15': ArrayView([0.18163796, 0.74551451, 0.48313102, ..., 1.40416976,
#             0.46830624, 0.57934739]),
#  'TEF': ArrayView([0.18170707, 0.74540603, 0.48309589, ..., 1.40417171,
#             0.46836951, 0.57943161]),
#  'ZNF384': ArrayView([0.18334999, 0.74790315, 0.48181076, ..., 1.40396982,
#             0.46497753, 0.57984875])}

# %% [markdown]
# ### Evaluation
#
# We compute the correlation of the predictions with held-out perturbations.

# %%
controlIndex = ko_lab_esc_data_train.obs["perturbation"]=="Control"
evaluator.evaluateCausalModel(
    heldout = ko_lab_esc_data_heldout, 
    predictions = predictions,   
    baseline = ko_lab_esc_data_train[controlIndex,:].X.mean(axis=0), 
    experiments = experiments,
    factor_varied = "cluster_resolution",
    experiment_name = EXPERIMENT_NAME
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <module>
#       1 controlIndex = ko_lab_esc_data_train.obs["perturbation"]=="Control"
# ----> 2 evaluator.evaluateCausalModel(
#       3     heldout = ko_lab_esc_data_heldout,
#       4     predictions = predictions,
#       5     baseline = ko_lab_esc_data_train[controlIndex,:].X.mean(axis=0),
#       6     experiments = experiments,
#       7     factor_varied = "cluster_resolution",
#       8     experiment_name = EXPERIMENT_NAME
#       9 )
#
# File ~/Desktop/jhu/research/projects/perturbation_prediction/cell_type_knowledge_transfer/benchmarking/evaluator/evaluator.py:78, in evaluateCausalModel(heldout, predictions, baseline, experiments, experiment_name, factor_varied, classifier)
#      76 remakeMainPlots(experiment_name, factor_varied)
#      77 # Which genes are best/worst?
# ---> 78 hardest = evaluationResults.loc[evaluationResults["spearman"].idxmax(),"perturbation"]
#      79 easiest = evaluationResults.loc[evaluationResults["spearman"].idxmin(),"perturbation"]
#      80 evaluationResults.loc[evaluationResults["perturbation"]==hardest,:].to_csv("results/"+ experiment_name +"/hardest.csv")
#
# NameError: name 'stripchartMainFig' is not defined
