# %% [markdown]
# ## Experiment 1: base network selection
#
# This experiment studies different options for the base GRN provided to CellOracle.

# %%
EXPERIMENT_NAME="baseNetwork_v1"

# %%
import warnings
warnings.filterwarnings('ignore')
import importlib
import os
import gc
import sys
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import joblib
import celloracle as co

#      visualization settings
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
plt.rcParams['figure.figsize'] = [6, 4.5]
plt.rcParams["savefig.dpi"] = 300

# %%
# Deal with various file paths specific to this project
PROJECT_PATH = '/home/ekernf01/Desktop/jhu/research/projects/perturbation_prediction/cell_type_knowledge_transfer/'
os.chdir(PROJECT_PATH + "benchmarking/")
try:
    os.makedirs("results/" + EXPERIMENT_NAME)
except:
    pass

sys.path.append(os.path.expanduser(PROJECT_PATH + 'networks/load_networks'))
sys.path.append(os.path.expanduser(PROJECT_PATH + 'perturbations/load_perturbations')) 
sys.path.append(os.path.expanduser(PROJECT_PATH + 'benchmarking/evaluator')) 
import evaluator
import load_networks
import load_perturbations
importlib.reload(evaluator) 
importlib.reload(load_networks) 
importlib.reload(load_perturbations)
os.environ["GRN_PATH"]           = PROJECT_PATH + "networks/networks"
os.environ["PERTURBATION_PATH"]  = PROJECT_PATH + "perturbations/perturbations"
# Out:
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2

# %%
X = evaluator.makeRandomNetwork(density = 1, TFs = ["foo", "bar", "baz"])
X.iloc[:, 2:] = np.array(X.iloc[:, 2:])   #undo sparse representation         
dict(X.iloc[:, 2:].apply(lambda x: x[x>0].index.values, axis=1))
# Out:
# {0: array(['foo', 'bar', 'baz'], dtype=object),
#  1: array(['foo', 'bar', 'baz'], dtype=object),
#  2: array(['foo', 'bar', 'baz'], dtype=object),
#  3: array(['foo', 'bar', 'baz'], dtype=object),
#  4: array(['foo', 'bar', 'baz'], dtype=object),
#  5: array(['foo', 'bar', 'baz'], dtype=object),
#  6: array(['foo', 'bar', 'baz'], dtype=object),
#  7: array(['foo', 'bar', 'baz'], dtype=object),
#  8: array(['foo', 'bar', 'baz'], dtype=object),
#  9: array(['foo', 'bar', 'baz'], dtype=object),
#  10: array(['foo', 'bar', 'baz'], dtype=object),
#  11: array(['foo', 'bar', 'baz'], dtype=object),
#  12: array(['foo', 'bar', 'baz'], dtype=object),
#  13: array(['foo', 'bar', 'baz'], dtype=object),
#  14: array(['foo', 'bar', 'baz'], dtype=object),
#  15: array(['foo', 'bar', 'baz'], dtype=object),
#  16: array(['foo', 'bar', 'baz'], dtype=object),
#  17: array(['foo', 'bar', 'baz'], dtype=object),
#  18: array(['foo', 'bar', 'baz'], dtype=object),
#  19: array(['foo', 'bar', 'baz'], dtype=object),
#  20: array(['foo', 'bar', 'baz'], dtype=object),
#  21: array(['foo', 'bar', 'baz'], dtype=object),
#  22: array(['foo', 'bar', 'baz'], dtype=object),
#  23: array(['foo', 'bar', 'baz'], dtype=object),
#  24: array(['foo', 'bar', 'baz'], dtype=object),
#  25: array(['foo', 'bar', 'baz'], dtype=object),
#  26: array(['foo', 'bar', 'baz'], dtype=object),
#  27: array(['foo', 'bar', 'baz'], dtype=object),
#  28: array(['foo', 'bar', 'baz'], dtype=object),
#  29: array(['foo', 'bar', 'baz'], dtype=object),
#  30: array(['foo', 'bar', 'baz'], dtype=object),
#  31: array(['foo', 'bar', 'baz'], dtype=object),
#  32: array(['foo', 'bar', 'baz'], dtype=object),
#  33: array(['foo', 'bar', 'baz'], dtype=object),
#  34: array(['foo', 'bar', 'baz'], dtype=object),
#  35: array(['foo', 'bar', 'baz'], dtype=object),
#  36: array(['foo', 'bar', 'baz'], dtype=object),
#  37: array(['foo', 'bar', 'baz'], dtype=object),
#  38: array(['foo', 'bar', 'baz'], dtype=object),
#  39: array(['foo', 'bar', 'baz'], dtype=object),
#  40: array(['foo', 'bar', 'baz'], dtype=object),
#  41: array(['foo', 'bar', 'baz'], dtype=object),
#  42: array(['foo', 'bar', 'baz'], dtype=object),
#  43: array(['foo', 'bar', 'baz'], dtype=object),
#  44: array(['foo', 'bar', 'baz'], dtype=object),
#  45: array(['foo', 'bar', 'baz'], dtype=object),
#  46: array(['foo', 'bar', 'baz'], dtype=object),
#  47: array(['foo', 'bar', 'baz'], dtype=object),
#  48: array(['foo', 'bar', 'baz'], dtype=object),
#  49: array(['foo', 'bar', 'baz'], dtype=object),
#  50: array(['foo', 'bar', 'baz'], dtype=object),
#  51: array(['foo', 'bar', 'baz'], dtype=object),
#  52: array(['foo', 'bar', 'baz'], dtype=object),
#  53: array(['foo', 'bar', 'baz'], dtype=object),
#  54: array(['foo', 'bar', 'baz'], dtype=object),
#  55: array(['foo', 'bar', 'baz'], dtype=object),
#  56: array(['foo', 'bar', 'baz'], dtype=object),
#  57: array(['foo', 'bar', 'baz'], dtype=object),
#  58: array(['foo', 'bar', 'baz'], dtype=object),
#  59: array(['foo', 'bar', 'baz'], dtype=object),
#  60: array(['foo', 'bar', 'baz'], dtype=object),
#  61: array(['foo', 'bar', 'baz'], dtype=object),
#  62: array(['foo', 'bar', 'baz'], dtype=object),
#  63: array(['foo', 'bar', 'baz'], dtype=object),
#  64: array(['foo', 'bar', 'baz'], dtype=object),
#  65: array(['foo', 'bar', 'baz'], dtype=object),
#  66: array(['foo', 'bar', 'baz'], dtype=object),
#  67: array(['foo', 'bar', 'baz'], dtype=object),
#  68: array(['foo', 'bar', 'baz'], dtype=object),
#  69: array(['foo', 'bar', 'baz'], dtype=object),
#  70: array(['foo', 'bar', 'baz'], dtype=object),
#  71: array(['foo', 'bar', 'baz'], dtype=object),
#  72: array(['foo', 'bar', 'baz'], dtype=object),
#  73: array(['foo', 'bar', 'baz'], dtype=object),
#  74: array(['foo', 'bar', 'baz'], dtype=object),
#  75: array(['foo', 'bar', 'baz'], dtype=object),
#  76: array(['foo', 'bar', 'baz'], dtype=object),
#  77: array(['foo', 'bar', 'baz'], dtype=object),
#  78: array(['foo', 'bar', 'baz'], dtype=object),
#  79: array(['foo', 'bar', 'baz'], dtype=object),
#  80: array(['foo', 'bar', 'baz'], dtype=object),
#  81: array(['foo', 'bar', 'baz'], dtype=object),
#  82: array(['foo', 'bar', 'baz'], dtype=object),
#  83: array(['foo', 'bar', 'baz'], dtype=object),
#  84: array(['foo', 'bar', 'baz'], dtype=object),
#  85: array(['foo', 'bar', 'baz'], dtype=object),
#  86: array(['foo', 'bar', 'baz'], dtype=object),
#  87: array(['foo', 'bar', 'baz'], dtype=object),
#  88: array(['foo', 'bar', 'baz'], dtype=object),
#  89: array(['foo', 'bar', 'baz'], dtype=object),
#  90: array(['foo', 'bar', 'baz'], dtype=object),
#  91: array(['foo', 'bar', 'baz'], dtype=object),
#  92: array(['foo', 'bar', 'baz'], dtype=object),
#  93: array(['foo', 'bar', 'baz'], dtype=object),
#  94: array(['foo', 'bar', 'baz'], dtype=object),
#  95: array(['foo', 'bar', 'baz'], dtype=object),
#  96: array(['foo', 'bar', 'baz'], dtype=object),
#  97: array(['foo', 'bar', 'baz'], dtype=object),
#  98: array(['foo', 'bar', 'baz'], dtype=object),
#  99: array(['foo', 'bar', 'baz'], dtype=object),
#  100: array(['foo', 'bar', 'baz'], dtype=object),
#  101: array(['foo', 'bar', 'baz'], dtype=object),
#  102: array(['foo', 'bar', 'baz'], dtype=object),
#  103: array(['foo', 'bar', 'baz'], dtype=object),
#  104: array(['foo', 'bar', 'baz'], dtype=object),
#  105: array(['foo', 'bar', 'baz'], dtype=object),
#  106: array(['foo', 'bar', 'baz'], dtype=object),
#  107: array(['foo', 'bar', 'baz'], dtype=object),
#  108: array(['foo', 'bar', 'baz'], dtype=object),
#  109: array(['foo', 'bar', 'baz'], dtype=object),
#  110: array(['foo', 'bar', 'baz'], dtype=object),
#  111: array(['foo', 'bar', 'baz'], dtype=object),
#  112: array(['foo', 'bar', 'baz'], dtype=object),
#  113: array(['foo', 'bar', 'baz'], dtype=object),
#  114: array(['foo', 'bar', 'baz'], dtype=object),
#  115: array(['foo', 'bar', 'baz'], dtype=object),
#  116: array(['foo', 'bar', 'baz'], dtype=object),
#  117: array(['foo', 'bar', 'baz'], dtype=object),
#  118: array(['foo', 'bar', 'baz'], dtype=object),
#  119: array(['foo', 'bar', 'baz'], dtype=object),
#  120: array(['foo', 'bar', 'baz'], dtype=object),
#  121: array(['foo', 'bar', 'baz'], dtype=object),
#  122: array(['foo', 'bar', 'baz'], dtype=object),
#  123: array(['foo', 'bar', 'baz'], dtype=object),
#  124: array(['foo', 'bar', 'baz'], dtype=object),
#  125: array(['foo', 'bar', 'baz'], dtype=object),
#  126: array(['foo', 'bar', 'baz'], dtype=object),
#  127: array(['foo', 'bar', 'baz'], dtype=object),
#  128: array(['foo', 'bar', 'baz'], dtype=object),
#  129: array(['foo', 'bar', 'baz'], dtype=object),
#  130: array(['foo', 'bar', 'baz'], dtype=object),
#  131: array(['foo', 'bar', 'baz'], dtype=object),
#  132: array(['foo', 'bar', 'baz'], dtype=object),
#  133: array(['foo', 'bar', 'baz'], dtype=object),
#  134: array(['foo', 'bar', 'baz'], dtype=object),
#  135: array(['foo', 'bar', 'baz'], dtype=object),
#  136: array(['foo', 'bar', 'baz'], dtype=object),
#  137: array(['foo', 'bar', 'baz'], dtype=object),
#  138: array(['foo', 'bar', 'baz'], dtype=object),
#  139: array(['foo', 'bar', 'baz'], dtype=object),
#  140: array(['foo', 'bar', 'baz'], dtype=object),
#  141: array(['foo', 'bar', 'baz'], dtype=object),
#  142: array(['foo', 'bar', 'baz'], dtype=object),
#  143: array(['foo', 'bar', 'baz'], dtype=object),
#  144: array(['foo', 'bar', 'baz'], dtype=object),
#  145: array(['foo', 'bar', 'baz'], dtype=object),
#  146: array(['foo', 'bar', 'baz'], dtype=object),
#  147: array(['foo', 'bar', 'baz'], dtype=object),
#  148: array(['foo', 'bar', 'baz'], dtype=object),
#  149: array(['foo', 'bar', 'baz'], dtype=object),
#  150: array(['foo', 'bar', 'baz'], dtype=object),
#  151: array(['foo', 'bar', 'baz'], dtype=object),
#  152: array(['foo', 'bar', 'baz'], dtype=object),
#  153: array(['foo', 'bar', 'baz'], dtype=object),
#  154: array(['foo', 'bar', 'baz'], dtype=object),
#  155: array(['foo', 'bar', 'baz'], dtype=object),
#  156: array(['foo', 'bar', 'baz'], dtype=object),
#  157: array(['foo', 'bar', 'baz'], dtype=object),
#  158: array(['foo', 'bar', 'baz'], dtype=object),
#  159: array(['foo', 'bar', 'baz'], dtype=object),
#  160: array(['foo', 'bar', 'baz'], dtype=object),
#  161: array(['foo', 'bar', 'baz'], dtype=object),
#  162: array(['foo', 'bar', 'baz'], dtype=object),
#  163: array(['foo', 'bar', 'baz'], dtype=object),
#  164: array(['foo', 'bar', 'baz'], dtype=object),
#  165: array(['foo', 'bar', 'baz'], dtype=object),
#  166: array(['foo', 'bar', 'baz'], dtype=object),
#  167: array(['foo', 'bar', 'baz'], dtype=object),
#  168: array(['foo', 'bar', 'baz'], dtype=object),
#  169: array(['foo', 'bar', 'baz'], dtype=object),
#  170: array(['foo', 'bar', 'baz'], dtype=object),
#  171: array(['foo', 'bar', 'baz'], dtype=object),
#  172: array(['foo', 'bar', 'baz'], dtype=object),
#  173: array(['foo', 'bar', 'baz'], dtype=object),
#  174: array(['foo', 'bar', 'baz'], dtype=object),
#  175: array(['foo', 'bar', 'baz'], dtype=object),
#  176: array(['foo', 'bar', 'baz'], dtype=object),
#  177: array(['foo', 'bar', 'baz'], dtype=object),
#  178: array(['foo', 'bar', 'baz'], dtype=object),
#  179: array(['foo', 'bar', 'baz'], dtype=object),
#  180: array(['foo', 'bar', 'baz'], dtype=object),
#  181: array(['foo', 'bar', 'baz'], dtype=object),
#  182: array(['foo', 'bar', 'baz'], dtype=object),
#  183: array(['foo', 'bar', 'baz'], dtype=object),
#  184: array(['foo', 'bar', 'baz'], dtype=object),
#  185: array(['foo', 'bar', 'baz'], dtype=object),
#  186: array(['foo', 'bar', 'baz'], dtype=object),
#  187: array(['foo', 'bar', 'baz'], dtype=object),
#  188: array(['foo', 'bar', 'baz'], dtype=object),
#  189: array(['foo', 'bar', 'baz'], dtype=object),
#  190: array(['foo', 'bar', 'baz'], dtype=object),
#  191: array(['foo', 'bar', 'baz'], dtype=object),
#  192: array(['foo', 'bar', 'baz'], dtype=object),
#  193: array(['foo', 'bar', 'baz'], dtype=object),
#  194: array(['foo', 'bar', 'baz'], dtype=object),
#  195: array(['foo', 'bar', 'baz'], dtype=object),
#  196: array(['foo', 'bar', 'baz'], dtype=object),
#  197: array(['foo', 'bar', 'baz'], dtype=object),
#  198: array(['foo', 'bar', 'baz'], dtype=object),
#  199: array(['foo', 'bar', 'baz'], dtype=object),
#  200: array(['foo', 'bar', 'baz'], dtype=object),
#  201: array(['foo', 'bar', 'baz'], dtype=object),
#  202: array(['foo', 'bar', 'baz'], dtype=object),
#  203: array(['foo', 'bar', 'baz'], dtype=object),
#  204: array(['foo', 'bar', 'baz'], dtype=object),
#  205: array(['foo', 'bar', 'baz'], dtype=object),
#  206: array(['foo', 'bar', 'baz'], dtype=object),
#  207: array(['foo', 'bar', 'baz'], dtype=object),
#  208: array(['foo', 'bar', 'baz'], dtype=object),
#  209: array(['foo', 'bar', 'baz'], dtype=object),
#  210: array(['foo', 'bar', 'baz'], dtype=object),
#  211: array(['foo', 'bar', 'baz'], dtype=object),
#  212: array(['foo', 'bar', 'baz'], dtype=object),
#  213: array(['foo', 'bar', 'baz'], dtype=object),
#  214: array(['foo', 'bar', 'baz'], dtype=object),
#  215: array(['foo', 'bar', 'baz'], dtype=object),
#  216: array(['foo', 'bar', 'baz'], dtype=object),
#  217: array(['foo', 'bar', 'baz'], dtype=object),
#  218: array(['foo', 'bar', 'baz'], dtype=object),
#  219: array(['foo', 'bar', 'baz'], dtype=object),
#  220: array(['foo', 'bar', 'baz'], dtype=object),
#  221: array(['foo', 'bar', 'baz'], dtype=object),
#  222: array(['foo', 'bar', 'baz'], dtype=object),
#  223: array(['foo', 'bar', 'baz'], dtype=object),
#  224: array(['foo', 'bar', 'baz'], dtype=object),
#  225: array(['foo', 'bar', 'baz'], dtype=object),
#  226: array(['foo', 'bar', 'baz'], dtype=object),
#  227: array(['foo', 'bar', 'baz'], dtype=object),
#  228: array(['foo', 'bar', 'baz'], dtype=object),
#  229: array(['foo', 'bar', 'baz'], dtype=object),
#  230: array(['foo', 'bar', 'baz'], dtype=object),
#  231: array(['foo', 'bar', 'baz'], dtype=object),
#  232: array(['foo', 'bar', 'baz'], dtype=object),
#  233: array(['foo', 'bar', 'baz'], dtype=object),
#  234: array(['foo', 'bar', 'baz'], dtype=object),
#  235: array(['foo', 'bar', 'baz'], dtype=object),
#  236: array(['foo', 'bar', 'baz'], dtype=object),
#  237: array(['foo', 'bar', 'baz'], dtype=object),
#  238: array(['foo', 'bar', 'baz'], dtype=object),
#  239: array(['foo', 'bar', 'baz'], dtype=object),
#  240: array(['foo', 'bar', 'baz'], dtype=object),
#  241: array(['foo', 'bar', 'baz'], dtype=object),
#  242: array(['foo', 'bar', 'baz'], dtype=object),
#  243: array(['foo', 'bar', 'baz'], dtype=object),
#  244: array(['foo', 'bar', 'baz'], dtype=object),
#  245: array(['foo', 'bar', 'baz'], dtype=object),
#  246: array(['foo', 'bar', 'baz'], dtype=object),
#  247: array(['foo', 'bar', 'baz'], dtype=object),
#  248: array(['foo', 'bar', 'baz'], dtype=object),
#  249: array(['foo', 'bar', 'baz'], dtype=object),
#  250: array(['foo', 'bar', 'baz'], dtype=object),
#  251: array(['foo', 'bar', 'baz'], dtype=object),
#  252: array(['foo', 'bar', 'baz'], dtype=object),
#  253: array(['foo', 'bar', 'baz'], dtype=object),
#  254: array(['foo', 'bar', 'baz'], dtype=object),
#  255: array(['foo', 'bar', 'baz'], dtype=object),
#  256: array(['foo', 'bar', 'baz'], dtype=object),
#  257: array(['foo', 'bar', 'baz'], dtype=object),
#  258: array(['foo', 'bar', 'baz'], dtype=object),
#  259: array(['foo', 'bar', 'baz'], dtype=object),
#  260: array(['foo', 'bar', 'baz'], dtype=object),
#  261: array(['foo', 'bar', 'baz'], dtype=object),
#  262: array(['foo', 'bar', 'baz'], dtype=object),
#  263: array(['foo', 'bar', 'baz'], dtype=object),
#  264: array(['foo', 'bar', 'baz'], dtype=object),
#  265: array(['foo', 'bar', 'baz'], dtype=object),
#  266: array(['foo', 'bar', 'baz'], dtype=object),
#  267: array(['foo', 'bar', 'baz'], dtype=object),
#  268: array(['foo', 'bar', 'baz'], dtype=object),
#  269: array(['foo', 'bar', 'baz'], dtype=object),
#  270: array(['foo', 'bar', 'baz'], dtype=object),
#  271: array(['foo', 'bar', 'baz'], dtype=object),
#  272: array(['foo', 'bar', 'baz'], dtype=object),
#  273: array(['foo', 'bar', 'baz'], dtype=object),
#  274: array(['foo', 'bar', 'baz'], dtype=object),
#  275: array(['foo', 'bar', 'baz'], dtype=object),
#  276: array(['foo', 'bar', 'baz'], dtype=object),
#  277: array(['foo', 'bar', 'baz'], dtype=object),
#  278: array(['foo', 'bar', 'baz'], dtype=object),
#  279: array(['foo', 'bar', 'baz'], dtype=object),
#  280: array(['foo', 'bar', 'baz'], dtype=object),
#  281: array(['foo', 'bar', 'baz'], dtype=object),
#  282: array(['foo', 'bar', 'baz'], dtype=object),
#  283: array(['foo', 'bar', 'baz'], dtype=object),
#  284: array(['foo', 'bar', 'baz'], dtype=object),
#  285: array(['foo', 'bar', 'baz'], dtype=object),
#  286: array(['foo', 'bar', 'baz'], dtype=object),
#  287: array(['foo', 'bar', 'baz'], dtype=object),
#  288: array(['foo', 'bar', 'baz'], dtype=object),
#  289: array(['foo', 'bar', 'baz'], dtype=object),
#  290: array(['foo', 'bar', 'baz'], dtype=object),
#  291: array(['foo', 'bar', 'baz'], dtype=object),
#  292: array(['foo', 'bar', 'baz'], dtype=object),
#  293: array(['foo', 'bar', 'baz'], dtype=object),
#  294: array(['foo', 'bar', 'baz'], dtype=object),
#  295: array(['foo', 'bar', 'baz'], dtype=object),
#  296: array(['foo', 'bar', 'baz'], dtype=object),
#  297: array(['foo', 'bar', 'baz'], dtype=object),
#  298: array(['foo', 'bar', 'baz'], dtype=object),
#  299: array(['foo', 'bar', 'baz'], dtype=object),
#  300: array(['foo', 'bar', 'baz'], dtype=object),
#  301: array(['foo', 'bar', 'baz'], dtype=object),
#  302: array(['foo', 'bar', 'baz'], dtype=object),
#  303: array(['foo', 'bar', 'baz'], dtype=object),
#  304: array(['foo', 'bar', 'baz'], dtype=object),
#  305: array(['foo', 'bar', 'baz'], dtype=object),
#  306: array(['foo', 'bar', 'baz'], dtype=object),
#  307: array(['foo', 'bar', 'baz'], dtype=object),
#  308: array(['foo', 'bar', 'baz'], dtype=object),
#  309: array(['foo', 'bar', 'baz'], dtype=object),
#  310: array(['foo', 'bar', 'baz'], dtype=object),
#  311: array(['foo', 'bar', 'baz'], dtype=object),
#  312: array(['foo', 'bar', 'baz'], dtype=object),
#  313: array(['foo', 'bar', 'baz'], dtype=object),
#  314: array(['foo', 'bar', 'baz'], dtype=object),
#  315: array(['foo', 'bar', 'baz'], dtype=object),
#  316: array(['foo', 'bar', 'baz'], dtype=object),
#  317: array(['foo', 'bar', 'baz'], dtype=object),
#  318: array(['foo', 'bar', 'baz'], dtype=object),
#  319: array(['foo', 'bar', 'baz'], dtype=object),
#  320: array(['foo', 'bar', 'baz'], dtype=object),
#  321: array(['foo', 'bar', 'baz'], dtype=object),
#  322: array(['foo', 'bar', 'baz'], dtype=object),
#  323: array(['foo', 'bar', 'baz'], dtype=object),
#  324: array(['foo', 'bar', 'baz'], dtype=object),
#  325: array(['foo', 'bar', 'baz'], dtype=object),
#  326: array(['foo', 'bar', 'baz'], dtype=object),
#  327: array(['foo', 'bar', 'baz'], dtype=object),
#  328: array(['foo', 'bar', 'baz'], dtype=object),
#  329: array(['foo', 'bar', 'baz'], dtype=object),
#  330: array(['foo', 'bar', 'baz'], dtype=object),
#  331: array(['foo', 'bar', 'baz'], dtype=object),
#  332: array(['foo', 'bar', 'baz'], dtype=object),
#  333: array(['foo', 'bar', 'baz'], dtype=object),
#  334: array(['foo', 'bar', 'baz'], dtype=object),
#  335: array(['foo', 'bar', 'baz'], dtype=object),
#  336: array(['foo', 'bar', 'baz'], dtype=object),
#  337: array(['foo', 'bar', 'baz'], dtype=object),
#  338: array(['foo', 'bar', 'baz'], dtype=object),
#  339: array(['foo', 'bar', 'baz'], dtype=object),
#  340: array(['foo', 'bar', 'baz'], dtype=object),
#  341: array(['foo', 'bar', 'baz'], dtype=object),
#  342: array(['foo', 'bar', 'baz'], dtype=object),
#  343: array(['foo', 'bar', 'baz'], dtype=object),
#  344: array(['foo', 'bar', 'baz'], dtype=object),
#  345: array(['foo', 'bar', 'baz'], dtype=object),
#  346: array(['foo', 'bar', 'baz'], dtype=object),
#  347: array(['foo', 'bar', 'baz'], dtype=object),
#  348: array(['foo', 'bar', 'baz'], dtype=object),
#  349: array(['foo', 'bar', 'baz'], dtype=object),
#  350: array(['foo', 'bar', 'baz'], dtype=object),
#  351: array(['foo', 'bar', 'baz'], dtype=object),
#  352: array(['foo', 'bar', 'baz'], dtype=object),
#  353: array(['foo', 'bar', 'baz'], dtype=object),
#  354: array(['foo', 'bar', 'baz'], dtype=object),
#  355: array(['foo', 'bar', 'baz'], dtype=object),
#  356: array(['foo', 'bar', 'baz'], dtype=object),
#  357: array(['foo', 'bar', 'baz'], dtype=object),
#  358: array(['foo', 'bar', 'baz'], dtype=object),
#  359: array(['foo', 'bar', 'baz'], dtype=object),
#  360: array(['foo', 'bar', 'baz'], dtype=object),
#  361: array(['foo', 'bar', 'baz'], dtype=object),
#  362: array(['foo', 'bar', 'baz'], dtype=object),
#  363: array(['foo', 'bar', 'baz'], dtype=object),
#  364: array(['foo', 'bar', 'baz'], dtype=object),
#  365: array(['foo', 'bar', 'baz'], dtype=object),
#  366: array(['foo', 'bar', 'baz'], dtype=object),
#  367: array(['foo', 'bar', 'baz'], dtype=object),
#  368: array(['foo', 'bar', 'baz'], dtype=object),
#  369: array(['foo', 'bar', 'baz'], dtype=object),
#  370: array(['foo', 'bar', 'baz'], dtype=object),
#  371: array(['foo', 'bar', 'baz'], dtype=object),
#  372: array(['foo', 'bar', 'baz'], dtype=object),
#  373: array(['foo', 'bar', 'baz'], dtype=object),
#  374: array(['foo', 'bar', 'baz'], dtype=object),
#  375: array(['foo', 'bar', 'baz'], dtype=object),
#  376: array(['foo', 'bar', 'baz'], dtype=object),
#  377: array(['foo', 'bar', 'baz'], dtype=object),
#  378: array(['foo', 'bar', 'baz'], dtype=object),
#  379: array(['foo', 'bar', 'baz'], dtype=object),
#  380: array(['foo', 'bar', 'baz'], dtype=object),
#  381: array(['foo', 'bar', 'baz'], dtype=object),
#  382: array(['foo', 'bar', 'baz'], dtype=object),
#  383: array(['foo', 'bar', 'baz'], dtype=object),
#  384: array(['foo', 'bar', 'baz'], dtype=object),
#  385: array(['foo', 'bar', 'baz'], dtype=object),
#  386: array(['foo', 'bar', 'baz'], dtype=object),
#  387: array(['foo', 'bar', 'baz'], dtype=object),
#  388: array(['foo', 'bar', 'baz'], dtype=object),
#  389: array(['foo', 'bar', 'baz'], dtype=object),
#  390: array(['foo', 'bar', 'baz'], dtype=object),
#  391: array(['foo', 'bar', 'baz'], dtype=object),
#  392: array(['foo', 'bar', 'baz'], dtype=object),
#  393: array(['foo', 'bar', 'baz'], dtype=object),
#  394: array(['foo', 'bar', 'baz'], dtype=object),
#  395: array(['foo', 'bar', 'baz'], dtype=object),
#  396: array(['foo', 'bar', 'baz'], dtype=object),
#  397: array(['foo', 'bar', 'baz'], dtype=object),
#  398: array(['foo', 'bar', 'baz'], dtype=object),
#  399: array(['foo', 'bar', 'baz'], dtype=object),
#  400: array(['foo', 'bar', 'baz'], dtype=object),
#  401: array(['foo', 'bar', 'baz'], dtype=object),
#  402: array(['foo', 'bar', 'baz'], dtype=object),
#  403: array(['foo', 'bar', 'baz'], dtype=object),
#  404: array(['foo', 'bar', 'baz'], dtype=object),
#  405: array(['foo', 'bar', 'baz'], dtype=object),
#  406: array(['foo', 'bar', 'baz'], dtype=object),
#  407: array(['foo', 'bar', 'baz'], dtype=object),
#  408: array(['foo', 'bar', 'baz'], dtype=object),
#  409: array(['foo', 'bar', 'baz'], dtype=object),
#  410: array(['foo', 'bar', 'baz'], dtype=object),
#  411: array(['foo', 'bar', 'baz'], dtype=object),
#  412: array(['foo', 'bar', 'baz'], dtype=object),
#  413: array(['foo', 'bar', 'baz'], dtype=object),
#  414: array(['foo', 'bar', 'baz'], dtype=object),
#  415: array(['foo', 'bar', 'baz'], dtype=object),
#  416: array(['foo', 'bar', 'baz'], dtype=object),
#  417: array(['foo', 'bar', 'baz'], dtype=object),
#  418: array(['foo', 'bar', 'baz'], dtype=object),
#  419: array(['foo', 'bar', 'baz'], dtype=object),
#  420: array(['foo', 'bar', 'baz'], dtype=object),
#  421: array(['foo', 'bar', 'baz'], dtype=object),
#  422: array(['foo', 'bar', 'baz'], dtype=object),
#  423: array(['foo', 'bar', 'baz'], dtype=object),
#  424: array(['foo', 'bar', 'baz'], dtype=object),
#  425: array(['foo', 'bar', 'baz'], dtype=object),
#  426: array(['foo', 'bar', 'baz'], dtype=object),
#  427: array(['foo', 'bar', 'baz'], dtype=object),
#  428: array(['foo', 'bar', 'baz'], dtype=object),
#  429: array(['foo', 'bar', 'baz'], dtype=object),
#  430: array(['foo', 'bar', 'baz'], dtype=object),
#  431: array(['foo', 'bar', 'baz'], dtype=object),
#  432: array(['foo', 'bar', 'baz'], dtype=object),
#  433: array(['foo', 'bar', 'baz'], dtype=object),
#  434: array(['foo', 'bar', 'baz'], dtype=object),
#  435: array(['foo', 'bar', 'baz'], dtype=object),
#  436: array(['foo', 'bar', 'baz'], dtype=object),
#  437: array(['foo', 'bar', 'baz'], dtype=object),
#  438: array(['foo', 'bar', 'baz'], dtype=object),
#  439: array(['foo', 'bar', 'baz'], dtype=object),
#  440: array(['foo', 'bar', 'baz'], dtype=object),
#  441: array(['foo', 'bar', 'baz'], dtype=object),
#  442: array(['foo', 'bar', 'baz'], dtype=object),
#  443: array(['foo', 'bar', 'baz'], dtype=object),
#  444: array(['foo', 'bar', 'baz'], dtype=object),
#  445: array(['foo', 'bar', 'baz'], dtype=object),
#  446: array(['foo', 'bar', 'baz'], dtype=object),
#  447: array(['foo', 'bar', 'baz'], dtype=object),
#  448: array(['foo', 'bar', 'baz'], dtype=object),
#  449: array(['foo', 'bar', 'baz'], dtype=object),
#  450: array(['foo', 'bar', 'baz'], dtype=object),
#  451: array(['foo', 'bar', 'baz'], dtype=object),
#  452: array(['foo', 'bar', 'baz'], dtype=object),
#  453: array(['foo', 'bar', 'baz'], dtype=object),
#  454: array(['foo', 'bar', 'baz'], dtype=object),
#  455: array(['foo', 'bar', 'baz'], dtype=object),
#  456: array(['foo', 'bar', 'baz'], dtype=object),
#  457: array(['foo', 'bar', 'baz'], dtype=object),
#  458: array(['foo', 'bar', 'baz'], dtype=object),
#  459: array(['foo', 'bar', 'baz'], dtype=object),
#  460: array(['foo', 'bar', 'baz'], dtype=object),
#  461: array(['foo', 'bar', 'baz'], dtype=object),
#  462: array(['foo', 'bar', 'baz'], dtype=object),
#  463: array(['foo', 'bar', 'baz'], dtype=object),
#  464: array(['foo', 'bar', 'baz'], dtype=object),
#  465: array(['foo', 'bar', 'baz'], dtype=object),
#  466: array(['foo', 'bar', 'baz'], dtype=object),
#  467: array(['foo', 'bar', 'baz'], dtype=object),
#  468: array(['foo', 'bar', 'baz'], dtype=object),
#  469: array(['foo', 'bar', 'baz'], dtype=object),
#  470: array(['foo', 'bar', 'baz'], dtype=object),
#  471: array(['foo', 'bar', 'baz'], dtype=object),
#  472: array(['foo', 'bar', 'baz'], dtype=object),
#  473: array(['foo', 'bar', 'baz'], dtype=object),
#  474: array(['foo', 'bar', 'baz'], dtype=object),
#  475: array(['foo', 'bar', 'baz'], dtype=object),
#  476: array(['foo', 'bar', 'baz'], dtype=object),
#  477: array(['foo', 'bar', 'baz'], dtype=object),
#  478: array(['foo', 'bar', 'baz'], dtype=object),
#  479: array(['foo', 'bar', 'baz'], dtype=object),
#  480: array(['foo', 'bar', 'baz'], dtype=object),
#  481: array(['foo', 'bar', 'baz'], dtype=object),
#  482: array(['foo', 'bar', 'baz'], dtype=object),
#  483: array(['foo', 'bar', 'baz'], dtype=object),
#  484: array(['foo', 'bar', 'baz'], dtype=object),
#  485: array(['foo', 'bar', 'baz'], dtype=object),
#  486: array(['foo', 'bar', 'baz'], dtype=object),
#  487: array(['foo', 'bar', 'baz'], dtype=object),
#  488: array(['foo', 'bar', 'baz'], dtype=object),
#  489: array(['foo', 'bar', 'baz'], dtype=object),
#  490: array(['foo', 'bar', 'baz'], dtype=object),
#  491: array(['foo', 'bar', 'baz'], dtype=object),
#  492: array(['foo', 'bar', 'baz'], dtype=object),
#  493: array(['foo', 'bar', 'baz'], dtype=object),
#  494: array(['foo', 'bar', 'baz'], dtype=object),
#  495: array(['foo', 'bar', 'baz'], dtype=object),
#  496: array(['foo', 'bar', 'baz'], dtype=object),
#  497: array(['foo', 'bar', 'baz'], dtype=object),
#  498: array(['foo', 'bar', 'baz'], dtype=object),
#  499: array(['foo', 'bar', 'baz'], dtype=object),
#  500: array(['foo', 'bar', 'baz'], dtype=object),
#  501: array(['foo', 'bar', 'baz'], dtype=object),
#  502: array(['foo', 'bar', 'baz'], dtype=object),
#  503: array(['foo', 'bar', 'baz'], dtype=object),
#  504: array(['foo', 'bar', 'baz'], dtype=object),
#  505: array(['foo', 'bar', 'baz'], dtype=object),
#  506: array(['foo', 'bar', 'baz'], dtype=object),
#  507: array(['foo', 'bar', 'baz'], dtype=object),
#  508: array(['foo', 'bar', 'baz'], dtype=object),
#  509: array(['foo', 'bar', 'baz'], dtype=object),
#  510: array(['foo', 'bar', 'baz'], dtype=object),
#  511: array(['foo', 'bar', 'baz'], dtype=object),
#  512: array(['foo', 'bar', 'baz'], dtype=object),
#  513: array(['foo', 'bar', 'baz'], dtype=object),
#  514: array(['foo', 'bar', 'baz'], dtype=object),
#  515: array(['foo', 'bar', 'baz'], dtype=object),
#  516: array(['foo', 'bar', 'baz'], dtype=object),
#  517: array(['foo', 'bar', 'baz'], dtype=object),
#  518: array(['foo', 'bar', 'baz'], dtype=object),
#  519: array(['foo', 'bar', 'baz'], dtype=object),
#  520: array(['foo', 'bar', 'baz'], dtype=object),
#  521: array(['foo', 'bar', 'baz'], dtype=object),
#  522: array(['foo', 'bar', 'baz'], dtype=object),
#  523: array(['foo', 'bar', 'baz'], dtype=object),
#  524: array(['foo', 'bar', 'baz'], dtype=object),
#  525: array(['foo', 'bar', 'baz'], dtype=object),
#  526: array(['foo', 'bar', 'baz'], dtype=object),
#  527: array(['foo', 'bar', 'baz'], dtype=object),
#  528: array(['foo', 'bar', 'baz'], dtype=object),
#  529: array(['foo', 'bar', 'baz'], dtype=object),
#  530: array(['foo', 'bar', 'baz'], dtype=object),
#  531: array(['foo', 'bar', 'baz'], dtype=object),
#  532: array(['foo', 'bar', 'baz'], dtype=object),
#  533: array(['foo', 'bar', 'baz'], dtype=object),
#  534: array(['foo', 'bar', 'baz'], dtype=object),
#  535: array(['foo', 'bar', 'baz'], dtype=object),
#  536: array(['foo', 'bar', 'baz'], dtype=object),
#  537: array(['foo', 'bar', 'baz'], dtype=object),
#  538: array(['foo', 'bar', 'baz'], dtype=object),
#  539: array(['foo', 'bar', 'baz'], dtype=object),
#  540: array(['foo', 'bar', 'baz'], dtype=object),
#  541: array(['foo', 'bar', 'baz'], dtype=object),
#  542: array(['foo', 'bar', 'baz'], dtype=object),
#  543: array(['foo', 'bar', 'baz'], dtype=object),
#  544: array(['foo', 'bar', 'baz'], dtype=object),
#  545: array(['foo', 'bar', 'baz'], dtype=object),
#  546: array(['foo', 'bar', 'baz'], dtype=object),
#  547: array(['foo', 'bar', 'baz'], dtype=object),
#  548: array(['foo', 'bar', 'baz'], dtype=object),
#  549: array(['foo', 'bar', 'baz'], dtype=object),
#  550: array(['foo', 'bar', 'baz'], dtype=object),
#  551: array(['foo', 'bar', 'baz'], dtype=object),
#  552: array(['foo', 'bar', 'baz'], dtype=object),
#  553: array(['foo', 'bar', 'baz'], dtype=object),
#  554: array(['foo', 'bar', 'baz'], dtype=object),
#  555: array(['foo', 'bar', 'baz'], dtype=object),
#  556: array(['foo', 'bar', 'baz'], dtype=object),
#  557: array(['foo', 'bar', 'baz'], dtype=object),
#  558: array(['foo', 'bar', 'baz'], dtype=object),
#  559: array(['foo', 'bar', 'baz'], dtype=object),
#  560: array(['foo', 'bar', 'baz'], dtype=object),
#  561: array(['foo', 'bar', 'baz'], dtype=object),
#  562: array(['foo', 'bar', 'baz'], dtype=object),
#  563: array(['foo', 'bar', 'baz'], dtype=object),
#  564: array(['foo', 'bar', 'baz'], dtype=object),
#  565: array(['foo', 'bar', 'baz'], dtype=object),
#  566: array(['foo', 'bar', 'baz'], dtype=object),
#  567: array(['foo', 'bar', 'baz'], dtype=object),
#  568: array(['foo', 'bar', 'baz'], dtype=object),
#  569: array(['foo', 'bar', 'baz'], dtype=object),
#  570: array(['foo', 'bar', 'baz'], dtype=object),
#  571: array(['foo', 'bar', 'baz'], dtype=object),
#  572: array(['foo', 'bar', 'baz'], dtype=object),
#  573: array(['foo', 'bar', 'baz'], dtype=object),
#  574: array(['foo', 'bar', 'baz'], dtype=object),
#  575: array(['foo', 'bar', 'baz'], dtype=object),
#  576: array(['foo', 'bar', 'baz'], dtype=object),
#  577: array(['foo', 'bar', 'baz'], dtype=object),
#  578: array(['foo', 'bar', 'baz'], dtype=object),
#  579: array(['foo', 'bar', 'baz'], dtype=object),
#  580: array(['foo', 'bar', 'baz'], dtype=object),
#  581: array(['foo', 'bar', 'baz'], dtype=object),
#  582: array(['foo', 'bar', 'baz'], dtype=object),
#  583: array(['foo', 'bar', 'baz'], dtype=object),
#  584: array(['foo', 'bar', 'baz'], dtype=object),
#  585: array(['foo', 'bar', 'baz'], dtype=object),
#  586: array(['foo', 'bar', 'baz'], dtype=object),
#  587: array(['foo', 'bar', 'baz'], dtype=object),
#  588: array(['foo', 'bar', 'baz'], dtype=object),
#  589: array(['foo', 'bar', 'baz'], dtype=object),
#  590: array(['foo', 'bar', 'baz'], dtype=object),
#  591: array(['foo', 'bar', 'baz'], dtype=object),
#  592: array(['foo', 'bar', 'baz'], dtype=object),
#  593: array(['foo', 'bar', 'baz'], dtype=object),
#  594: array(['foo', 'bar', 'baz'], dtype=object),
#  595: array(['foo', 'bar', 'baz'], dtype=object),
#  596: array(['foo', 'bar', 'baz'], dtype=object),
#  597: array(['foo', 'bar', 'baz'], dtype=object),
#  598: array(['foo', 'bar', 'baz'], dtype=object),
#  599: array(['foo', 'bar', 'baz'], dtype=object),
#  600: array(['foo', 'bar', 'baz'], dtype=object),
#  601: array(['foo', 'bar', 'baz'], dtype=object),
#  602: array(['foo', 'bar', 'baz'], dtype=object),
#  603: array(['foo', 'bar', 'baz'], dtype=object),
#  604: array(['foo', 'bar', 'baz'], dtype=object),
#  605: array(['foo', 'bar', 'baz'], dtype=object),
#  606: array(['foo', 'bar', 'baz'], dtype=object),
#  607: array(['foo', 'bar', 'baz'], dtype=object),
#  608: array(['foo', 'bar', 'baz'], dtype=object),
#  609: array(['foo', 'bar', 'baz'], dtype=object),
#  610: array(['foo', 'bar', 'baz'], dtype=object),
#  611: array(['foo', 'bar', 'baz'], dtype=object),
#  612: array(['foo', 'bar', 'baz'], dtype=object),
#  613: array(['foo', 'bar', 'baz'], dtype=object),
#  614: array(['foo', 'bar', 'baz'], dtype=object),
#  615: array(['foo', 'bar', 'baz'], dtype=object),
#  616: array(['foo', 'bar', 'baz'], dtype=object),
#  617: array(['foo', 'bar', 'baz'], dtype=object),
#  618: array(['foo', 'bar', 'baz'], dtype=object),
#  619: array(['foo', 'bar', 'baz'], dtype=object),
#  620: array(['foo', 'bar', 'baz'], dtype=object),
#  621: array(['foo', 'bar', 'baz'], dtype=object),
#  622: array(['foo', 'bar', 'baz'], dtype=object),
#  623: array(['foo', 'bar', 'baz'], dtype=object),
#  624: array(['foo', 'bar', 'baz'], dtype=object),
#  625: array(['foo', 'bar', 'baz'], dtype=object),
#  626: array(['foo', 'bar', 'baz'], dtype=object),
#  627: array(['foo', 'bar', 'baz'], dtype=object),
#  628: array(['foo', 'bar', 'baz'], dtype=object),
#  629: array(['foo', 'bar', 'baz'], dtype=object),
#  630: array(['foo', 'bar', 'baz'], dtype=object),
#  631: array(['foo', 'bar', 'baz'], dtype=object),
#  632: array(['foo', 'bar', 'baz'], dtype=object),
#  633: array(['foo', 'bar', 'baz'], dtype=object),
#  634: array(['foo', 'bar', 'baz'], dtype=object),
#  635: array(['foo', 'bar', 'baz'], dtype=object),
#  636: array(['foo', 'bar', 'baz'], dtype=object),
#  637: array(['foo', 'bar', 'baz'], dtype=object),
#  638: array(['foo', 'bar', 'baz'], dtype=object),
#  639: array(['foo', 'bar', 'baz'], dtype=object),
#  640: array(['foo', 'bar', 'baz'], dtype=object),
#  641: array(['foo', 'bar', 'baz'], dtype=object),
#  642: array(['foo', 'bar', 'baz'], dtype=object),
#  643: array(['foo', 'bar', 'baz'], dtype=object),
#  644: array(['foo', 'bar', 'baz'], dtype=object),
#  645: array(['foo', 'bar', 'baz'], dtype=object),
#  646: array(['foo', 'bar', 'baz'], dtype=object),
#  647: array(['foo', 'bar', 'baz'], dtype=object),
#  648: array(['foo', 'bar', 'baz'], dtype=object),
#  649: array(['foo', 'bar', 'baz'], dtype=object),
#  650: array(['foo', 'bar', 'baz'], dtype=object),
#  651: array(['foo', 'bar', 'baz'], dtype=object),
#  652: array(['foo', 'bar', 'baz'], dtype=object),
#  653: array(['foo', 'bar', 'baz'], dtype=object),
#  654: array(['foo', 'bar', 'baz'], dtype=object),
#  655: array(['foo', 'bar', 'baz'], dtype=object),
#  656: array(['foo', 'bar', 'baz'], dtype=object),
#  657: array(['foo', 'bar', 'baz'], dtype=object),
#  658: array(['foo', 'bar', 'baz'], dtype=object),
#  659: array(['foo', 'bar', 'baz'], dtype=object),
#  660: array(['foo', 'bar', 'baz'], dtype=object),
#  661: array(['foo', 'bar', 'baz'], dtype=object),
#  662: array(['foo', 'bar', 'baz'], dtype=object),
#  663: array(['foo', 'bar', 'baz'], dtype=object),
#  664: array(['foo', 'bar', 'baz'], dtype=object),
#  665: array(['foo', 'bar', 'baz'], dtype=object),
#  666: array(['foo', 'bar', 'baz'], dtype=object),
#  667: array(['foo', 'bar', 'baz'], dtype=object),
#  668: array(['foo', 'bar', 'baz'], dtype=object),
#  669: array(['foo', 'bar', 'baz'], dtype=object),
#  670: array(['foo', 'bar', 'baz'], dtype=object),
#  671: array(['foo', 'bar', 'baz'], dtype=object),
#  672: array(['foo', 'bar', 'baz'], dtype=object),
#  673: array(['foo', 'bar', 'baz'], dtype=object),
#  674: array(['foo', 'bar', 'baz'], dtype=object),
#  675: array(['foo', 'bar', 'baz'], dtype=object),
#  676: array(['foo', 'bar', 'baz'], dtype=object),
#  677: array(['foo', 'bar', 'baz'], dtype=object),
#  678: array(['foo', 'bar', 'baz'], dtype=object),
#  679: array(['foo', 'bar', 'baz'], dtype=object),
#  680: array(['foo', 'bar', 'baz'], dtype=object),
#  681: array(['foo', 'bar', 'baz'], dtype=object),
#  682: array(['foo', 'bar', 'baz'], dtype=object),
#  683: array(['foo', 'bar', 'baz'], dtype=object),
#  684: array(['foo', 'bar', 'baz'], dtype=object),
#  685: array(['foo', 'bar', 'baz'], dtype=object),
#  686: array(['foo', 'bar', 'baz'], dtype=object),
#  687: array(['foo', 'bar', 'baz'], dtype=object),
#  688: array(['foo', 'bar', 'baz'], dtype=object),
#  689: array(['foo', 'bar', 'baz'], dtype=object),
#  690: array(['foo', 'bar', 'baz'], dtype=object),
#  691: array(['foo', 'bar', 'baz'], dtype=object),
#  692: array(['foo', 'bar', 'baz'], dtype=object),
#  693: array(['foo', 'bar', 'baz'], dtype=object),
#  694: array(['foo', 'bar', 'baz'], dtype=object),
#  695: array(['foo', 'bar', 'baz'], dtype=object),
#  696: array(['foo', 'bar', 'baz'], dtype=object),
#  697: array(['foo', 'bar', 'baz'], dtype=object),
#  698: array(['foo', 'bar', 'baz'], dtype=object),
#  699: array(['foo', 'bar', 'baz'], dtype=object),
#  700: array(['foo', 'bar', 'baz'], dtype=object),
#  701: array(['foo', 'bar', 'baz'], dtype=object),
#  702: array(['foo', 'bar', 'baz'], dtype=object),
#  703: array(['foo', 'bar', 'baz'], dtype=object),
#  704: array(['foo', 'bar', 'baz'], dtype=object),
#  705: array(['foo', 'bar', 'baz'], dtype=object),
#  706: array(['foo', 'bar', 'baz'], dtype=object),
#  707: array(['foo', 'bar', 'baz'], dtype=object),
#  708: array(['foo', 'bar', 'baz'], dtype=object),
#  709: array(['foo', 'bar', 'baz'], dtype=object),
#  710: array(['foo', 'bar', 'baz'], dtype=object),
#  711: array(['foo', 'bar', 'baz'], dtype=object),
#  712: array(['foo', 'bar', 'baz'], dtype=object),
#  713: array(['foo', 'bar', 'baz'], dtype=object),
#  714: array(['foo', 'bar', 'baz'], dtype=object),
#  715: array(['foo', 'bar', 'baz'], dtype=object),
#  716: array(['foo', 'bar', 'baz'], dtype=object),
#  717: array(['foo', 'bar', 'baz'], dtype=object),
#  718: array(['foo', 'bar', 'baz'], dtype=object),
#  719: array(['foo', 'bar', 'baz'], dtype=object),
#  720: array(['foo', 'bar', 'baz'], dtype=object),
#  721: array(['foo', 'bar', 'baz'], dtype=object),
#  722: array(['foo', 'bar', 'baz'], dtype=object),
#  723: array(['foo', 'bar', 'baz'], dtype=object),
#  724: array(['foo', 'bar', 'baz'], dtype=object),
#  725: array(['foo', 'bar', 'baz'], dtype=object),
#  726: array(['foo', 'bar', 'baz'], dtype=object),
#  727: array(['foo', 'bar', 'baz'], dtype=object),
#  728: array(['foo', 'bar', 'baz'], dtype=object),
#  729: array(['foo', 'bar', 'baz'], dtype=object),
#  730: array(['foo', 'bar', 'baz'], dtype=object),
#  731: array(['foo', 'bar', 'baz'], dtype=object),
#  732: array(['foo', 'bar', 'baz'], dtype=object),
#  733: array(['foo', 'bar', 'baz'], dtype=object),
#  734: array(['foo', 'bar', 'baz'], dtype=object),
#  735: array(['foo', 'bar', 'baz'], dtype=object),
#  736: array(['foo', 'bar', 'baz'], dtype=object),
#  737: array(['foo', 'bar', 'baz'], dtype=object),
#  738: array(['foo', 'bar', 'baz'], dtype=object),
#  739: array(['foo', 'bar', 'baz'], dtype=object),
#  740: array(['foo', 'bar', 'baz'], dtype=object),
#  741: array(['foo', 'bar', 'baz'], dtype=object),
#  742: array(['foo', 'bar', 'baz'], dtype=object),
#  743: array(['foo', 'bar', 'baz'], dtype=object),
#  744: array(['foo', 'bar', 'baz'], dtype=object),
#  745: array(['foo', 'bar', 'baz'], dtype=object),
#  746: array(['foo', 'bar', 'baz'], dtype=object),
#  747: array(['foo', 'bar', 'baz'], dtype=object),
#  748: array(['foo', 'bar', 'baz'], dtype=object),
#  749: array(['foo', 'bar', 'baz'], dtype=object),
#  750: array(['foo', 'bar', 'baz'], dtype=object),
#  751: array(['foo', 'bar', 'baz'], dtype=object),
#  752: array(['foo', 'bar', 'baz'], dtype=object),
#  753: array(['foo', 'bar', 'baz'], dtype=object),
#  754: array(['foo', 'bar', 'baz'], dtype=object),
#  755: array(['foo', 'bar', 'baz'], dtype=object),
#  756: array(['foo', 'bar', 'baz'], dtype=object),
#  757: array(['foo', 'bar', 'baz'], dtype=object),
#  758: array(['foo', 'bar', 'baz'], dtype=object),
#  759: array(['foo', 'bar', 'baz'], dtype=object),
#  760: array(['foo', 'bar', 'baz'], dtype=object),
#  761: array(['foo', 'bar', 'baz'], dtype=object),
#  762: array(['foo', 'bar', 'baz'], dtype=object),
#  763: array(['foo', 'bar', 'baz'], dtype=object),
#  764: array(['foo', 'bar', 'baz'], dtype=object),
#  765: array(['foo', 'bar', 'baz'], dtype=object),
#  766: array(['foo', 'bar', 'baz'], dtype=object),
#  767: array(['foo', 'bar', 'baz'], dtype=object),
#  768: array(['foo', 'bar', 'baz'], dtype=object),
#  769: array(['foo', 'bar', 'baz'], dtype=object),
#  770: array(['foo', 'bar', 'baz'], dtype=object),
#  771: array(['foo', 'bar', 'baz'], dtype=object),
#  772: array(['foo', 'bar', 'baz'], dtype=object),
#  773: array(['foo', 'bar', 'baz'], dtype=object),
#  774: array(['foo', 'bar', 'baz'], dtype=object),
#  775: array(['foo', 'bar', 'baz'], dtype=object),
#  776: array(['foo', 'bar', 'baz'], dtype=object),
#  777: array(['foo', 'bar', 'baz'], dtype=object),
#  778: array(['foo', 'bar', 'baz'], dtype=object),
#  779: array(['foo', 'bar', 'baz'], dtype=object),
#  780: array(['foo', 'bar', 'baz'], dtype=object),
#  781: array(['foo', 'bar', 'baz'], dtype=object),
#  782: array(['foo', 'bar', 'baz'], dtype=object),
#  783: array(['foo', 'bar', 'baz'], dtype=object),
#  784: array(['foo', 'bar', 'baz'], dtype=object),
#  785: array(['foo', 'bar', 'baz'], dtype=object),
#  786: array(['foo', 'bar', 'baz'], dtype=object),
#  787: array(['foo', 'bar', 'baz'], dtype=object),
#  788: array(['foo', 'bar', 'baz'], dtype=object),
#  789: array(['foo', 'bar', 'baz'], dtype=object),
#  790: array(['foo', 'bar', 'baz'], dtype=object),
#  791: array(['foo', 'bar', 'baz'], dtype=object),
#  792: array(['foo', 'bar', 'baz'], dtype=object),
#  793: array(['foo', 'bar', 'baz'], dtype=object),
#  794: array(['foo', 'bar', 'baz'], dtype=object),
#  795: array(['foo', 'bar', 'baz'], dtype=object),
#  796: array(['foo', 'bar', 'baz'], dtype=object),
#  797: array(['foo', 'bar', 'baz'], dtype=object),
#  798: array(['foo', 'bar', 'baz'], dtype=object),
#  799: array(['foo', 'bar', 'baz'], dtype=object),
#  800: array(['foo', 'bar', 'baz'], dtype=object),
#  801: array(['foo', 'bar', 'baz'], dtype=object),
#  802: array(['foo', 'bar', 'baz'], dtype=object),
#  803: array(['foo', 'bar', 'baz'], dtype=object),
#  804: array(['foo', 'bar', 'baz'], dtype=object),
#  805: array(['foo', 'bar', 'baz'], dtype=object),
#  806: array(['foo', 'bar', 'baz'], dtype=object),
#  807: array(['foo', 'bar', 'baz'], dtype=object),
#  808: array(['foo', 'bar', 'baz'], dtype=object),
#  809: array(['foo', 'bar', 'baz'], dtype=object),
#  810: array(['foo', 'bar', 'baz'], dtype=object),
#  811: array(['foo', 'bar', 'baz'], dtype=object),
#  812: array(['foo', 'bar', 'baz'], dtype=object),
#  813: array(['foo', 'bar', 'baz'], dtype=object),
#  814: array(['foo', 'bar', 'baz'], dtype=object),
#  815: array(['foo', 'bar', 'baz'], dtype=object),
#  816: array(['foo', 'bar', 'baz'], dtype=object),
#  817: array(['foo', 'bar', 'baz'], dtype=object),
#  818: array(['foo', 'bar', 'baz'], dtype=object),
#  819: array(['foo', 'bar', 'baz'], dtype=object),
#  820: array(['foo', 'bar', 'baz'], dtype=object),
#  821: array(['foo', 'bar', 'baz'], dtype=object),
#  822: array(['foo', 'bar', 'baz'], dtype=object),
#  823: array(['foo', 'bar', 'baz'], dtype=object),
#  824: array(['foo', 'bar', 'baz'], dtype=object),
#  825: array(['foo', 'bar', 'baz'], dtype=object),
#  826: array(['foo', 'bar', 'baz'], dtype=object),
#  827: array(['foo', 'bar', 'baz'], dtype=object),
#  828: array(['foo', 'bar', 'baz'], dtype=object),
#  829: array(['foo', 'bar', 'baz'], dtype=object),
#  830: array(['foo', 'bar', 'baz'], dtype=object),
#  831: array(['foo', 'bar', 'baz'], dtype=object),
#  832: array(['foo', 'bar', 'baz'], dtype=object),
#  833: array(['foo', 'bar', 'baz'], dtype=object),
#  834: array(['foo', 'bar', 'baz'], dtype=object),
#  835: array(['foo', 'bar', 'baz'], dtype=object),
#  836: array(['foo', 'bar', 'baz'], dtype=object),
#  837: array(['foo', 'bar', 'baz'], dtype=object),
#  838: array(['foo', 'bar', 'baz'], dtype=object),
#  839: array(['foo', 'bar', 'baz'], dtype=object),
#  840: array(['foo', 'bar', 'baz'], dtype=object),
#  841: array(['foo', 'bar', 'baz'], dtype=object),
#  842: array(['foo', 'bar', 'baz'], dtype=object),
#  843: array(['foo', 'bar', 'baz'], dtype=object),
#  844: array(['foo', 'bar', 'baz'], dtype=object),
#  845: array(['foo', 'bar', 'baz'], dtype=object),
#  846: array(['foo', 'bar', 'baz'], dtype=object),
#  847: array(['foo', 'bar', 'baz'], dtype=object),
#  848: array(['foo', 'bar', 'baz'], dtype=object),
#  849: array(['foo', 'bar', 'baz'], dtype=object),
#  850: array(['foo', 'bar', 'baz'], dtype=object),
#  851: array(['foo', 'bar', 'baz'], dtype=object),
#  852: array(['foo', 'bar', 'baz'], dtype=object),
#  853: array(['foo', 'bar', 'baz'], dtype=object),
#  854: array(['foo', 'bar', 'baz'], dtype=object),
#  855: array(['foo', 'bar', 'baz'], dtype=object),
#  856: array(['foo', 'bar', 'baz'], dtype=object),
#  857: array(['foo', 'bar', 'baz'], dtype=object),
#  858: array(['foo', 'bar', 'baz'], dtype=object),
#  859: array(['foo', 'bar', 'baz'], dtype=object),
#  860: array(['foo', 'bar', 'baz'], dtype=object),
#  861: array(['foo', 'bar', 'baz'], dtype=object),
#  862: array(['foo', 'bar', 'baz'], dtype=object),
#  863: array(['foo', 'bar', 'baz'], dtype=object),
#  864: array(['foo', 'bar', 'baz'], dtype=object),
#  865: array(['foo', 'bar', 'baz'], dtype=object),
#  866: array(['foo', 'bar', 'baz'], dtype=object),
#  867: array(['foo', 'bar', 'baz'], dtype=object),
#  868: array(['foo', 'bar', 'baz'], dtype=object),
#  869: array(['foo', 'bar', 'baz'], dtype=object),
#  870: array(['foo', 'bar', 'baz'], dtype=object),
#  871: array(['foo', 'bar', 'baz'], dtype=object),
#  872: array(['foo', 'bar', 'baz'], dtype=object),
#  873: array(['foo', 'bar', 'baz'], dtype=object),
#  874: array(['foo', 'bar', 'baz'], dtype=object),
#  875: array(['foo', 'bar', 'baz'], dtype=object),
#  876: array(['foo', 'bar', 'baz'], dtype=object),
#  877: array(['foo', 'bar', 'baz'], dtype=object),
#  878: array(['foo', 'bar', 'baz'], dtype=object),
#  879: array(['foo', 'bar', 'baz'], dtype=object),
#  880: array(['foo', 'bar', 'baz'], dtype=object),
#  881: array(['foo', 'bar', 'baz'], dtype=object),
#  882: array(['foo', 'bar', 'baz'], dtype=object),
#  883: array(['foo', 'bar', 'baz'], dtype=object),
#  884: array(['foo', 'bar', 'baz'], dtype=object),
#  885: array(['foo', 'bar', 'baz'], dtype=object),
#  886: array(['foo', 'bar', 'baz'], dtype=object),
#  887: array(['foo', 'bar', 'baz'], dtype=object),
#  888: array(['foo', 'bar', 'baz'], dtype=object),
#  889: array(['foo', 'bar', 'baz'], dtype=object),
#  890: array(['foo', 'bar', 'baz'], dtype=object),
#  891: array(['foo', 'bar', 'baz'], dtype=object),
#  892: array(['foo', 'bar', 'baz'], dtype=object),
#  893: array(['foo', 'bar', 'baz'], dtype=object),
#  894: array(['foo', 'bar', 'baz'], dtype=object),
#  895: array(['foo', 'bar', 'baz'], dtype=object),
#  896: array(['foo', 'bar', 'baz'], dtype=object),
#  897: array(['foo', 'bar', 'baz'], dtype=object),
#  898: array(['foo', 'bar', 'baz'], dtype=object),
#  899: array(['foo', 'bar', 'baz'], dtype=object),
#  900: array(['foo', 'bar', 'baz'], dtype=object),
#  901: array(['foo', 'bar', 'baz'], dtype=object),
#  902: array(['foo', 'bar', 'baz'], dtype=object),
#  903: array(['foo', 'bar', 'baz'], dtype=object),
#  904: array(['foo', 'bar', 'baz'], dtype=object),
#  905: array(['foo', 'bar', 'baz'], dtype=object),
#  906: array(['foo', 'bar', 'baz'], dtype=object),
#  907: array(['foo', 'bar', 'baz'], dtype=object),
#  908: array(['foo', 'bar', 'baz'], dtype=object),
#  909: array(['foo', 'bar', 'baz'], dtype=object),
#  910: array(['foo', 'bar', 'baz'], dtype=object),
#  911: array(['foo', 'bar', 'baz'], dtype=object),
#  912: array(['foo', 'bar', 'baz'], dtype=object),
#  913: array(['foo', 'bar', 'baz'], dtype=object),
#  914: array(['foo', 'bar', 'baz'], dtype=object),
#  915: array(['foo', 'bar', 'baz'], dtype=object),
#  916: array(['foo', 'bar', 'baz'], dtype=object),
#  917: array(['foo', 'bar', 'baz'], dtype=object),
#  918: array(['foo', 'bar', 'baz'], dtype=object),
#  919: array(['foo', 'bar', 'baz'], dtype=object),
#  920: array(['foo', 'bar', 'baz'], dtype=object),
#  921: array(['foo', 'bar', 'baz'], dtype=object),
#  922: array(['foo', 'bar', 'baz'], dtype=object),
#  923: array(['foo', 'bar', 'baz'], dtype=object),
#  924: array(['foo', 'bar', 'baz'], dtype=object),
#  925: array(['foo', 'bar', 'baz'], dtype=object),
#  926: array(['foo', 'bar', 'baz'], dtype=object),
#  927: array(['foo', 'bar', 'baz'], dtype=object),
#  928: array(['foo', 'bar', 'baz'], dtype=object),
#  929: array(['foo', 'bar', 'baz'], dtype=object),
#  930: array(['foo', 'bar', 'baz'], dtype=object),
#  931: array(['foo', 'bar', 'baz'], dtype=object),
#  932: array(['foo', 'bar', 'baz'], dtype=object),
#  933: array(['foo', 'bar', 'baz'], dtype=object),
#  934: array(['foo', 'bar', 'baz'], dtype=object),
#  935: array(['foo', 'bar', 'baz'], dtype=object),
#  936: array(['foo', 'bar', 'baz'], dtype=object),
#  937: array(['foo', 'bar', 'baz'], dtype=object),
#  938: array(['foo', 'bar', 'baz'], dtype=object),
#  939: array(['foo', 'bar', 'baz'], dtype=object),
#  940: array(['foo', 'bar', 'baz'], dtype=object),
#  941: array(['foo', 'bar', 'baz'], dtype=object),
#  942: array(['foo', 'bar', 'baz'], dtype=object),
#  943: array(['foo', 'bar', 'baz'], dtype=object),
#  944: array(['foo', 'bar', 'baz'], dtype=object),
#  945: array(['foo', 'bar', 'baz'], dtype=object),
#  946: array(['foo', 'bar', 'baz'], dtype=object),
#  947: array(['foo', 'bar', 'baz'], dtype=object),
#  948: array(['foo', 'bar', 'baz'], dtype=object),
#  949: array(['foo', 'bar', 'baz'], dtype=object),
#  950: array(['foo', 'bar', 'baz'], dtype=object),
#  951: array(['foo', 'bar', 'baz'], dtype=object),
#  952: array(['foo', 'bar', 'baz'], dtype=object),
#  953: array(['foo', 'bar', 'baz'], dtype=object),
#  954: array(['foo', 'bar', 'baz'], dtype=object),
#  955: array(['foo', 'bar', 'baz'], dtype=object),
#  956: array(['foo', 'bar', 'baz'], dtype=object),
#  957: array(['foo', 'bar', 'baz'], dtype=object),
#  958: array(['foo', 'bar', 'baz'], dtype=object),
#  959: array(['foo', 'bar', 'baz'], dtype=object),
#  960: array(['foo', 'bar', 'baz'], dtype=object),
#  961: array(['foo', 'bar', 'baz'], dtype=object),
#  962: array(['foo', 'bar', 'baz'], dtype=object),
#  963: array(['foo', 'bar', 'baz'], dtype=object),
#  964: array(['foo', 'bar', 'baz'], dtype=object),
#  965: array(['foo', 'bar', 'baz'], dtype=object),
#  966: array(['foo', 'bar', 'baz'], dtype=object),
#  967: array(['foo', 'bar', 'baz'], dtype=object),
#  968: array(['foo', 'bar', 'baz'], dtype=object),
#  969: array(['foo', 'bar', 'baz'], dtype=object),
#  970: array(['foo', 'bar', 'baz'], dtype=object),
#  971: array(['foo', 'bar', 'baz'], dtype=object),
#  972: array(['foo', 'bar', 'baz'], dtype=object),
#  973: array(['foo', 'bar', 'baz'], dtype=object),
#  974: array(['foo', 'bar', 'baz'], dtype=object),
#  975: array(['foo', 'bar', 'baz'], dtype=object),
#  976: array(['foo', 'bar', 'baz'], dtype=object),
#  977: array(['foo', 'bar', 'baz'], dtype=object),
#  978: array(['foo', 'bar', 'baz'], dtype=object),
#  979: array(['foo', 'bar', 'baz'], dtype=object),
#  980: array(['foo', 'bar', 'baz'], dtype=object),
#  981: array(['foo', 'bar', 'baz'], dtype=object),
#  982: array(['foo', 'bar', 'baz'], dtype=object),
#  983: array(['foo', 'bar', 'baz'], dtype=object),
#  984: array(['foo', 'bar', 'baz'], dtype=object),
#  985: array(['foo', 'bar', 'baz'], dtype=object),
#  986: array(['foo', 'bar', 'baz'], dtype=object),
#  987: array(['foo', 'bar', 'baz'], dtype=object),
#  988: array(['foo', 'bar', 'baz'], dtype=object),
#  989: array(['foo', 'bar', 'baz'], dtype=object),
#  990: array(['foo', 'bar', 'baz'], dtype=object),
#  991: array(['foo', 'bar', 'baz'], dtype=object),
#  992: array(['foo', 'bar', 'baz'], dtype=object),
#  993: array(['foo', 'bar', 'baz'], dtype=object),
#  994: array(['foo', 'bar', 'baz'], dtype=object),
#  995: array(['foo', 'bar', 'baz'], dtype=object),
#  996: array(['foo', 'bar', 'baz'], dtype=object),
#  997: array(['foo', 'bar', 'baz'], dtype=object),
#  998: array(['foo', 'bar', 'baz'], dtype=object),
#  999: array(['foo', 'bar', 'baz'], dtype=object),
#  ...}

# %% [markdown]
# ### Networks setup
#
# This experiment aims to test a variety of published sparse regulatory network structures.

# %%
networks = {
    'dense': evaluator.makeRandomNetwork(density = 1),
    'random0.1': evaluator.makeRandomNetwork(density = 0.1),
    'random0.01': evaluator.makeRandomNetwork(density = 0.01),
    'cellOracle': co.data.load_human_promoter_base_GRN()
}
gc.collect()
# Out:
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2
# 0

# %%
pd.DataFrame({bn:sys.getsizeof(networks[bn])/1e6 for bn in networks}, index = ["memory"])
# Out:
#            dense  random0.1  random0.01  cellOracle
# memory  2.636366  125.36657   14.906018  329.156543

# %%
for network in [
    # Networks used in GWAS-related projects
    'gtex_rna',
    'magnum_compendium_32',   
    'magnum_compendium_394', 
    'magnum_compendium_ppi',
    'humanbase',
    # Networks used in reprogramming-related and differentiation-related projects
    'cellnet_human_Hg1332',
    'cellnet_human_Hugene',
    'MARA_FANTOM4',
    'STRING',    
    'ANANSE_0.5',
    'ANANSE_tissue_0.5'
]:
    print("Loading " + network)
    if not network in networks:
        networks[network] = evaluator.networkEdgesToMatrix(load_networks.load_grn_all_subnetworks(network))
    gc.collect()
    
# One more network used in a reprogramming-related project
networks["mogrify"] = pd.concat([networks[n] for n in ['MARA_FANTOM4','STRING']])

network_sizes = pd.DataFrame({bn:evaluator.countMatrixEdges(networks[bn]) for bn in networks}, index = ["numEdges"])
network_sizes = network_sizes.T.reset_index().rename({"index":"network"}, axis = 1)
network_sizes
# Out:
# Loading gtex_rna
# Loading magnum_compendium_32
# Loading magnum_compendium_394
# Loading magnum_compendium_ppi
# Loading humanbase
# Loading cellnet_human_Hg1332
# Loading cellnet_human_Hugene
# Loading MARA_FANTOM4
# Loading STRING
# Loading ANANSE_0.5
# Loading ANANSE_tissue_0.5
#                   network     numEdges
# 0                   dense  102313295.0
# 1               random0.1   10227517.0
# 2              random0.01    1022471.0
# 3              cellOracle    5134330.0
# 4                gtex_rna    1548622.0
# 5    magnum_compendium_32    3246008.0
# 6   magnum_compendium_394    3246008.0
# 7   magnum_compendium_ppi     246866.0
# 8               humanbase   26156969.0
# 9    cellnet_human_Hg1332     201422.0
# 10   cellnet_human_Hugene     157408.0
# 11           MARA_FANTOM4       8462.0
# 12                 STRING   11083663.0
# 13             ANANSE_0.5    2372660.0
# 14      ANANSE_tissue_0.5    3278644.0
# 15                mogrify   11092125.0

# %% [markdown]
# ### Memory consumption
#
# This experiment has been a little problematic recently in terms of memory consumed. We can check on that briefly.

# %%
pd.DataFrame({bn:sys.getsizeof(networks[bn])/1e6 for bn in networks}, index = ["memory"])
# Out:
#            dense  random0.1  random0.01  cellOracle   gtex_rna  \
# memory  2.636366  125.36657   14.906018  329.156543  19.282986
#
#         magnum_compendium_32  magnum_compendium_394  magnum_compendium_ppi  \
# memory             40.140932              40.140932                4.29154
#
#         humanbase  cellnet_human_Hg1332  cellnet_human_Hugene  MARA_FANTOM4  \
# memory  315.26506              3.123013              2.445973      0.317984
#
#             STRING  ANANSE_0.5  ANANSE_tissue_0.5     mogrify
# memory  134.298736   29.477668          40.400131  810.060376

# %% [markdown]
# ### Data setup
#
# We use the Nakatake et al data. This experiment is on per-cluster versus shared regression models, so we run Leiden clustering at many different resolutions.

# %%
ko_lab_esc_data = sc.read_h5ad(os.environ["PERTURBATION_PATH"] + "/nakatake/" + "test.h5ad")
cellFateClassifier = joblib.load(os.environ["PERTURBATION_PATH"] + "/nakatake/" + "classifier.joblib")

# %%
ko_lab_esc_data.obs.columns
# Out:
# Index(['perturbation', 'is_control', 'fraction_missing', 'leiden',
#        'fake_cluster'],
#       dtype='object')

# %%
allowedRegulators = set.union(*[set(networks[key].columns) for key in networks])
ko_lab_esc_data_train, ko_lab_esc_data_heldout, perturbationsToPredict = \
    evaluator.splitData(ko_lab_esc_data, allowedRegulators, minTestSetSize=250)
# Out:
# Example perturbations formatted as
#  (gene, expression after perturbation)
# [('ALX3', 2.829177), ('ALX3', 3.583377), ('ALX4', 1.1726332), ('ALX4', 0.7964212), ('ANKRD22', 0.43029666)]
# Test set size:
# 263
# Training set size:
# 250

# %% [markdown]
# ### Experimental metadata

# %%
n_networks = len(networks.keys())
experiments = pd.DataFrame({"network":[n for n in networks.keys()], 
                            "p":[1]*n_networks,
                            "threshold_number":[int(network_sizes['numEdges'].max())]*n_networks,
                            "pruning":["none"]*n_networks})
experiments["index"] = experiments.index
experiments.to_csv("results/" + EXPERIMENT_NAME + "/networkExperiments.csv")
experiments
# Out:
#                   network  p  threshold_number pruning  index
# 0                   dense  1         102313295    none      0
# 1               random0.1  1         102313295    none      1
# 2              random0.01  1         102313295    none      2
# 3              cellOracle  1         102313295    none      3
# 4                gtex_rna  1         102313295    none      4
# 5    magnum_compendium_32  1         102313295    none      5
# 6   magnum_compendium_394  1         102313295    none      6
# 7   magnum_compendium_ppi  1         102313295    none      7
# 8               humanbase  1         102313295    none      8
# 9    cellnet_human_Hg1332  1         102313295    none      9
# 10   cellnet_human_Hugene  1         102313295    none     10
# 11           MARA_FANTOM4  1         102313295    none     11
# 12                 STRING  1         102313295    none     12
# 13             ANANSE_0.5  1         102313295    none     13
# 14      ANANSE_tissue_0.5  1         102313295    none     14
# 15                mogrify  1         102313295    none     15

# %%
predictions = {
    i: evaluator.trainCausalModelAndPredict(expression=ko_lab_esc_data_train,
                                  baseNetwork=networks[experiments.loc[i,'network']],
                                  memoizationName="results/" + EXPERIMENT_NAME + "/" + str(i) + ".celloracle.oracle", 
                                  perturbations=perturbationsToPredict,
                                  clusterColumnName = "fake_cluster",
                                  pruningParameters = {"p":experiments.loc[i,'p'], 
                                                       "threshold_number":experiments.loc[i,'threshold_number']}) 
    for i in experiments.index
}
# Out:
# Working on results/baseNetwork_v1/0.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/1 [00:00<?, ?it/s]
# inferring GRN for all_one_cluster...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in all_one_cluster
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# Predicting ZNF74
# ALX3 ALX3 ALX4 ALX4 ANKRD22
# Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ANKRD22
# Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# AR AR ARNT2 ARNT2 ASH2L
# Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ASH2L
# Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF2 ATF2 ATF3 ATF3 BACH1 BACH1 BARHL2 BARHL2 BARX2 BARX2 BCL6 BCL6 BHLHE40 BHLHE40 BMP4 BMP4 BRF2 BRF2 CDX2 CDX2 CDX2 CDYL
# Prediction failed for CDYL with error Gene CDYL is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CDYL
# Prediction failed for CDYL with error Gene CDYL is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CEBPB CEBPB CHD4 CHD4 CREB3 CREB3 CTCF DEDD2
# Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DEDD2
# Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DLX2 DLX2 DLX4 DLX4 DMRT1 DMRT1 DMRTC2 DMRTC2 DNMT3L DNMT3L E2F4 E2F4 E2F6 E2F6 EED EED ELF2 ELF2 ELF4 ELF5 ELF5 ELK1 ELK1 ELL2
# Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELL2
# Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELOA
# Prediction failed for ELOA with error Gene ELOA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELOA
# Prediction failed for ELOA with error Gene ELOA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETS1 ETS1 ETS2 ETS2 ETV5 ETV5 FBXO15
# Prediction failed for FBXO15 with error Gene FBXO15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FBXO15
# Prediction failed for FBXO15 with error Gene FBXO15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FIGLA FIGLA FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOXD1 FOXD1 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXH1 FOXH1 FOXM1 FOXM1 FOXS1 FOXS1 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GBX2 GBX2 GLI1 GLI1 GRHL2 GRHL2 GSC GSC GTF2B GTF2B GTF2F1 GTF2F1 H2AFZ
# Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# H2AFZ
# Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HDAC3 HDAC3 HDAC8 HDAC8 HES1 HES1 HESX1 HESX1 HEY1 HEY1 HMGB2 HMGB2 HMGN1 HMGXB4 HMGXB4 HNF1A HOPX HOPX HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXB3 HOXB3 HOXB4 HOXB4 HOXC9 HOXC9 HOXD10 HOXD10 HOXD13 HOXD13 HSF1 HSF1 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF3 IRF3 IRF5 IRF5 JARID2 JARID2 JUN JUN KAT8 KAT8 KDM1A KDM1A KDM5A KDM5A KDM5B KDM5B KLF11 KLF11 KLF12 KLF15 KLF15 KLF8 KLF8 KLF9 KLF9 LHFPL6
# Prediction failed for LHFPL6 with error Gene LHFPL6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHFPL6
# Prediction failed for LHFPL6 with error Gene LHFPL6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHX1 LHX1 LHX3 LHX3 LHX4 LHX4 LMO1
# Prediction failed for LMO1 with error Gene LMO1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LMO1
# Prediction failed for LMO1 with error Gene LMO1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAB21L2
# Prediction failed for MAB21L2 with error Gene MAB21L2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAB21L2
# Prediction failed for MAB21L2 with error Gene MAB21L2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MEF2A MEF2A MEIS1 MEIS1 MEIS2 MEIS2 MKRN1 MKRN1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MXI1 MXI1 MYB MYB MYBL2 MYBL2 MYF5 MYF5 MYF6 MYF6 NELFA
# Prediction failed for NELFA with error Gene NELFA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFA
# Prediction failed for NELFA with error Gene NELFA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFE
# Prediction failed for NELFE with error Gene NELFE is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFE
# Prediction failed for NELFE with error Gene NELFE is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NEUROD1 NEUROD1 NEUROD4 NEUROD4 NEUROD6 NEUROD6 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NFE2L1 NFYB NFYB NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NKX6-3 NKX6-3 NR1D2 NR1D2 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NRF1 NRF1 NSD2 NSD2 OLIG1 OLIG1 OSTF1
# Prediction failed for OSTF1 with error Gene OSTF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OSTF1
# Prediction failed for OSTF1 with error Gene OSTF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OTP OTP OTX2 OTX2 OVOL2 OVOL2 PABPC1
# Prediction failed for PABPC1 with error Gene PABPC1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PAX2 PAX2 PAX5 PAX5 PAX6 PAX6 PAX8 PAX8 PDX1 PDX1 PHF8
# Prediction failed for PHF8 with error Gene PHF8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PHF8
# Prediction failed for PHF8 with error Gene PHF8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PHOX2B PHOX2B PITX3 PITX3 PLXNB3 PLXNB3 POLR3A POLR3A POU2AF1 POU2AF1 POU2F2 POU2F2 POU4F1 POU4F1 POU5F1 POU5F1 POU5F1 PPARGC1A PPARGC1A PTAFR
# Prediction failed for PTAFR with error Gene PTAFR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PTAFR
# Prediction failed for PTAFR with error Gene PTAFR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PTF1A PTF1A RAD21 RAD21 RBBP5
# Prediction failed for RBBP5 with error Gene RBBP5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP5
# Prediction failed for RBBP5 with error Gene RBBP5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP6
# Prediction failed for RBBP6 with error Gene RBBP6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP6
# Prediction failed for RBBP6 with error Gene RBBP6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# REPIN1 REPIN1 REST REST RFX2 RFX2 RNF2 RNF2 RUNX1 RUNX1 RUNX3 RUNX3 RUVBL2
# Prediction failed for RUVBL2 with error Gene RUVBL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RUVBL2
# Prediction failed for RUVBL2 with error Gene RUVBL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SALL4 SALL4 SAP30
# Prediction failed for SAP30 with error Gene SAP30 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SETDB1 SETDB1 SIN3A SIN3A SIX5 SIX5 SMAD1 SMAD1 SMAD2 SMAD2 SMAD4 SMAD4 SMAD5 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX2 SOX2 SOX7 SOX7 SPIC SPIC SPIC STAG1 STAG1 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A STRA8
# Prediction failed for STRA8 with error Gene STRA8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# STRA8
# Prediction failed for STRA8 with error Gene STRA8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TBX2 TBX2 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF4 TCF4 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 TGM2
# Prediction failed for TGM2 with error Gene TGM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TGM2
# Prediction failed for TGM2 with error Gene TGM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP1 THAP1 THAP11 THAP11 THAP3 THAP3 THAP7 THAP7 TP53 TP53 TRPV2
# Prediction failed for TRPV2 with error Gene TRPV2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TRPV2
# Prediction failed for TRPV2 with error Gene TRPV2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TWIST2 TWIST2 TYRP1
# Prediction failed for TYRP1 with error Gene TYRP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TYRP1
# Prediction failed for TYRP1 with error Gene TYRP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# VAX1 VAX1 VPS72 VPS72 XRCC4
# Prediction failed for XRCC4 with error Gene XRCC4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# XRCC4
# Prediction failed for XRCC4 with error Gene XRCC4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBED4 ZBED4 ZBTB33 ZBTB33 ZBTB45 ZBTB45 ZBTB7A ZFAND3
# Prediction failed for ZFAND3 with error Gene ZFAND3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZFAND3
# Prediction failed for ZFAND3 with error Gene ZFAND3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZIC1 ZIC1 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF280B ZNF280B ZNF281 ZNF281 ZNF426 ZNF426 ZNF646 ZNF646 ZNF706 ZNF706 ZNF713 ZNF713 ALX1 ALX1 ATF4 ATF4 CBFB CHD5
# Prediction failed for CHD5 with error Gene CHD5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD5
# Prediction failed for CHD5 with error Gene CHD5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CITED1 CITED1 CTBP1 CTBP1 CXXC5 CXXC5 EMX2 EMX2 ETV4 ETV4 FGR
# Prediction failed for FGR with error Gene FGR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FGR
# Prediction failed for FGR with error Gene FGR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXE1 FOXE1 GTF3C5
# Prediction failed for GTF3C5 with error Gene GTF3C5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF3C5
# Prediction failed for GTF3C5 with error Gene GTF3C5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGA1 HMGA1 HNRNPD HNRNPD HOXC5 HOXC5 MBD3 MBD3 MLLT1 MLLT1 NR1H2 NR1H2 OSR1 OSR1 POU3F4 POU3F4 PRDM2 PRDM2 PRICKLE1
# Prediction failed for PRICKLE1 with error Gene PRICKLE1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SRF SRF TAF1A TAF1A TCF15 TCF15 TEF TEF THAP10 THAP10 THRA THRA TNF TNF ZNF384 ZNF384 ZNF384 ZNF384 ZNF480 ZNF480 ZNF74 ZNF74
# Working on results/baseNetwork_v1/1.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/1 [00:00<?, ?it/s]
# inferring GRN for all_one_cluster...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in all_one_cluster
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2407 genes
# Predicting ZNF74
# ALX3 ALX3 ALX4 ALX4 ANKRD22
# Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ANKRD22
# Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# AR AR ARNT2 ARNT2 ASH2L
# Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ASH2L
# Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF2 ATF2 ATF3 ATF3 BACH1 BACH1 BARHL2 BARHL2 BARX2 BARX2 BCL6 BCL6 BHLHE40 BHLHE40 BMP4 BMP4 BRF2 BRF2 CDX2 CDX2 CDX2 CDYL
# Prediction failed for CDYL with error Gene CDYL is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CDYL
# Prediction failed for CDYL with error Gene CDYL is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CEBPB CEBPB CHD4 CHD4 CREB3 CREB3 CTCF DEDD2
# Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DEDD2
# Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DLX2 DLX2 DLX4 DLX4 DMRT1 DMRT1 DMRTC2 DMRTC2 DNMT3L DNMT3L E2F4 E2F4 E2F6 E2F6 EED EED ELF2 ELF2 ELF4 ELF5 ELF5 ELK1 ELK1 ELL2
# Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELL2
# Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELOA
# Prediction failed for ELOA with error Gene ELOA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELOA
# Prediction failed for ELOA with error Gene ELOA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETS1 ETS1 ETS2 ETS2 ETV5 ETV5 FBXO15
# Prediction failed for FBXO15 with error Gene FBXO15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FBXO15
# Prediction failed for FBXO15 with error Gene FBXO15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FIGLA FIGLA FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOXD1 FOXD1 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXH1 FOXH1 FOXM1 FOXM1 FOXS1 FOXS1 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GBX2 GBX2 GLI1 GLI1 GRHL2 GRHL2 GSC GSC GTF2B GTF2B GTF2F1 GTF2F1 H2AFZ
# Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# H2AFZ
# Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HDAC3 HDAC3 HDAC8 HDAC8 HES1 HES1 HESX1 HESX1 HEY1 HEY1 HMGB2 HMGB2 HMGN1 HMGXB4 HMGXB4 HNF1A HOPX HOPX HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXB3 HOXB3 HOXB4 HOXB4 HOXC9 HOXC9 HOXD10 HOXD10 HOXD13 HOXD13 HSF1 HSF1 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF3 IRF3 IRF5 IRF5 JARID2 JARID2 JUN JUN KAT8 KAT8 KDM1A KDM1A KDM5A KDM5A KDM5B KDM5B KLF11 KLF11 KLF12 KLF15 KLF15 KLF8 KLF8 KLF9 KLF9 LHFPL6
# Prediction failed for LHFPL6 with error Gene LHFPL6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHFPL6
# Prediction failed for LHFPL6 with error Gene LHFPL6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHX1 LHX1 LHX3 LHX3 LHX4 LHX4 LMO1
# Prediction failed for LMO1 with error Gene LMO1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LMO1
# Prediction failed for LMO1 with error Gene LMO1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAB21L2
# Prediction failed for MAB21L2 with error Gene MAB21L2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAB21L2
# Prediction failed for MAB21L2 with error Gene MAB21L2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MEF2A MEF2A MEIS1 MEIS1 MEIS2 MEIS2 MKRN1 MKRN1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MXI1 MXI1 MYB MYB MYBL2 MYBL2 MYF5 MYF5 MYF6 MYF6 NELFA
# Prediction failed for NELFA with error Gene NELFA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFA
# Prediction failed for NELFA with error Gene NELFA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFE
# Prediction failed for NELFE with error Gene NELFE is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFE
# Prediction failed for NELFE with error Gene NELFE is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NEUROD1 NEUROD1 NEUROD4 NEUROD4 NEUROD6 NEUROD6 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NFE2L1 NFYB NFYB NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NKX6-3 NKX6-3 NR1D2 NR1D2 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NRF1 NRF1 NSD2 NSD2 OLIG1 OLIG1 OSTF1
# Prediction failed for OSTF1 with error Gene OSTF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OSTF1
# Prediction failed for OSTF1 with error Gene OSTF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OTP OTP OTX2 OTX2 OVOL2 OVOL2 PABPC1
# Prediction failed for PABPC1 with error Gene PABPC1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PAX2 PAX2 PAX5 PAX5 PAX6 PAX6 PAX8 PAX8 PDX1 PDX1 PHF8
# Prediction failed for PHF8 with error Gene PHF8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PHF8
# Prediction failed for PHF8 with error Gene PHF8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PHOX2B PHOX2B PITX3 PITX3 PLXNB3 PLXNB3 POLR3A POLR3A POU2AF1 POU2AF1 POU2F2 POU2F2 POU4F1 POU4F1 POU5F1 POU5F1 POU5F1 PPARGC1A PPARGC1A PTAFR
# Prediction failed for PTAFR with error Gene PTAFR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PTAFR
# Prediction failed for PTAFR with error Gene PTAFR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PTF1A PTF1A RAD21 RAD21 RBBP5
# Prediction failed for RBBP5 with error Gene RBBP5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP5
# Prediction failed for RBBP5 with error Gene RBBP5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP6
# Prediction failed for RBBP6 with error Gene RBBP6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP6
# Prediction failed for RBBP6 with error Gene RBBP6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# REPIN1 REPIN1 REST REST RFX2 RFX2 RNF2 RNF2 RUNX1 RUNX1 RUNX3 RUNX3 RUVBL2
# Prediction failed for RUVBL2 with error Gene RUVBL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RUVBL2
# Prediction failed for RUVBL2 with error Gene RUVBL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SALL4 SALL4 SAP30
# Prediction failed for SAP30 with error Gene SAP30 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SETDB1 SETDB1 SIN3A SIN3A SIX5 SIX5 SMAD1 SMAD1 SMAD2 SMAD2 SMAD4 SMAD4 SMAD5 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX2 SOX2 SOX7 SOX7 SPIC SPIC SPIC STAG1 STAG1 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A STRA8
# Prediction failed for STRA8 with error Gene STRA8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# STRA8
# Prediction failed for STRA8 with error Gene STRA8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TBX2 TBX2 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF4 TCF4 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 TGM2
# Prediction failed for TGM2 with error Gene TGM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TGM2
# Prediction failed for TGM2 with error Gene TGM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP1 THAP1 THAP11 THAP11 THAP3 THAP3 THAP7 THAP7 TP53 TP53 TRPV2
# Prediction failed for TRPV2 with error Gene TRPV2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TRPV2
# Prediction failed for TRPV2 with error Gene TRPV2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TWIST2 TWIST2 TYRP1
# Prediction failed for TYRP1 with error Gene TYRP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TYRP1
# Prediction failed for TYRP1 with error Gene TYRP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# VAX1 VAX1 VPS72 VPS72 XRCC4
# Prediction failed for XRCC4 with error Gene XRCC4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# XRCC4
# Prediction failed for XRCC4 with error Gene XRCC4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBED4 ZBED4 ZBTB33 ZBTB33 ZBTB45 ZBTB45 ZBTB7A ZFAND3
# Prediction failed for ZFAND3 with error Gene ZFAND3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZFAND3
# Prediction failed for ZFAND3 with error Gene ZFAND3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZIC1 ZIC1 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF280B ZNF280B ZNF281 ZNF281 ZNF426 ZNF426 ZNF646 ZNF646 ZNF706 ZNF706 ZNF713 ZNF713 ALX1 ALX1 ATF4 ATF4 CBFB CHD5
# Prediction failed for CHD5 with error Gene CHD5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD5
# Prediction failed for CHD5 with error Gene CHD5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CITED1 CITED1 CTBP1 CTBP1 CXXC5 CXXC5 EMX2 EMX2 ETV4 ETV4 FGR
# Prediction failed for FGR with error Gene FGR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FGR
# Prediction failed for FGR with error Gene FGR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXE1 FOXE1 GTF3C5
# Prediction failed for GTF3C5 with error Gene GTF3C5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF3C5
# Prediction failed for GTF3C5 with error Gene GTF3C5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGA1 HMGA1 HNRNPD HNRNPD HOXC5 HOXC5 MBD3 MBD3 MLLT1 MLLT1 NR1H2 NR1H2 OSR1 OSR1 POU3F4 POU3F4 PRDM2 PRDM2 PRICKLE1
# Prediction failed for PRICKLE1 with error Gene PRICKLE1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SRF SRF TAF1A TAF1A TCF15 TCF15 TEF TEF THAP10 THAP10 THRA THRA TNF TNF ZNF384 ZNF384 ZNF384 ZNF384 ZNF480 ZNF480 ZNF74 ZNF74
# Working on results/baseNetwork_v1/2.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/1 [00:00<?, ?it/s]
# inferring GRN for all_one_cluster...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in all_one_cluster
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2404 genes
# Predicting ZNF74
# ALX3 ALX3 ALX4 ALX4 ANKRD22
# Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ANKRD22
# Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# AR AR ARNT2 ARNT2 ASH2L
# Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ASH2L
# Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF2 ATF2 ATF3 ATF3 BACH1 BACH1 BARHL2 BARHL2 BARX2 BARX2 BCL6 BCL6 BHLHE40 BHLHE40 BMP4 BMP4 BRF2 BRF2 CDX2 CDX2 CDX2 CDYL
# Prediction failed for CDYL with error Gene CDYL is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CDYL
# Prediction failed for CDYL with error Gene CDYL is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CEBPB CEBPB CHD4 CHD4 CREB3 CREB3 CTCF DEDD2
# Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DEDD2
# Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DLX2 DLX2 DLX4 DLX4 DMRT1 DMRT1 DMRTC2 DMRTC2 DNMT3L DNMT3L E2F4 E2F4 E2F6 E2F6 EED EED ELF2 ELF2 ELF4 ELF5 ELF5 ELK1 ELK1 ELL2
# Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELL2
# Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELOA
# Prediction failed for ELOA with error Gene ELOA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELOA
# Prediction failed for ELOA with error Gene ELOA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETS1 ETS1 ETS2 ETS2 ETV5 ETV5 FBXO15
# Prediction failed for FBXO15 with error Gene FBXO15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FBXO15
# Prediction failed for FBXO15 with error Gene FBXO15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FIGLA FIGLA FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOXD1 FOXD1 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXH1 FOXH1 FOXM1 FOXM1 FOXS1 FOXS1 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GBX2 GBX2 GLI1 GLI1 GRHL2 GRHL2 GSC GSC GTF2B GTF2B GTF2F1 GTF2F1 H2AFZ
# Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# H2AFZ
# Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HDAC3 HDAC3 HDAC8 HDAC8 HES1 HES1 HESX1 HESX1 HEY1 HEY1 HMGB2 HMGB2 HMGN1 HMGXB4 HMGXB4 HNF1A HOPX HOPX HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXB3 HOXB3 HOXB4 HOXB4 HOXC9 HOXC9 HOXD10 HOXD10 HOXD13 HOXD13 HSF1 HSF1 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF3 IRF3 IRF5 IRF5 JARID2 JARID2 JUN JUN KAT8 KAT8 KDM1A KDM1A KDM5A KDM5A KDM5B KDM5B KLF11 KLF11 KLF12 KLF15 KLF15 KLF8 KLF8 KLF9 KLF9 LHFPL6
# Prediction failed for LHFPL6 with error Gene LHFPL6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHFPL6
# Prediction failed for LHFPL6 with error Gene LHFPL6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LHX1 LHX1 LHX3 LHX3 LHX4 LHX4 LMO1
# Prediction failed for LMO1 with error Gene LMO1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# LMO1
# Prediction failed for LMO1 with error Gene LMO1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAB21L2
# Prediction failed for MAB21L2 with error Gene MAB21L2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MAB21L2
# Prediction failed for MAB21L2 with error Gene MAB21L2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MEF2A MEF2A MEIS1 MEIS1 MEIS2 MEIS2 MKRN1 MKRN1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MXI1 MXI1 MYB MYB MYBL2 MYBL2 MYF5 MYF5 MYF6 MYF6 NELFA
# Prediction failed for NELFA with error Gene NELFA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFA
# Prediction failed for NELFA with error Gene NELFA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFE
# Prediction failed for NELFE with error Gene NELFE is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NELFE
# Prediction failed for NELFE with error Gene NELFE is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NEUROD1 NEUROD1 NEUROD4 NEUROD4 NEUROD6 NEUROD6 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NFE2L1 NFYB NFYB NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NKX6-3 NKX6-3 NR1D2 NR1D2 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NRF1 NRF1 NSD2 NSD2 OLIG1 OLIG1 OSTF1
# Prediction failed for OSTF1 with error Gene OSTF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OSTF1
# Prediction failed for OSTF1 with error Gene OSTF1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OTP OTP OTX2 OTX2 OVOL2 OVOL2 PABPC1
# Prediction failed for PABPC1 with error Gene PABPC1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PAX2 PAX2 PAX5 PAX5 PAX6 PAX6 PAX8 PAX8 PDX1 PDX1 PHF8
# Prediction failed for PHF8 with error Gene PHF8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PHF8
# Prediction failed for PHF8 with error Gene PHF8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PHOX2B PHOX2B PITX3 PITX3 PLXNB3 PLXNB3 POLR3A POLR3A POU2AF1 POU2AF1 POU2F2 POU2F2 POU4F1 POU4F1 POU5F1 POU5F1 POU5F1 PPARGC1A PPARGC1A PTAFR
# Prediction failed for PTAFR with error Gene PTAFR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PTAFR
# Prediction failed for PTAFR with error Gene PTAFR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PTF1A PTF1A RAD21 RAD21 RBBP5
# Prediction failed for RBBP5 with error Gene RBBP5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP5
# Prediction failed for RBBP5 with error Gene RBBP5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP6
# Prediction failed for RBBP6 with error Gene RBBP6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RBBP6
# Prediction failed for RBBP6 with error Gene RBBP6 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# REPIN1 REPIN1 REST REST RFX2 RFX2 RNF2 RNF2 RUNX1 RUNX1 RUNX3 RUNX3 RUVBL2
# Prediction failed for RUVBL2 with error Gene RUVBL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# RUVBL2
# Prediction failed for RUVBL2 with error Gene RUVBL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SALL4 SALL4 SAP30
# Prediction failed for SAP30 with error Gene SAP30 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SETDB1 SETDB1 SIN3A SIN3A SIX5 SIX5 SMAD1 SMAD1 SMAD2 SMAD2 SMAD4 SMAD4 SMAD5 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX2 SOX2 SOX7 SOX7 SPIC SPIC SPIC STAG1 STAG1 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A STRA8
# Prediction failed for STRA8 with error Gene STRA8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# STRA8
# Prediction failed for STRA8 with error Gene STRA8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TBX2 TBX2 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF4 TCF4 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A TFAP2A TFAP2B TFAP2B TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 TGM2
# Prediction failed for TGM2 with error Gene TGM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TGM2
# Prediction failed for TGM2 with error Gene TGM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP1 THAP1 THAP11 THAP11 THAP3 THAP3 THAP7 THAP7 TP53 TP53 TRPV2
# Prediction failed for TRPV2 with error Gene TRPV2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TRPV2
# Prediction failed for TRPV2 with error Gene TRPV2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TWIST2 TWIST2 TYRP1
# Prediction failed for TYRP1 with error Gene TYRP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TYRP1
# Prediction failed for TYRP1 with error Gene TYRP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# VAX1 VAX1 VPS72 VPS72 XRCC4
# Prediction failed for XRCC4 with error Gene XRCC4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# XRCC4
# Prediction failed for XRCC4 with error Gene XRCC4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBED4 ZBED4 ZBTB33 ZBTB33 ZBTB45 ZBTB45 ZBTB7A ZFAND3
# Prediction failed for ZFAND3 with error Gene ZFAND3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZFAND3
# Prediction failed for ZFAND3 with error Gene ZFAND3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZIC1 ZIC1 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF280B ZNF280B ZNF281 ZNF281 ZNF426 ZNF426 ZNF646 ZNF646 ZNF706 ZNF706 ZNF713 ZNF713 ALX1 ALX1 ATF4 ATF4 CBFB CHD5
# Prediction failed for CHD5 with error Gene CHD5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD5
# Prediction failed for CHD5 with error Gene CHD5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CITED1 CITED1 CTBP1 CTBP1 CXXC5 CXXC5 EMX2 EMX2 ETV4 ETV4 FGR
# Prediction failed for FGR with error Gene FGR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FGR
# Prediction failed for FGR with error Gene FGR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXE1 FOXE1 GTF3C5
# Prediction failed for GTF3C5 with error Gene GTF3C5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF3C5
# Prediction failed for GTF3C5 with error Gene GTF3C5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGA1 HMGA1 HNRNPD HNRNPD HOXC5 HOXC5 MBD3 MBD3 MLLT1 MLLT1 NR1H2 NR1H2 OSR1 OSR1 POU3F4 POU3F4 PRDM2 PRDM2 PRICKLE1
# Prediction failed for PRICKLE1 with error Gene PRICKLE1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SRF SRF TAF1A TAF1A TCF15 TCF15 TEF TEF THAP10 THAP10 THRA THRA TNF TNF ZNF384 ZNF384 ZNF384 ZNF384 ZNF480 ZNF480 ZNF74 ZNF74
# Working on results/baseNetwork_v1/3.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/1 [00:00<?, ?it/s]
# inferring GRN for all_one_cluster...
#   0%|          | 0/2407 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in all_one_cluster
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2406 genes
# Predicting ZNF74
# ALX3 ALX3 ALX4 ALX4 ANKRD22
# Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ANKRD22
# Prediction failed for ANKRD22 with error Gene ANKRD22 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# AR AR ARNT2 ARNT2 ASH2L
# Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ASH2L
# Prediction failed for ASH2L with error Gene ASH2L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF2 ATF2 ATF3 ATF3 BACH1 BACH1 BARHL2 BARHL2 BARX2 BARX2 BCL6 BCL6 BHLHE40 BHLHE40 BMP4
# Prediction failed for BMP4 with error Gene BMP4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BMP4
# Prediction failed for BMP4 with error Gene BMP4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# BRF2 BRF2 CDX2 CDX2 CDX2 CDYL
# Prediction failed for CDYL with error Gene CDYL is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CDYL
# Prediction failed for CDYL with error Gene CDYL is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CEBPB CEBPB CHD4
# Prediction failed for CHD4 with error Gene CHD4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD4
# Prediction failed for CHD4 with error Gene CHD4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CREB3 CREB3 CTCF DEDD2
# Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DEDD2
# Prediction failed for DEDD2 with error Gene DEDD2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DLX2 DLX2 DLX4
# Prediction failed for DLX4 with error Gene DLX4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DLX4
# Prediction failed for DLX4 with error Gene DLX4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DMRT1 DMRT1 DMRTC2 DMRTC2 DNMT3L
# Prediction failed for DNMT3L with error Gene DNMT3L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# DNMT3L
# Prediction failed for DNMT3L with error Gene DNMT3L is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# E2F4 E2F4 E2F6 E2F6 EED
# Prediction failed for EED with error Gene EED is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# EED
# Prediction failed for EED with error Gene EED is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELF2 ELF2 ELF4 ELF5 ELF5 ELK1 ELK1 ELL2
# Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELL2
# Prediction failed for ELL2 with error Gene ELL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELOA
# Prediction failed for ELOA with error Gene ELOA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELOA
# Prediction failed for ELOA with error Gene ELOA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETS1 ETS1 ETS2 ETS2 ETV5 ETV5 FBXO15
# Prediction failed for FBXO15 with error Gene FBXO15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FBXO15
# Prediction failed for FBXO15 with error Gene FBXO15 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FIGLA
# Prediction failed for FIGLA with error Gene FIGLA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FIGLA
# Prediction failed for FIGLA with error Gene FIGLA is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOXD1 FOXD1 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXH1 FOXH1 FOXM1 FOXM1 FOXS1 FOXS1 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GBX2 GBX2 GLI1 GLI1 GRHL2 GRHL2 GSC GSC GTF2B
# Prediction failed for GTF2B with error Gene GTF2B is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF2B
# Prediction failed for GTF2B with error Gene GTF2B is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF2F1
# Prediction failed for GTF2F1 with error Gene GTF2F1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF2F1
# Prediction failed for GTF2F1 with error Gene GTF2F1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# H2AFZ
# Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# H2AFZ
# Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HDAC3
# Prediction failed for HDAC3 with error Gene HDAC3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HDAC3
# Prediction failed for HDAC3 with error Gene HDAC3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HDAC8
# Prediction failed for HDAC8 with error Gene HDAC8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HDAC8
# Prediction failed for HDAC8 with error Gene HDAC8 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HES1 HES1 HESX1 HESX1 HEY1 HEY1 HMGB2
# Prediction failed for HMGB2 with error Gene HMGB2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGB2
# Prediction failed for HMGB2 with error Gene HMGB2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGN1
# Prediction failed for HMGN1 with error Gene HMGN1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGXB4
# Prediction failed for HMGXB4 with error Gene HMGXB4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGXB4
# Prediction failed for HMGXB4 with error Gene HMGXB4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HNF1A HOPX
# ...
# XRCC4
# Prediction failed for XRCC4 with error Gene XRCC4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBED4
# Prediction failed for ZBED4 with error Gene ZBED4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBED4
# Prediction failed for ZBED4 with error Gene ZBED4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBTB33 ZBTB33 ZBTB45
# Prediction failed for ZBTB45 with error Gene ZBTB45 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBTB45
# Prediction failed for ZBTB45 with error Gene ZBTB45 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZBTB7A ZFAND3
# Prediction failed for ZFAND3 with error Gene ZFAND3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZFAND3
# Prediction failed for ZFAND3 with error Gene ZFAND3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZIC1 ZIC1 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF280B
# Prediction failed for ZNF280B with error Gene ZNF280B is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF280B
# Prediction failed for ZNF280B with error Gene ZNF280B is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF281 ZNF281 ZNF426
# Prediction failed for ZNF426 with error Gene ZNF426 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF426
# Prediction failed for ZNF426 with error Gene ZNF426 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF646
# Prediction failed for ZNF646 with error Gene ZNF646 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF646
# Prediction failed for ZNF646 with error Gene ZNF646 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF706
# Prediction failed for ZNF706 with error Gene ZNF706 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF706
# Prediction failed for ZNF706 with error Gene ZNF706 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF713
# Prediction failed for ZNF713 with error Gene ZNF713 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF713
# Prediction failed for ZNF713 with error Gene ZNF713 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ALX1
# Prediction failed for ALX1 with error Gene ALX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ALX1
# Prediction failed for ALX1 with error Gene ALX1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ATF4 ATF4 CBFB
# Prediction failed for CBFB with error Gene CBFB is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD5
# Prediction failed for CHD5 with error Gene CHD5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CHD5
# Prediction failed for CHD5 with error Gene CHD5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CITED1
# Prediction failed for CITED1 with error Gene CITED1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CITED1
# Prediction failed for CITED1 with error Gene CITED1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTBP1
# Prediction failed for CTBP1 with error Gene CTBP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CTBP1
# Prediction failed for CTBP1 with error Gene CTBP1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CXXC5
# Prediction failed for CXXC5 with error Gene CXXC5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# CXXC5
# Prediction failed for CXXC5 with error Gene CXXC5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# EMX2 EMX2 ETV4 ETV4 FGR
# Prediction failed for FGR with error Gene FGR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FGR
# Prediction failed for FGR with error Gene FGR is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# FOXE1 FOXE1 GTF3C5
# Prediction failed for GTF3C5 with error Gene GTF3C5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GTF3C5
# Prediction failed for GTF3C5 with error Gene GTF3C5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGA1
# Prediction failed for HMGA1 with error Gene HMGA1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HMGA1
# Prediction failed for HMGA1 with error Gene HMGA1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HNRNPD
# Prediction failed for HNRNPD with error Gene HNRNPD is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HNRNPD
# Prediction failed for HNRNPD with error Gene HNRNPD is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXC5
# Prediction failed for HOXC5 with error Gene HOXC5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HOXC5
# Prediction failed for HOXC5 with error Gene HOXC5 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MBD3
# Prediction failed for MBD3 with error Gene MBD3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MBD3
# Prediction failed for MBD3 with error Gene MBD3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MLLT1
# Prediction failed for MLLT1 with error Gene MLLT1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# MLLT1
# Prediction failed for MLLT1 with error Gene MLLT1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# NR1H2 NR1H2 OSR1
# Prediction failed for OSR1 with error Gene OSR1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# OSR1
# Prediction failed for OSR1 with error Gene OSR1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# POU3F4
# Prediction failed for POU3F4 with error Gene POU3F4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# POU3F4
# Prediction failed for POU3F4 with error Gene POU3F4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PRDM2
# Prediction failed for PRDM2 with error Gene PRDM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PRDM2
# Prediction failed for PRDM2 with error Gene PRDM2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PRICKLE1
# Prediction failed for PRICKLE1 with error Gene PRICKLE1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# SRF SRF TAF1A
# Prediction failed for TAF1A with error Gene TAF1A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TAF1A
# Prediction failed for TAF1A with error Gene TAF1A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TCF15 TCF15 TEF TEF THAP10
# Prediction failed for THAP10 with error Gene THAP10 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THAP10
# Prediction failed for THAP10 with error Gene THAP10 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# THRA THRA TNF
# Prediction failed for TNF with error Gene TNF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TNF
# Prediction failed for TNF with error Gene TNF is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF384 ZNF384 ZNF384 ZNF384 ZNF480
# Prediction failed for ZNF480 with error Gene ZNF480 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF480
# Prediction failed for ZNF480 with error Gene ZNF480 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF74
# Prediction failed for ZNF74 with error Gene ZNF74 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ZNF74
# Prediction failed for ZNF74 with error Gene ZNF74 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# Working on results/baseNetwork_v1/15.celloracle.oracle
# Memoized results not found with error File not found. Please check if the file_path is correct.
#   0%|          | 0/1 [00:00<?, ?it/s]
# inferring GRN for all_one_cluster...
#   0%|          | 0/2307 [00:00<?, ?it/s]
# fitting GRN again...
# calculating GRN in all_one_cluster
#   0%|          | 0/2603 [00:00<?, ?it/s]
# genes_in_gem: 2603
# models made for 2305 genes
# Predicting ZNF74
# ALX3
# Prediction failed for ALX3 with error Gene ALX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ALX3
# Prediction failed for ALX3 with error Gene ALX3 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ALX4 ALX4 ANKRD22 ANKRD22 AR AR ARNT2 ARNT2 ASH2L ASH2L ATF2 ATF2 ATF3 ATF3 BACH1 BACH1 BARHL2 BARHL2 BARX2 BARX2 BCL6 BCL6 BHLHE40 BHLHE40 BMP4 BMP4 BRF2 BRF2 CDX2 CDX2 CDX2 CDYL CDYL CEBPB CEBPB CHD4 CHD4 CREB3 CREB3 CTCF DEDD2 DEDD2 DLX2 DLX2 DLX4 DLX4 DMRT1 DMRT1 DMRTC2 DMRTC2 DNMT3L DNMT3L E2F4 E2F4 E2F6 E2F6 EED EED ELF2 ELF2 ELF4 ELF5 ELF5 ELK1
# Prediction failed for ELK1 with error Gene ELK1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELK1
# Prediction failed for ELK1 with error Gene ELK1 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# ELL2 ELL2 ELOA ELOA ESRRB ESRRB ESRRG ESRRG ESX1 ESX1 ETS1 ETS1 ETS2 ETS2 ETV5 ETV5 FBXO15 FBXO15 FIGLA FIGLA FLI1 FLI1 FOS FOS FOSL1 FOSL1 FOXD1 FOXD1 FOXD4L3 FOXD4L3 FOXE3 FOXE3 FOXH1 FOXH1 FOXM1 FOXM1 FOXS1 FOXS1 GABPA GABPA GATA1 GATA1 GATA2 GATA2 GBX2 GBX2 GLI1 GLI1 GRHL2
# Prediction failed for GRHL2 with error Gene GRHL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GRHL2
# Prediction failed for GRHL2 with error Gene GRHL2 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# GSC GSC GTF2B GTF2B GTF2F1 GTF2F1 H2AFZ
# Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# H2AFZ
# Prediction failed for H2AFZ with error Gene H2AFZ is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# HDAC3 HDAC3 HDAC8 HDAC8 HES1 HES1 HESX1 HESX1 HEY1 HEY1 HMGB2 HMGB2 HMGN1 HMGXB4 HMGXB4 HNF1A HOPX HOPX HOXA10 HOXA10 HOXA2 HOXA2 HOXB1 HOXB1 HOXB3 HOXB3 HOXB4 HOXB4 HOXC9 HOXC9 HOXD10 HOXD10 HOXD13 HOXD13 HSF1 HSF1 ID1 ID1 ID3 IKZF1 IKZF1 IRF1 IRF1 IRF3 IRF3 IRF5 IRF5 JARID2 JARID2 JUN JUN KAT8 KAT8 KDM1A KDM1A KDM5A KDM5A KDM5B KDM5B KLF11 KLF11 KLF12 KLF15 KLF15 KLF8 KLF8 KLF9 KLF9 LHFPL6 LHFPL6 LHX1 LHX1 LHX3 LHX3 LHX4 LHX4 LMO1 LMO1 MAB21L2 MAB21L2 MEF2A MEF2A MEIS1 MEIS1 MEIS2 MEIS2 MKRN1 MKRN1 MSC MSC MSGN1 MSGN1 MSX2 MSX2 MXI1 MXI1 MYB MYB MYBL2 MYBL2 MYF5 MYF5 MYF6 MYF6 NELFA NELFA NELFE NELFE NEUROD1 NEUROD1 NEUROD4 NEUROD4 NEUROD6 NEUROD6 NEUROG1 NEUROG1 NEUROG2 NEUROG2 NFE2L1 NFYB NFYB NKX2-2 NKX2-2 NKX2-5 NKX2-5 NKX6-1 NKX6-1 NKX6-2 NKX6-2 NKX6-3 NKX6-3 NR1D2 NR1D2 NR2F1 NR2F1 NR2F2 NR2F2 NR4A2 NR4A2 NRF1 NRF1 NSD2 NSD2 OLIG1 OLIG1 OSTF1 OSTF1 OTP OTP OTX2 OTX2 OVOL2 OVOL2 PABPC1 PAX2 PAX2 PAX5 PAX5 PAX6 PAX6 PAX8 PAX8 PDX1 PDX1 PHF8 PHF8 PHOX2B PHOX2B PITX3 PITX3 PLXNB3 PLXNB3 POLR3A POLR3A POU2AF1 POU2AF1 POU2F2 POU2F2 POU4F1 POU4F1 POU5F1 POU5F1 POU5F1 PPARGC1A PPARGC1A PTAFR PTAFR PTF1A PTF1A RAD21 RAD21 RBBP5 RBBP5 RBBP6 RBBP6 REPIN1 REPIN1 REST REST RFX2 RFX2 RNF2 RNF2 RUNX1 RUNX1 RUNX3 RUNX3 RUVBL2 RUVBL2 SALL4 SALL4 SAP30 SETDB1 SETDB1 SIN3A SIN3A SIX5 SIX5 SMAD1 SMAD1 SMAD2 SMAD2 SMAD4 SMAD4 SMAD5 SMC3 SMC3 SNAI1 SNAI1 SNAI2 SNAI2 SOX14 SOX14 SOX15 SOX15 SOX17 SOX17 SOX2 SOX2 SOX7 SOX7 SPIC SPIC SPIC STAG1 STAG1 STAT3 STAT3 STAT4 STAT4 STAT5A STAT5A STRA8 STRA8 TBX2 TBX2 TBX4 TBX4 TBX5 TBX5 TCF12 TCF12 TCF4 TCF4 TCF7L2 TCF7L2 TEAD4 TEAD4 TFAP2A
# Prediction failed for TFAP2A with error Gene TFAP2A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TFAP2A
# Prediction failed for TFAP2A with error Gene TFAP2A is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# TFAP2B TFAP2B TFCP2L1 TFCP2L1 TFE3 TFE3 TGIF1 TGIF1 TGM2 TGM2 THAP1 THAP1 THAP11 THAP11 THAP3 THAP3 THAP7 THAP7 TP53 TP53 TRPV2 TRPV2 TWIST2 TWIST2 TYRP1 TYRP1 VAX1 VAX1 VPS72 VPS72 XRCC4 XRCC4 ZBED4 ZBED4 ZBTB33 ZBTB33 ZBTB45 ZBTB45 ZBTB7A ZFAND3 ZFAND3 ZIC1 ZIC1 ZKSCAN1 ZKSCAN1 ZNF263 ZNF263 ZNF280B ZNF280B ZNF281 ZNF281 ZNF426 ZNF426 ZNF646 ZNF646 ZNF706 ZNF706 ZNF713 ZNF713 ALX1 ALX1 ATF4 ATF4 CBFB CHD5 CHD5 CITED1 CITED1 CTBP1 CTBP1 CXXC5 CXXC5 EMX2 EMX2 ETV4 ETV4 FGR FGR FOXE1 FOXE1 GTF3C5 GTF3C5 HMGA1 HMGA1 HNRNPD HNRNPD HOXC5 HOXC5 MBD3 MBD3 MLLT1 MLLT1 NR1H2 NR1H2 OSR1 OSR1 POU3F4
# Prediction failed for POU3F4 with error Gene POU3F4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# POU3F4
# Prediction failed for POU3F4 with error Gene POU3F4 is not included in the base GRN; It is not TF or TF motif information is not available. Cannot perform simulation.
# PRDM2 PRDM2 PRICKLE1 SRF SRF TAF1A TAF1A TCF15 TCF15 TEF TEF THAP10 THAP10 THRA THRA TNF TNF ZNF384 ZNF384 ZNF384 ZNF384 ZNF480 ZNF480 ZNF74 ZNF74

# %%
predictions[0]
# Out:
# {'ALX3': ArrayView([0.31561609, 0.26152816, 0.35131918, ..., 0.51167567,
#             0.28141059, 1.07257846]),
#  'ALX4': ArrayView([0.31193832, 0.2619526 , 0.34870129, ..., 0.51094181,
#             0.27834803, 1.07358705]),
#  'ANKRD22': nan,
#  'AR': ArrayView([0.34634354, 0.25567578, 0.34695238, ..., 0.50534779,
#             0.28219491, 1.06233339]),
#  'ARNT2': ArrayView([0.28167256, 0.2378007 , 0.33687195, ..., 0.46816673,
#             0.27854854, 1.05891042]),
#  'ASH2L': nan,
#  'ATF2': ArrayView([0.31675888, 0.26212676, 0.33870435, ..., 0.49489395,
#             0.28645555, 1.07451111]),
#  'ATF3': ArrayView([0.2982281 , 0.26537446, 0.41181882, ..., 0.42561057,
#             0.26344697, 1.06625047]),
#  'BACH1': ArrayView([0.3100639 , 0.26008171, 0.37376715, ..., 0.49669916,
#             0.28551468, 1.03706124]),
#  'BARHL2': ArrayView([0.32477018, 0.26174528, 0.35454713, ..., 0.50942092,
#             0.27769272, 1.06074177]),
#  'BARX2': ArrayView([0.32164722, 0.26340812, 0.35076443, ..., 0.50502376,
#             0.27561965, 1.06233294]),
#  'BCL6': ArrayView([0.31886486, 0.28656461, 0.29964131, ..., 0.49648529,
#             0.31119562, 1.09923952]),
#  'BHLHE40': ArrayView([0.36942488, 0.44031123, 0.4074006 , ..., 0.55919385,
#             0.21154412, 1.09145022]),
#  'BMP4': ArrayView([0.53223317, 0.48089405, 0.23396997, ..., 0.43719772,
#             0.21841887, 1.00655516]),
#  'BRF2': ArrayView([0.32220599, 0.27389772, 0.40129012, ..., 0.50400087,
#             0.27687176, 1.05153819]),
#  'CDX2': ArrayView([0.46135935, 0.43267533, 0.33359521, ..., 0.48894349,
#             0.29712364, 1.05796607]),
#  'CDYL': nan,
#  'CEBPB': ArrayView([0.34326192, 0.29768278, 0.38742399, ..., 0.55888021,
#             0.27668664, 1.06003957]),
#  'CHD4': ArrayView([0.26933211, 0.19734135, 0.35327743, ..., 0.52819872,
#             0.27004855, 1.03504063]),
#  'CREB3': ArrayView([0.31849487, 0.32295323, 0.41452875, ..., 0.48910917,
#             0.22124749, 0.97644911]),
#  'CTCF': ArrayView([0.36587175, 0.27516012, 0.35972386, ..., 0.48457477,
#             0.2694595 , 1.08532108]),
#  'DEDD2': nan,
#  'DLX2': ArrayView([0.4181694 , 0.37815301, 0.33131381, ..., 0.48496934,
#             0.31714618, 1.06000938]),
#  'DLX4': ArrayView([0.30908852, 0.28202477, 0.33645417, ..., 0.53355343,
#             0.27905556, 1.06527684]),
#  'DMRT1': ArrayView([0.32249085, 0.28000646, 0.34677305, ..., 0.48585198,
#             0.28231652, 1.05769966]),
#  'DMRTC2': ArrayView([0.31458498, 0.25851923, 0.35175121, ..., 0.51099473,
#             0.281102  , 1.07120091]),
#  'DNMT3L': ArrayView([0.33473964, 0.28817313, 0.39687981, ..., 0.54573786,
#             0.27743706, 1.07116087]),
#  'E2F4': ArrayView([0.31474582, 0.24381174, 0.37950858, ..., 0.5353149 ,
#             0.29581029, 1.07712793]),
#  'E2F6': ArrayView([0.30919883, 0.25670097, 0.36153477, ..., 0.52054803,
#             0.27991437, 1.08240928]),
#  'EED': ArrayView([0.35862071, 0.25297666, 0.34182977, ..., 0.51189405,
#             0.29460723, 1.11110402]),
#  'ELF2': ArrayView([0.32747652, 0.2605143 , 0.34781391, ..., 0.5081737 ,
#             0.28299057, 1.06991208]),
#  'ELF4': ArrayView([0.43022748, 0.32834795, 0.44411422, ..., 0.52948905,
#             0.20971114, 1.0210037 ]),
#  'ELF5': ArrayView([0.32979126, 0.27939288, 0.33987909, ..., 0.51265268,
#             0.28182101, 1.07864457]),
#  'ELK1': ArrayView([0.31785464, 0.2896983 , 0.34643625, ..., 0.5460908 ,
#             0.27866286, 1.10005105]),
#  'ELL2': nan,
#  'ELOA': nan,
#  'ESRRB': ArrayView([0.30787317, 0.25119299, 0.34476883, ..., 0.50188601,
#             0.27298548, 1.06538423]),
#  'ESRRG': ArrayView([0.30635643, 0.25135165, 0.35671854, ..., 0.50298336,
#             0.27913899, 1.05950656]),
#  'ESX1': ArrayView([0.31383792, 0.25395996, 0.34814032, ..., 0.50531978,
#             0.27965767, 1.06385281]),
#  'ETS1': ArrayView([0.39109448, 0.27225043, 0.30873433, ..., 0.49043069,
#             0.33892679, 1.0858542 ]),
#  'ETS2': ArrayView([0.3462704 , 0.18748047, 0.30717346, ..., 0.49308004,
#             0.31995568, 1.07364982]),
#  'ETV5': ArrayView([0.31644416, 0.25741763, 0.35269265, ..., 0.50520002,
#             0.27944836, 1.06636558]),
#  'FBXO15': nan,
#  'FIGLA': ArrayView([0.31142372, 0.25533946, 0.34958993, ..., 0.50970161,
#             0.28086211, 1.07251229]),
#  'FLI1': ArrayView([0.34843495, 0.29546497, 0.32553045, ..., 0.49565924,
#             0.28466834, 1.01804551]),
#  'FOS': ArrayView([0.3639467 , 0.21755442, 0.41510034, ..., 0.43573417,
#             0.24482391, 1.0129503 ]),
#  'FOSL1': ArrayView([0.29991953, 0.26506025, 0.39604475, ..., 0.50715869,
#             0.25898564, 1.05264673]),
#  'FOXD1': ArrayView([0.31457027, 0.25872529, 0.35182314, ..., 0.51057513,
#             0.28072114, 1.07058788]),
#  'FOXD4L3': ArrayView([0.31452347, 0.258387  , 0.35168658, ..., 0.5110572 ,
#             0.28111341, 1.07144268]),
#  'FOXE3': ArrayView([0.31450761, 0.25811201, 0.35073667, ..., 0.51047523,
#             0.2811629 , 1.07006344]),
#  'FOXH1': ArrayView([0.34643167, 0.23046661, 0.33878103, ..., 0.53891433,
#             0.28724087, 1.11963439]),
#  'FOXM1': ArrayView([0.31813973, 0.24736   , 0.34666937, ..., 0.53408757,
#             0.27627321, 1.08202758]),
#  'FOXS1': ArrayView([0.31022939, 0.26967367, 0.35284257, ..., 0.52464173,
#             0.2766148 , 1.07036693]),
#  'GABPA': ArrayView([0.3151509 , 0.26203505, 0.35625332, ..., 0.50889748,
#             0.28619152, 1.07742288]),
#  'GATA1': ArrayView([0.31606906, 0.25771308, 0.35048918, ..., 0.50889769,
#             0.2807961 , 1.07370162]),
#  'GATA2': ArrayView([0.30058518, 0.27817357, 0.3476354 , ..., 0.49434628,
#             0.27490397, 1.05621331]),
#  'GBX2': ArrayView([0.32360138, 0.26392108, 0.35574182, ..., 0.51849836,
#             0.27209746, 1.07003112]),
#  'GLI1': ArrayView([0.31145138, 0.26337147, 0.38748847, ..., 0.54072837,
#             0.2858449 , 1.06026924]),
#  'GRHL2': ArrayView([0.3326946 , 0.26467104, 0.34037002, ..., 0.49934568,
#             0.27940165, 1.07585646]),
#  'GSC': ArrayView([0.32458352, 0.2365223 , 0.35263767, ..., 0.50016967,
#             0.26137596, 1.07822996]),
#  'GTF2B': ArrayView([0.33600845, 0.27248236, 0.46620974, ..., 0.5103381 ,
#             0.27051197, 1.09952367]),
#  'GTF2F1': ArrayView([0.3280829 , 0.25966254, 0.36193857, ..., 0.50257225,
#             0.27395114, 1.05160908]),
#  'H2AFZ': nan,
#  'HDAC3': ArrayView([0.27794126, 0.25666111, 0.31290815, ..., 0.51305155,
#             0.29759409, 1.10643391]),
#  'HDAC8': ArrayView([0.31126702, 0.26027084, 0.34524261, ..., 0.51386059,
#             0.28114865, 1.07515223]),
#  'HES1': ArrayView([0.2958734 , 0.32576581, 0.27503143, ..., 0.476133  ,
#             0.25648346, 1.05496982]),
#  'HESX1': ArrayView([0.31347488, 0.25286223, 0.36802736, ..., 0.52683203,
#             0.27602245, 1.07623298]),
#  'HEY1': ArrayView([0.32864662, 0.29512367, 0.35786971, ..., 0.4657395 ,
#             0.28545647, 1.04380304]),
#  'HMGB2': ArrayView([0.33426537, 0.24601319, 0.32594317, ..., 0.53309174,
#             0.27086453, 1.10600111]),
#  'HMGN1': ArrayView([0.30942634, 0.25914406, 0.33605815, ..., 0.5239268 ,
#             0.29607215, 1.07638199]),
#  'HMGXB4': ArrayView([0.34253871, 0.23443226, 0.32575955, ..., 0.52108014,
#             0.28934855, 1.11894943]),
#  'HNF1A': ArrayView([0.31473635, 0.25853526, 0.35173024, ..., 0.51044228,
#             0.28130844, 1.07134649]),
#  'HOPX': ArrayView([0.31786834, 0.25813381, 0.35205268, ..., 0.50993305,
#             0.28013763, 1.07009805]),
#  'HOXA10': ArrayView([0.32349127, 0.26636492, 0.35591343, ..., 0.51096012,
#             0.27891718, 1.06621456]),
#  'HOXA2': ArrayView([0.3141084 , 0.25792015, 0.35189148, ..., 0.51020699,
#             0.28180627, 1.07010349]),
#  'HOXB1': ArrayView([0.31567222, 0.26026471, 0.35346242, ..., 0.51037156,
#             0.27933313, 1.07179109]),
#  'HOXB3': ArrayView([0.3126847 , 0.25884601, 0.35912957, ..., 0.50968485,
#             0.28007823, 1.06244718]),
#  'HOXB4': ArrayView([0.31465139, 0.25872108, 0.3518574 , ..., 0.51085918,
#             0.28123402, 1.07061196]),
#  'HOXC9': ArrayView([0.31468184, 0.25856086, 0.35175917, ..., 0.51093485,
#             0.28115934, 1.07093994]),
#  'HOXD10': ArrayView([0.3150482 , 0.26100866, 0.35382017, ..., 0.51040202,
#             0.28196995, 1.06582968]),
#  'HOXD13': ArrayView([0.32434494, 0.27262414, 0.3548723 , ..., 0.51232762,
#             0.27968524, 1.06896049]),
#  'HSF1': ArrayView([0.26733064, 0.2130959 , 0.37239086, ..., 0.54533311,
#             0.28707693, 1.05115941]),
#  'ID1': ArrayView([0.32940653, 0.26662759, 0.35343618, ..., 0.49743701,
#             0.27863085, 1.05935083]),
#  'ID3': ArrayView([0.30878784, 0.27940353, 0.3223248 , ..., 0.43251956,
#             0.22227103, 1.0676817 ]),
#  'IKZF1': ArrayView([0.33236121, 0.24184527, 0.35393708, ..., 0.49698308,
#             0.27473615, 1.06516584]),
#  'IRF1': ArrayView([0.35510933, 0.26781444, 0.35371456, ..., 0.51236369,
#             0.28165195, 1.06796765]),
#  'IRF3': ArrayView([0.29691577, 0.24015039, 0.33846305, ..., 0.51008162,
#             0.27539316, 1.09909129]),
#  'IRF5': ArrayView([0.31112172, 0.26146834, 0.35297334, ..., 0.51344722,
#             0.27977503, 1.07222475]),
#  'JARID2': ArrayView([0.38208155, 0.27088048, 0.35430174, ..., 0.48774249,
#             0.30750973, 1.04315052]),
#  'JUN': ArrayView([0.331751  , 0.2490884 , 0.38428083, ..., 0.44799269,
#             0.26419108, 1.06752133]),
#  'KAT8': ArrayView([0.29247923, 0.24708231, 0.28953371, ..., 0.55369178,
#             0.29520111, 1.16339186]),
#  'KDM1A': ArrayView([0.25200134, 0.23394933, 0.29335566, ..., 0.53893447,
#             0.29070422, 1.11572699]),
#  'KDM5A': ArrayView([0.32966052, 0.26113049, 0.37303451, ..., 0.485016  ,
#             0.29061058, 1.05440215]),
#  'KDM5B': ArrayView([0.34657106, 0.24484745, 0.32369672, ..., 0.47646794,
#             0.26949062, 0.98552433]),
#  'KLF11': ArrayView([0.32903773, 0.27230934, 0.35822638, ..., 0.51954853,
#             0.27055198, 1.05505681]),
#  'KLF12': ArrayView([0.31268201, 0.26522482, 0.38515924, ..., 0.49965777,
#             0.27671667, 1.02115186]),
#  'KLF15': ArrayView([0.31033773, 0.25198305, 0.33527067, ..., 0.50387435,
#             0.28584652, 1.06715317]),
#  'KLF8': ArrayView([0.32940125, 0.26807316, 0.37937274, ..., 0.52004827,
#             0.27774161, 1.06003633]),
#  'KLF9': ArrayView([0.31570876, 0.26161194, 0.35886457, ..., 0.51767232,
#             0.27832204, 1.06720484]),
#  'LHFPL6': nan,
#  'LHX1': ArrayView([0.37308842, 0.26492491, 0.31941167, ..., 0.51762861,
#             0.25394073, 1.06586366]),
#  'LHX3': ArrayView([0.31389435, 0.25778739, 0.35215218, ..., 0.51068347,
#             0.28052539, 1.07139036]),
#  'LHX4': ArrayView([0.33982513, 0.26765815, 0.36170436, ..., 0.56372445,
#             0.33400356, 1.0671715 ]),
#  'LMO1': nan,
#  'MAB21L2': nan,
#  'MEF2A': ArrayView([0.32263125, 0.26606293, 0.36892797, ..., 0.51363986,
#             0.28709539, 1.04814371]),
#  'MEIS1': ArrayView([0.33274773, 0.28700495, 0.35751546, ..., 0.50987012,
#             0.27936608, 1.06349087]),
#  'MEIS2': ArrayView([0.30899994, 0.25389904, 0.35932471, ..., 0.50652401,
#             0.27522994, 1.05443987]),
#  'MKRN1': ArrayView([0.32436157, 0.2833614 , 0.35879068, ..., 0.50911675,
#             0.26882609, 1.03000027]),
#  'MSC': ArrayView([0.32813241, 0.24434392, 0.34617193, ..., 0.50636725,
#             0.29498921, 1.06947696]),
#  'MSGN1': ArrayView([0.32977448, 0.25358007, 0.34997128, ..., 0.49724851,
#             0.27798078, 1.08229198]),
#  'MSX2': ArrayView([0.36224304, 0.32166064, 0.37637625, ..., 0.52217299,
#             0.23736952, 1.07676136]),
#  'MXI1': ArrayView([0.29276796, 0.28150859, 0.33099231, ..., 0.49327047,
#             0.2957883 , 1.03326495]),
#  'MYB': ArrayView([0.28843272, 0.2234596 , 0.30339919, ..., 0.53357926,
#             0.30500422, 1.11600493]),
#  'MYBL2': ArrayView([0.33806692, 0.2365006 , 0.40196248, ..., 0.58683815,
#             0.22633939, 1.04903652]),
#  'MYF5': ArrayView([0.31014195, 0.25173921, 0.3487535 , ..., 0.50795226,
#             0.27987768, 1.07349895]),
#  'MYF6': ArrayView([0.29535117, 0.22963485, 0.33470487, ..., 0.49223719,
#             0.27164256, 1.06309635]),
#  'NELFA': nan,
#  'NELFE': nan,
#  'NEUROD1': ArrayView([0.3090229 , 0.25196148, 0.35471415, ..., 0.50113223,
#             0.28011606, 1.06629403]),
#  'NEUROD4': ArrayView([0.29511359, 0.23773237, 0.35481024, ..., 0.48801851,
#             0.27471099, 1.06020979]),
#  'NEUROD6': ArrayView([0.31457201, 0.25851224, 0.35167387, ..., 0.51104275,
#             0.28106486, 1.07122891]),
#  'NEUROG1': ArrayView([0.3073433 , 0.253966  , 0.34893047, ..., 0.50745305,
#             0.27615547, 1.07712558]),
#  'NEUROG2': ArrayView([0.31396399, 0.25957475, 0.3542243 , ..., 0.50728075,
#             0.27864368, 1.06872973]),
#  'NFE2L1': ArrayView([0.37155141, 0.29816324, 0.40127461, ..., 0.49240786,
#             0.28877494, 0.99489554]),
#  'NFYB': ArrayView([0.32014657, 0.25417543, 0.34746683, ..., 0.517838  ,
#             0.29290729, 1.07484257]),
#  'NKX2-2': ArrayView([0.30865959, 0.25974799, 0.34603477, ..., 0.50707309,
#             0.28024334, 1.06066074]),
#  'NKX2-5': ArrayView([0.30411502, 0.25576133, 0.34965692, ..., 0.51999276,
#             0.27589822, 1.06643981]),
#  'NKX6-1': ArrayView([0.31645895, 0.2549405 , 0.35108751, ..., 0.50394176,
#             0.27738146, 1.0667997 ]),
#  'NKX6-2': ArrayView([0.31696563, 0.26590543, 0.35362332, ..., 0.50842374,
#             0.27765476, 1.06283995]),
#  'NKX6-3': ArrayView([0.31375992, 0.25765906, 0.35227578, ..., 0.51082161,
#             0.28140563, 1.07104824]),
#  'NR1D2': ArrayView([0.31595413, 0.26375759, 0.3457371 , ..., 0.51268696,
#             0.27734469, 1.06034153]),
#  'NR2F1': ArrayView([0.31389421, 0.26049894, 0.35024945, ..., 0.51215304,
#             0.28188856, 1.06972786]),
#  'NR2F2': ArrayView([0.3530143 , 0.29640178, 0.34362395, ..., 0.49919614,
#             0.28715607, 1.06323515]),
#  'NR4A2': ArrayView([0.31490894, 0.25920236, 0.35066939, ..., 0.50939377,
#             0.28086954, 1.06749636]),
#  'NRF1': ArrayView([0.31997892, 0.27072002, 0.35347497, ..., 0.52209615,
#             0.28607673, 1.0831935 ]),
#  'NSD2': ArrayView([0.24576273, 0.24807086, 0.29438194, ..., 0.49235866,
#             0.27210706, 1.09743445]),
#  'OLIG1': ArrayView([0.3123765 , 0.25652481, 0.35207888, ..., 0.50912854,
#             0.27998862, 1.07052318]),
#  'OSTF1': nan,
#  'OTP': ArrayView([0.31358686, 0.25934122, 0.35363635, ..., 0.51008139,
#             0.28025435, 1.06685415]),
#  'OTX2': ArrayView([0.34539448, 0.22584102, 0.3525472 , ..., 0.49070883,
#             0.29951113, 1.07608843]),
#  'OVOL2': ArrayView([0.31646382, 0.25040352, 0.35506522, ..., 0.49602568,
#             0.30090836, 1.08039041]),
#  'PABPC1': nan,
#  'PAX2': ArrayView([0.33953995, 0.25970297, 0.34929543, ..., 0.51394108,
#             0.27582818, 1.06568631]),
#  'PAX5': ArrayView([0.32483254, 0.26978972, 0.35756505, ..., 0.49245494,
#             0.28362806, 1.05053436]),
#  'PAX6': ArrayView([0.31913703, 0.25554232, 0.35158285, ..., 0.5095394 ,
#             0.28023872, 1.06223636]),
#  'PAX8': ArrayView([0.34230514, 0.26292386, 0.36640216, ..., 0.51341793,
#             0.27746659, 1.06791918]),
#  'PDX1': ArrayView([0.31461921, 0.25862447, 0.3511248 , ..., 0.51051847,
#             0.28090353, 1.07161313]),
#  'PHF8': nan,
#  'PHOX2B': ArrayView([0.30295566, 0.24418587, 0.35969733, ..., 0.50945039,
#             0.27872383, 1.07059068]),
#  'PITX3': ArrayView([0.31495803, 0.25673564, 0.35282566, ..., 0.51358124,
#             0.28385819, 1.06245108]),
#  'PLXNB3': ArrayView([0.30527508, 0.25127419, 0.35510936, ..., 0.50473488,
#             0.27664176, 1.07355417]),
#  'POLR3A': ArrayView([0.2949722 , 0.22628623, 0.35701583, ..., 0.49536407,
#             0.28162897, 1.09160836]),
#  'POU2AF1': ArrayView([0.31456718, 0.25848128, 0.35173023, ..., 0.51093616,
#             0.28109256, 1.07117465]),
#  'POU2F2': ArrayView([0.31447487, 0.25834164, 0.35224663, ..., 0.51174823,
#             0.28056472, 1.07093852]),
#  'POU4F1': ArrayView([0.32196131, 0.27050515, 0.35112905, ..., 0.51100132,
#             0.28176006, 1.05922414]),
#  'POU5F1': ArrayView([0.32869128, 0.26496181, 0.33745482, ..., 0.52979109,
#             0.27049576, 1.09235006]),
#  'PPARGC1A': ArrayView([0.3155153 , 0.26199071, 0.35199808, ..., 0.51061003,
#             0.27924523, 1.07135339]),
#  'PTAFR': nan,
#  'PTF1A': ArrayView([0.34300089, 0.28001348, 0.36320297, ..., 0.52195941,
#             0.27684249, 1.04614839]),
#  'RAD21': ArrayView([0.30125945, 0.25658892, 0.32885305, ..., 0.51530357,
#             0.3082618 , 1.05780152]),
#  'RBBP5': nan,
#  'RBBP6': nan,
#  'REPIN1': ArrayView([0.30552684, 0.24599556, 0.3155478 , ..., 0.51865973,
#             0.29148668, 1.09528593]),
#  'REST': ArrayView([0.32344528, 0.26392495, 0.36203321, ..., 0.49993662,
#             0.28753017, 1.04903999]),
#  'RFX2': ArrayView([0.31141794, 0.25762037, 0.33467395, ..., 0.51042001,
#             0.29166715, 1.06606756]),
#  'RNF2': ArrayView([0.3301475 , 0.26109953, 0.34904363, ..., 0.4914485 ,
#             0.27927189, 1.07735786]),
#  'RUNX1': ArrayView([0.33303945, 0.28080051, 0.34418632, ..., 0.49815775,
#             0.27931407, 1.06431598]),
#  'RUNX3': ArrayView([0.36716584, 0.28206665, 0.36047758, ..., 0.5110888 ,
#             0.27924304, 1.05200727]),
#  'RUVBL2': nan,
#  'SALL4': ArrayView([0.33497894, 0.18129364, 0.33350079, ..., 0.52854632,
#             0.27722597, 1.10477462]),
#  'SAP30': nan,
#  'SETDB1': ArrayView([0.31664468, 0.24586798, 0.33695928, ..., 0.50984679,
#             0.29476947, 1.11692292]),
#  'SIN3A': ArrayView([0.30435738, 0.25566276, 0.33855242, ..., 0.52048662,
#             0.29200393, 1.07793835]),
#  'SIX5': ArrayView([0.30603291, 0.24521165, 0.32945434, ..., 0.51063502,
#             0.28103558, 1.06218754]),
#  'SMAD1': ArrayView([0.37063611, 0.27271793, 0.35202   , ..., 0.48009773,
#             0.29469447, 1.01574512]),
#  'SMAD2': ArrayView([0.3190797 , 0.26316463, 0.34906425, ..., 0.50852389,
#             0.27887732, 1.06975906]),
#  'SMAD4': ArrayView([0.31464346, 0.26040199, 0.34562823, ..., 0.52108411,
#             0.28354638, 1.07484189]),
#  'SMAD5': ArrayView([0.31072429, 0.26027095, 0.34979497, ..., 0.51227242,
#             0.28482093, 1.07144428]),
#  'SMC3': ArrayView([0.30925221, 0.2560423 , 0.35407711, ..., 0.50926157,
#             0.28085724, 1.08061065]),
#  'SNAI1': ArrayView([0.32940073, 0.27219917, 0.35943588, ..., 0.52008381,
#             0.26763142, 1.07232052]),
#  'SNAI2': ArrayView([0.28410982, 0.2404632 , 0.34849548, ..., 0.49327001,
#             0.27987079, 1.06371046]),
#  'SOX14': ArrayView([0.34813577, 0.26840587, 0.33915717, ..., 0.48800058,
#             0.28096184, 1.04274076]),
#  'SOX15': ArrayView([0.27663202, 0.28334104, 0.44159791, ..., 0.53849214,
#             0.2152802 , 1.04330277]),
#  'SOX17': ArrayView([0.46694549, 0.38792052, 0.32937505, ..., 0.43441294,
#             0.29094644, 1.0293457 ]),
#  'SOX2': ArrayView([0.35795214, 0.16368765, 0.33254672, ..., 0.57847497,
#             0.32758145, 1.09426161]),
#  'SOX7': ArrayView([0.36140394, 0.32944137, 0.31694227, ..., 0.48680476,
#             0.28945062, 1.02081083]),
#  'SPIC': ArrayView([0.31422108, 0.25798492, 0.35158116, ..., 0.51178737,
#             0.28076954, 1.07212587]),
#  'STAG1': ArrayView([0.29990498, 0.24887338, 0.35606815, ..., 0.47648364,
#             0.28978346, 1.0817979 ]),
#  'STAT3': ArrayView([0.34312899, 0.30869748, 0.41076308, ..., 0.46517669,
#             0.2858831 , 0.92915589]),
#  'STAT4': ArrayView([0.30498602, 0.24882473, 0.35437925, ..., 0.50644117,
#             0.281336  , 1.05865777]),
#  'STAT5A': ArrayView([0.46037738, 0.31306167, 0.36177436, ..., 0.48963108,
#             0.26662469, 0.99900968]),
#  'STRA8': nan,
#  'TBX2': ArrayView([0.32654734, 0.26983846, 0.35003287, ..., 0.50703562,
#             0.28412531, 1.06229638]),
#  'TBX4': ArrayView([0.31646005, 0.26221424, 0.35292468, ..., 0.50862146,
#             0.27994919, 1.06916539]),
#  'TBX5': ArrayView([0.29428065, 0.26010915, 0.35604998, ..., 0.49201735,
#             0.28753482, 1.0515671 ]),
#  'TCF12': ArrayView([0.31450236, 0.23232616, 0.32936243, ..., 0.44137424,
#             0.28258598, 1.0915841 ]),
#  'TCF4': ArrayView([0.32311714, 0.25012745, 0.31477334, ..., 0.49355341,
#             0.32597712, 1.04492822]),
#  'TCF7L2': ArrayView([0.31566196, 0.26189407, 0.35117898, ..., 0.50746559,
#             0.28074998, 1.06171302]),
#  'TEAD4': ArrayView([0.37870264, 0.32312674, 0.36675197, ..., 0.5539695 ,
#             0.28167442, 1.05347905]),
#  'TFAP2A': ArrayView([0.32548493, 0.26966782, 0.35101199, ..., 0.50878435,
#             0.28236874, 1.07080894]),
#  'TFAP2B': ArrayView([0.31492806, 0.25924109, 0.35183211, ..., 0.51103983,
#             0.28110794, 1.0715351 ]),
#  'TFCP2L1': ArrayView([0.37603069, 0.28936657, 0.38323812, ..., 0.49021612,
#             0.26091134, 1.04285116]),
#  'TFE3': ArrayView([0.28698506, 0.22313753, 0.36027518, ..., 0.46073944,
#             0.26666069, 1.076669  ]),
#  'TGIF1': ArrayView([0.33589983, 0.2738691 , 0.34308136, ..., 0.50126411,
#             0.27777387, 1.0563483 ]),
#  'TGM2': nan,
#  'THAP1': ArrayView([0.32073022, 0.2627063 , 0.36555943, ..., 0.50218281,
#             0.29432152, 1.09565845]),
#  'THAP11': ArrayView([0.26780599, 0.23838632, 0.34477533, ..., 0.56488395,
#             0.30027128, 1.12278418]),
#  'THAP3': ArrayView([0.29987239, 0.26193565, 0.34616181, ..., 0.51324995,
#             0.27816906, 1.08693389]),
#  'THAP7': ArrayView([0.28758149, 0.22464988, 0.34670114, ..., 0.55358957,
#             0.30032367, 1.10325625]),
#  'TP53': ArrayView([0.3107044 , 0.25991801, 0.34530118, ..., 0.51507586,
#             0.2938725 , 1.08824837]),
#  'TRPV2': nan,
#  'TWIST2': ArrayView([0.33958876, 0.2654098 , 0.34980438, ..., 0.51187381,
#             0.28413141, 1.06449446]),
#  'TYRP1': nan,
#  'VAX1': ArrayView([0.31649635, 0.26043884, 0.35082616, ..., 0.50997247,
#             0.27984552, 1.06875517]),
#  'VPS72': ArrayView([0.26492796, 0.20353152, 0.29892298, ..., 0.55542883,
#             0.28592076, 1.13630883]),
#  'XRCC4': nan,
#  'ZBED4': ArrayView([0.26695363, 0.23009972, 0.30498571, ..., 0.50329207,
#             0.30526617, 1.11919614]),
#  'ZBTB33': ArrayView([0.31395319, 0.25825805, 0.35012799, ..., 0.50945838,
#             0.28142054, 1.07296368]),
#  'ZBTB45': ArrayView([0.31626822, 0.25825533, 0.34747319, ..., 0.51084931,
#             0.28106623, 1.0744494 ]),
#  'ZBTB7A': ArrayView([0.29437162, 0.2630488 , 0.37118792, ..., 0.56881542,
#             0.2785924 , 1.08651963]),
#  'ZFAND3': nan,
#  'ZIC1': ArrayView([0.34566816, 0.24696306, 0.2968219 , ..., 0.52208587,
#             0.2551422 , 1.09083704]),
#  'ZKSCAN1': ArrayView([0.28183817, 0.25058509, 0.34150806, ..., 0.4889288 ,
#             0.29318622, 1.06836843]),
#  'ZNF263': ArrayView([0.32765692, 0.26968957, 0.38059067, ..., 0.49558977,
#             0.27943801, 1.03790346]),
#  'ZNF280B': ArrayView([0.31456085, 0.25842787, 0.35175046, ..., 0.51098007,
#             0.28106191, 1.07143445]),
#  'ZNF281': ArrayView([0.32275473, 0.26241748, 0.35618928, ..., 0.50781666,
#             0.28847678, 1.06642614]),
#  'ZNF426': ArrayView([0.31378509, 0.25765176, 0.3529289 , ..., 0.50942489,
#             0.2817108 , 1.07235161]),
#  'ZNF646': ArrayView([0.32380824, 0.23581975, 0.36358441, ..., 0.49953531,
#             0.28351582, 1.07206099]),
#  'ZNF706': ArrayView([0.31467365, 0.25854038, 0.35184587, ..., 0.51111939,
#             0.28108861, 1.07118236]),
#  'ZNF713': ArrayView([0.31164426, 0.25796334, 0.34123343, ..., 0.50021955,
#             0.28104769, 1.06881945]),
#  'ALX1': ArrayView([0.32196546, 0.26304084, 0.35298907, ..., 0.50725327,
#             0.27296456, 1.05972929]),
#  'ATF4': ArrayView([0.32214271, 0.26274548, 0.35448598, ..., 0.50612533,
#             0.284165  , 1.08336441]),
#  'CBFB': ArrayView([0.31418521, 0.25867241, 0.35199779, ..., 0.51073874,
#             0.28109871, 1.06971524]),
#  'CHD5': nan,
#  'CITED1': ArrayView([0.31420381, 0.25656119, 0.35116047, ..., 0.50860474,
#             0.28102272, 1.07038045]),
#  'CTBP1': ArrayView([0.28481994, 0.25415479, 0.33666015, ..., 0.51597819,
#             0.27841179, 1.06483587]),
#  'CXXC5': ArrayView([0.31086116, 0.25584755, 0.35078734, ..., 0.51377766,
#             0.27868286, 1.06871134]),
#  'EMX2': ArrayView([0.31460506, 0.25854718, 0.35176834, ..., 0.51097389,
#             0.28109683, 1.07112081]),
#  'ETV4': ArrayView([0.31511139, 0.26171682, 0.35504069, ..., 0.51546295,
#             0.280879  , 1.06675247]),
#  'FGR': nan,
#  'FOXE1': ArrayView([0.31460223, 0.25854084, 0.35176118, ..., 0.51098482,
#             0.28110194, 1.07113014]),
#  'GTF3C5': nan,
#  'HMGA1': ArrayView([0.28961061, 0.23627903, 0.35527911, ..., 0.52828043,
#             0.2753112 , 1.08262021]),
#  'HNRNPD': ArrayView([0.31461969, 0.2592677 , 0.35133885, ..., 0.51237079,
#             0.28012039, 1.07408982]),
#  'HOXC5': ArrayView([0.31424477, 0.25811671, 0.35192762, ..., 0.51078634,
#             0.28134548, 1.07146035]),
#  'MBD3': ArrayView([0.30989086, 0.25632356, 0.3522065 , ..., 0.51507918,
#             0.28235853, 1.07219459]),
#  'MLLT1': ArrayView([0.31455052, 0.25839743, 0.352108  , ..., 0.51105324,
#             0.2809543 , 1.07149921]),
#  'NR1H2': ArrayView([0.31824359, 0.25988783, 0.3607452 , ..., 0.52723652,
#             0.28425761, 1.0732325 ]),
#  'OSR1': ArrayView([0.31460158, 0.25853671, 0.35176522, ..., 0.51098758,
#             0.28110234, 1.07113151]),
#  'POU3F4': ArrayView([0.33446733, 0.24321169, 0.35006277, ..., 0.49724457,
#             0.27978494, 1.07750543]),
#  'PRDM2': ArrayView([0.31441745, 0.2584907 , 0.35176959, ..., 0.51041595,
#             0.28129464, 1.07064497]),
#  'PRICKLE1': nan,
#  'SRF': ArrayView([0.31410218, 0.25949915, 0.35291193, ..., 0.51200614,
#             0.2811349 , 1.07054832]),
#  'TAF1A': ArrayView([0.32125548, 0.25638486, 0.35898242, ..., 0.51611864,
#             0.28761815, 1.1100622 ]),
#  'TCF15': ArrayView([0.31461262, 0.25855889, 0.3517739 , ..., 0.51099589,
#             0.28110881, 1.07112701]),
#  'TEF': ArrayView([0.31455307, 0.25849392, 0.35181287, ..., 0.51084559,
#             0.28115734, 1.07090896]),
#  'THAP10': ArrayView([0.31459816, 0.25854207, 0.35176011, ..., 0.5110185 ,
#             0.28109898, 1.07115226]),
#  'THRA': ArrayView([0.29144959, 0.25341542, 0.32868129, ..., 0.52922062,
#             0.29079494, 1.08356478]),
#  'TNF': ArrayView([0.31461448, 0.25854053, 0.35175646, ..., 0.51098906,
#             0.28110587, 1.07112886]),
#  'ZNF384': ArrayView([0.31809997, 0.25591292, 0.35592063, ..., 0.51019728,
#             0.27939332, 1.06936743]),
#  'ZNF480': ArrayView([0.3144768 , 0.25810719, 0.35116532, ..., 0.51055365,
#             0.28154005, 1.07203258]),
#  'ZNF74': ArrayView([0.30650587, 0.25353668, 0.34461631, ..., 0.51620885,
#             0.28708733, 1.08116652])}

# %% [markdown]
# ### Evaluation
#
# We compute the correlation of the predictions with held-out perturbations.

# %%
controlIndex = ko_lab_esc_data_train.obs["perturbation"]=="Control"
evaluator.evaluateCausalModel(heldout = ko_lab_esc_data_heldout, 
                    predictions = predictions,   
                    baseline = ko_lab_esc_data_train[controlIndex,:].X.mean(axis=0), 
                    classifier=cellFateClassifier, 
                    experiments = experiments,
                    factor_varied = "network",
                    experiment_name = EXPERIMENT_NAME)
# Out:
# (      spearman     spearmanp  cell_fate_correct perturbation  index  network  \
#  0     0.239075  3.728341e-35                0.0         ALX3      0    dense
#  1     0.184445  2.370995e-21                0.0         ALX4      0    dense
#  2     0.000000  1.000000e+00                NaN      ANKRD22      0    dense
#  3     0.198213  1.800618e-24                0.0           AR      0    dense
#  4     0.168788  4.335405e-18                0.0        ARNT2      0    dense
#  ...        ...           ...                ...          ...    ...      ...
#  4203  0.094460  1.380655e-06                1.0         THRA     15  mogrify
#  4204  0.154329  2.423030e-15                0.0          TNF     15  mogrify
#  4205  0.138807  1.135825e-12                1.0       ZNF384     15  mogrify
#  4206  0.103738  1.130106e-07                1.0       ZNF480     15  mogrify
#  4207  0.085719  1.190452e-05                0.0        ZNF74     15  mogrify
#
#        p  threshold_number pruning  somePredictionRefused
#  0     1         102313295    none                   True
#  1     1         102313295    none                   True
#  2     1         102313295    none                   True
#  3     1         102313295    none                   True
#  4     1         102313295    none                   True
#  ...  ..               ...     ...                    ...
#  4203  1         102313295    none                   True
#  4204  1         102313295    none                   True
#  4205  1         102313295    none                   True
#  4206  1         102313295    none                   True
#  4207  1         102313295    none                   True
#
#  [4208 rows x 10 columns],
#  <AxesSubplot:xlabel='network', ylabel='Spearman correlation \npredicted log fold change vs observed'>,
#  {'spearman': <AxesSubplot:title={'center':'Mean and SE of spearman'}, xlabel='network', ylabel='spearman'>,
#   'cell_fate_correct': <AxesSubplot:title={'center':'Mean and SE of cell_fate_correct'}, xlabel='network', ylabel='cell_fate_correct'>})
